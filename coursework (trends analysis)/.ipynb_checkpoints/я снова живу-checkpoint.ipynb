# %% [markdown]
# ## Что нужно сделать?
#     (+) переделать получение описаний с запроса к api на поиск по данной html-странице
#     (+) обработать все базы и выделить нужные вакансии, перенести в новую базу
#     (+) выделить из каждой вакансии список требований
#     (+) перенести сюда то, что скинул Саня
#     (+) сделать окончательную удобную! базу (id, работодатель, дата публикации, город, требования)
#
#
#     (-) передалать выбор требований через regexp
#     (-) сделать окончательный список встречающихся технологий
#     (-) создать матрицу упоминаний технологий по каждой вакансии
#     (-) подумать над тем, как лучше визуализировать результаты
#     (-) визуализировать результаты
#     (-) кластеризовать названия вакансий по их описаниям (опционально)

# %%
import sqlite3
import requests
import json
from bs4 import BeautifulSoup

# %%
pre_final = 'C:\\Users\\busya\\Desktop\\anaconda\\проекты\\uni\\курсовая\\final.db'

conn = sqlite3.connect(pre_final)
cursor = conn.cursor()

cursor.execute('SELECT * from vacancy')
pre_final_db = cursor.fetchall()
conn.close()

# %%
final = 'dataset.db'

conn = sqlite3.connect(final)
cursor = conn.cursor()

cursor.execute('SELECT * from vacancies')
final_db = cursor.fetchall()
conn.close()

# %% [markdown]
# ### Создание новой "хорошей" базы данных
#     1. используем hh.api для сбора полезных для инфографики характеристик

# %%
def collect_data(id_):
    req = requests.get('https://api.hh.ru/vacancies/' + id_).json()
    new_line = (
        id_,
        req['name'],
        req['area']['name'],
        req['employer']['name'],
        req['published_at'],
        req['description']
    )
    return new_line

# %%
#beautiful_db = []
#left = len(final_db)
#for job in final_db:
#    beautiful_db.append(collect_data(job[0]))
#    left -= 1
#    if left % 100 == 0:
#        print(f'осталось {left} вакансий.')

# %%
#conn = sqlite3.connect('C:\\Users\\mag\\Desktop\\data_set.db')
#cursor = conn.cursor()
#cursor.execute('''CREATE TABLE vacancies (id text, name text, city text, 
#                                            employer text, publication_date text, description text)''')
#for job in beautiful_db:
#    try:
#        cursor.execute(f'''INSERT INTO vacancies VALUES {job}''')
#    except:
#        pass
#conn.commit()

# %% [markdown]
# ### Формирование списка всех возможных технических навыков
#     1. выкачка с википедии
#     2. доп. анализ получившихся требований с целью обнаружения английский названий
#     3. добавление аббревиатур

# %%
link = 'https://ru.wikipedia.org/wiki/Список_языков_программирования_по_категориям'
alphabet = 'абвгдеёжзийклмнопрстуфхцчщшьыъэюя'

# %%
soup = BeautifulSoup(requests.get(link).text, 'lxml')

# %%
base = [y for y in [x.text.lower() for x in soup.findAll('li')][20:-67] if set(y) & set(alphabet) == set()]

# %%
print(len(base))
base[-5:]
# Out:
# 161
# ['lolcode', 'malbolge', 'piet', 'whitespace', 'emptyscript']

# %%
monosyllabic = [x for x in base if len(x.split()) == 1] # односложные названия
monosyllabic[:7]
# Out:
# ['aspectc++', 'aspectj', 'caesarj', 'compose*', 'objectteams', 'basic', 'cg']

# %% [markdown]
# ### Получение списка требований с помощью регулярных выражений
#     то, что прислала Катя

# %%
# пример работы
list(filter(None, re.compile("<[^>]*>").split(re.sub('> +<', '', final_db[182][-1]))))
# Out:
# ['Требования:',
#  'Опыт работы в IT сфере;',
#  'Понимание методологии ITSM;',
#  'Знание интерфейса и опыт написание SQL скриптов;',
#  'Навык разбора файлов в XML формате.',
#  'Обязанности:',
#  'Сопровождение АС Pega.',
#  'Условия работы:',
#  'Условия работы:',
#  'Место работы: м. Кожуховская;',
#  'График работы 5/2;',
#  'Оформление согласно ТК РФ;',
#  'Социальный пакет: ДМС, спортзал (фитнес, йога), спортивные и культурно-массовые мероприятия, возможность обучения за счет компании, льготные условия кредитования;',
#  'Отличная профессиональная команда',
#  'Годовая премия']

# %%
keywords1 = ['требования', 'желательно', 'необходимо', 'ожидаем', 'requirements', 'обязательно', 
            'приветствуется', 'знание', 'ожидания', 'компетенции', 'приветствуются', 
            'backend', 'технологии', 'требуется', 'если', 'ждём', 'важно',
            'навыки', 'будет', 'ищем', 'уровень', 'вас', 'дополнительно', 'желательны', 'техническое',
            'ждем', 'стек', 'ожиданем', 'умеете', 'приветствуем', 'навыки', 'нужно', 'стеке', 'потребуется', 
            'преимуществом', 'нужен', 'ожиданием', 'пригодится', 'expect', 'fullstack', 'качества', 
            'looking', 'хотелось', 'требовани', 'обязательн', 'must', 'skills', 'мастхэв', 'required',
            'ходим', 'обязателен', 'тебя', 'преимущества', 'знаниеумения', 'пожелания', 'стэк', 'компетенция', 
            'желательные', 'преимущество', 'хотим', 'знания', 'желание', 'хотели', 'have', 'применяется', 'технологий',
            'видим', 'обязательные', 'разработки']

keywords2 = ['плюсом', 'плюсами', 'бонусы', 'плюсы', 'плюс',]

punct = '«•»∙!"#$%&\'()*+-./:;<=>?@[\\]^_`{|}~'
table = str.maketrans({key: None for key in punct})

# %%
req_set = {}
errors = []
names = []

for job in final_db:
    #print(job[0])
    text = job[5]
    if '<strong>' in text:
        paragraphs = [x.split('</strong>') for x in text.split('<strong>') if '</strong>' in x]
        for x in paragraphs:
            if set(x[0].lower().translate(table).split()) & set(keywords) != set():
                names.append(x[0])
        #        req_set[job[0]] = list(filter(None, re.compile("<[^>]*>").split(re.sub('> +<', '', x[1]))))
        #       break
    else:
        errors.append(job[0])

# %%
names
# Out:
# ['Требования:',
#  'Требования: ',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования: ',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Навыки:',
#  'Требования:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Технические компетенции:',
#  'Дополнительные требования:',
#  'Работая в данном проекте, разработчик получит возможность использовать в своей работе самые передовые технологии и фреймоворки BigData и стать одним из разработчиков такого фреймворка.',
#  'Требования:',
#  'Приветствуются знания / опыт:',
#  'Требования:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'ТРЕБОВАНИЯ К КАНДИДАТУ:',
#  'Общие требования:',
#  'Необходимые навыки и технологии:',
#  'Будет плюсом:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Мы ищем ',
#  'Технические компетенции',
#  'Будет плюсом',
#  'Уровень образования',
#  'Бонусы',
#  'Профессиональные компетенции',
#  'Навыки',
#  'Мы ожидаем от Вас:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования',
#  'Требования',
#  'Требования:',
#  'Мы ищем:',
#  'Требования',
#  'Требования:',
#  'Требования:',
#  'Плюсом будут:',
#  'Требования:',
#  'Профессиональные навыки:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Мы ждём от тебя:',
#  'Требования:',
#  'Требования:',
#  'Требования',
#  'Технические компетенции:',
#  'Приветствуется: ',
#  'Технические компетенции:',
#  'Личностные качества:',
#  'Плюсом будет опыт работы с:',
#  'Так же люсом будет знакомство с:',
#  'Мы ищем сильного аналитика, который вместе с нашей командой будет:',
#  'Требования',
#  'Будет плюсом',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Необходимые навыки',
#  'Плюсом будут',
#  'Тогда мы ждем тебя в нашу команду!',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Тогда мы ждем тебя в нашу команду!',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Тогда мы ждем тебя в нашу команду!',
#  'Требования:',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Тогда мы ждем тебя в нашу команду!',
#  'Требования:',
#  '<em>От Вас нужно:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Проекты, в которых будет задействован кандидат',
#  'Важно:',
#  'Плюсом будет:',
#  'Личностные качества',
#  'Знание специальных программ ',
#  'Уровень образования: ',
#  'Стэк',
#  'Важно:',
#  'Требования:',
#  '<em>Сбербанк объявляет набор специалистов, которые хотят развиваться в направлении разработки. Но это не стандартная разработка на известных языках.</em>',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Что нужно делать',
#  'От Вас нужно',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Проекты, в которых будет задействован кандидат',
#  'Требования',
#  'Обязательно:',
#  ' Компетенция Python разработчик',
#  ' Компетенция Data Scientist',
#  'Будет плюсом:',
#  'Личностные качества',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Будет плюсом:',
#  'Дополнительным плюсом было бы:',
#  'Требования:',
#  'Требования:',
#  'Обязательные:',
#  'Пожелания:',
#  'Наши преимущества:',
#  'Требования:',
#  ' России&quot; - крупнейший российский банк с собственным центром разработки и внедрения программного обеспечения. ',
#  'технологии',
#  'Бонусы и скидки',
#  'Обязательно:',
#  'Желательно:',
#  'Ждем тебя в команде профессионалов!',
#  'Требования: ',
#  'Используемый стек технологий:',
#  'Основные требования к кандидатам:',
#  'От вас нужно:',
#  'Знание технологий:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования:',
#  'Желательно:',
#  'Чего ждем от кандидата:',
#  'Требования:',
#  'Требуемые навыки и знания:',
#  'Личные качества кандидата:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Личные качества',
#  'Если тебе интересно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  '<em>В нашу команду требуется Аналитик:</em>',
#  'Требования:',
#  'Наши ожидания:',
#  'Плюсом будут:',
#  'Что необходимо делать:',
#  'Наши требования:',
#  'Требования:',
#  'Требования',
#  'Будет преимуществом',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Технические компетенции кандидата:',
#  'Плюсом будут:',
#  'Личностные качества',
#  'Требования',
#  '<em>Проект «Единый Розничный Интернет Банк» (ЕРИБ) – автоматизированная система, обеспечивающее дистанционный доступ клиентов к продуктам банка через сеть Интернет. Приложение разрабатывается более 10 лет распределенной командой разработчиков. Используемые технологии: Java SE, Struts, Hibernate, JSP,JavaScript, Oracle. В течение года выходит несколько релизов АС. В настоящее время в Самаре работают 3 разработчика и планируется расширение команды с привлечением к задачам по приему переводов и платежей физических лиц, а также следующих задач:</em>',
#  'Желательные знания:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'ТРЕБОВАНИЯ',
#  'Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit, знание основ РСУБД',
#  'Требования:',
#  'Технологии:',
#  'Наши ожидания:',
#  'Мы используем следующие технологии:',
#  'Наши ожидания',
#  'Технические компетенции:',
#  'Личностные качества:',
#  'Требования:',
#  'Требования:',
#  'Что нужно будет делать:',
#  'Какие компетенции мы ожидаем от вас:',
#  'Требования:',
#  'Требования',
#  'Требования:',
#  'Мы используем следующие технологии:',
#  'Мы ожидаем от кандидата:',
#  'Требования:',
#  '<em>Компания «Сбербанк», Блок «Технологии» приглашает Разработчика </em>',
#  'Желательно:',
#  'ТЕХНИЧЕСКИЕ КОМПЕТЕНЦИИ',
#  'ТЕХНИЧЕСКИЕ КОМПЕТЕНЦИИ',
#  'ТРЕБОВАНИЯ',
#  'Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit, знание основ РСУБД',
#  'ТРЕБОВАНИЯ',
#  'Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit, знание основ РСУБД',
#  'ТРЕБОВАНИЯ',
#  'Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit, знание основ РСУБД',
#  'Требования:',
#  'Требования:',
#  'От вас нужно:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Мы ждем тебя в нашу команду!',
#  'Если тебе интересно:',
#  'Если есть:',
#  'Тогда мы ждем тебя в нашу команду!',
#  'Требования:',
#  'Требования:',
#  'Требования',
#  '<em>Что нужно будет делать:</em>',
#  'Требования:',
#  'Если ты:',
#  'Ты подходишь нам, если:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Вас ожидает:',
#  'Требования:',
#  'Знание/умения:',
#  'Будет плюсом:',
#  'Дополнительно:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'b.Технические компетенции',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'современный стек технологий и микросервисную архитектуру',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Обязательные навыки:',
#  'Дополнительные преимущества для кандидата:',
#  'Требования',
#  'Требования:',
#  'Наши ожидания:',
#  'Наши ожидания:',
#  'Если ты:',
#  'Ты подходишь нам, если ты:',
#  'ы ждем тебя! ',
#  'Требования:',
#  'Требования:',
#  'Мы ждем что вы умеете/обладаете:',
#  'Круто если вы так же:',
#  'Требования:',
#  'Мы ожидаем, что у вас есть',
#  'Необходимые навыки и опыт:',
#  'Несомненными плюсами будут знания:',
#  'Технические компетенции:',
#  'Требования:',
#  'Стек технологий:',
#  'Требования:',
#  'Требования:',
#  'Требования',
#  'Требования:',
#  'Профессиональные компетенции',
#  'Профессиональные компетенции',
#  'Будет плюсом',
#  'Кого мы ищем:',
#  'Что хотелось бы видеть в кандидате:',
#  'Требования:',
#  'Требования',
#  'Требования',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'От Вас нужно:',
#  '<em><u>Что НЕ нужно будет делать:</u></em>',
#  'Требования',
#  'Желательно:',
#  'Требования:',
#  'Компетенции:',
#  'Требования:',
#  'Требования:',
#  'Мы ожидаем от кандидата:',
#  'Плюсом будет:',
#  'Используемые технологии:',
#  'Ожидания от кандидата:',
#  'Требования:',
#  'Требования:',
#  'Профессиональные компетенции',
#  'Знания и навыки: ',
#  'Дополнительные плюсом будет:',
#  'Требования:',
#  'Требования:',
#  'Ожидаем от кандидата:',
#  'Используемые технологии:',
#  'Необходимые навыки:',
#  'Требования:',
#  'Желательны:',
#  'Личностные качества:',
#  'Требования',
#  'Навыки:',
#  'Что нужно будет делать:',
#  'Знание технологий:',
#  'Ищем QA инженера в команду тестирования.',
#  'Вакансия подойдёт, если тебе важно качество выпускаемого продукта и ты стремишься к оптимизации работы и не забываешь про развитие в тестировании, а также в курсе последних новинок и подходов. ',
#  'Требования:',
#  'Требования:',
#  'Технические компетенции:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Наши ожидания:',
#  'Мы ожидаем у кандидата наличие следующих качеств:',
#  '<i>Сбербанк объявляет набор специалистов, которые хотят развиваться в направлении разработки. Но это не стандартная разработка на известных языках.</i>',
#  '<em>Что нужно будет делать:</em>',
#  'Требования:',
#  'Будет здорово, если вы:',
#  'Требования:',
#  'Требования',
#  'Мы ищем ',
#  'Технические компетенции',
#  'Будет плюсом',
#  'Уровень образования',
#  'Бонусы',
#  'Профессиональные компетенции:',
#  'Будет плюсом',
#  'Мы ищем ',
#  'Технические компетенции',
#  'Будет плюсом',
#  'Уровень образования',
#  'Бонусы',
#  'Технические компетенции:',
#  'Будет плюсом:',
#  'Профессиональные компетенции:',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Backend Разработчика следующий:',
#  '<em>Что нужно будет делать:</em>',
#  '<em>Что НЕ нужно будет делать:</em>',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Используемые технологии:',
#  'Мы ожидаем:',
#  'Дополнительные требования (будет плюсом):',
#  'Требования:',
#  'Требования:',
#  'Преимуществом будет:',
#  'Требования:',
#  'Для работы также потребуется знания (мы готовы этому учить):',
#  'Требования:',
#  'Приветствуется:',
#  'Будет плюсом:',
#  'Будет здорово, если вы:',
#  'Требования:',
#  'Мы ищем:',
#  'Требования:',
#  'Основные требования:',
#  'Мы ждем от кандидата: ',
#  'ждем',
#  '<em>Что нужно делать?</em>',
#  '<em>Что мы ждем от кандидата?</em>',
#  'Наши ожидания:',
#  'Требования:',
#  'Мы ждем что Вы',
#  'Будет плюсом:',
#  'Мы ждем что вы умеете/обладаете:',
#  'Круто если вы:',
#  'Обязательно:',
#  'Будет плюсом:',
#  'Ждем от Вас:',
#  'Требования:',
#  'Специализация в текстовом анализе и NLP (обязательно):',
#  'Дополнительные навыки (желательно):',
#  'Требования:',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Требования',
#  'Мы ждем тебя, чтобы строить счастливое будущее вместе!',
#  'Требования:',
#  'Требования:',
#  'Что важно для нас:',
#  'Плюсом будет опыт работы с:',
#  'Наши ожидания:',
#  'Дополнительным плюсом будет:',
#  'Требования: ',
#  'Обязательные компетенции:',
#  'Дополнительные компетенции:',
#  'Инструментальные требования:',
#  'Кого мы ждём:',
#  'Особенно ждём людей, которые идут с желанием не просто попробовать, а прийти и изменить, сделать хоть немного лучше, чем уже есть. Ведь если не мы, то — кто?',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Что нужно будет делать:',
#  'Требования:',
#  '<span><span><span>От Вас мы ждем:</span></span></span>',
#  'Требования:',
#  '<em>Вашим преимуществом будет:</em>',
#  'Очень хотим видеть у тебя:',
#  'Тем более будем рады если:',
#  'Дополнительные требования:',
#  'Очень хотим видеть у тебя:',
#  'Тем более будем рады если:',
#  'Требования:',
#  'Требования к кандидату:',
#  'Требования:',
#  'Для тебя:',
#  'тебя:',
#  'Требования:',
#  'Требования:',
#  'Требования для ',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования к кандидату:',
#  'Требования:',
#  'Требования:',
#  'Требования к кандидатам:',
#  'Кого ждем:',
#  'Требования',
#  '<span><span><span>Что мы от вас ожидаем:</span></span></span>',
#  'Что мы от вас ожидаем:',
#  'Приветствуется:',
#  'Что мы от вас ожидаем:',
#  'Приветствуется',
#  'Требования к кандидату:',
#  'Очень хотим видеть у тебя:',
#  'Тем более будем рады если:',
#  'Требования:',
#  'обязателен',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Что мы ждем от наших кандидатов?',
#  'Плюсы:',
#  'Что для нас важно:',
#  'Плюсы',
#  'Требования:',
#  'техническое',
#  'Что для нас важно:',
#  'Требования:',
#  'техническое',
#  'Требования',
#  'Плюсы',
#  'Требования',
#  'Плюсы',
#  'Требования:',
#  'Плюсы:',
#  'Что для нас важно:',
#  'Плюсы',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования: ',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'техническое',
#  'Как плюс',
#  'Требования:',
#  'Требования: ',
#  'Желательно: ',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Требования',
#  'Что мы ждем от наших кандидатов?',
#  'Требования',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно: ',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования: ',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом, если вы:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Что мы ждем от наших кандидатов?',
#  'Плюсы:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Здорово, если Вы обладаете следующими профессиональными навыками:',
#  'Требования:',
#  'Требования:',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования:',
#  'техническое',
#  'Как плюс',
#  'Требования:',
#  'техническое',
#  'Требования:',
#  'Требования:',
#  'Уважаемые кандидаты! Просьба, если в вашем резюме не указан ожидаемый уровень дохода - указать его в сопроводительном письме. Резюме без указания дохода рассматриваться не будут.',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования к кандидату:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Требования к кандидату:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Убедительная просьба, если у Вас в резюме не указан ожидаемый уровень заработной платы - указать его в сопроводительном письме.',
#  'Требования: ',
#  'Требования:',
#  'Желательно:',
#  'Если вам захочется большего разнообразия в работе, то у нас есть и такие задачи:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования: ',
#  'Плюсом будет:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Приветствуется:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования',
#  'Желательно',
#  'Приветствуется',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования к кандидату:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования к кандидату:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Будет плюсом:',
#  'Мы ожидаем от Вас: ',
#  'Желательны: ',
#  'Требования:',
#  'Будет плюсом',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Будет плюсом, если вы:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования к кандидату:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Требования к опыту работы:',
#  'Компетенции:',
#  'Требования:',
#  'Успешным кандидатам, отобранным по резюме, будет предложено тестовое задание. ',
#  'Используемые технологии:',
#  'Требования:',
#  'Будет плюсом:',
#  'Используемые технологии:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Бонусы:',
#  'Требования:',
#  'Будет плюсом:',
#  'Бонусы:',
#  'Требования к образованию и квалификации:',
#  'Требования к опыту работы:',
#  'Требования к владению иностранными языками:',
#  'Требования к образованию и квалификации:',
#  'Требования к знаниям и умениям: ',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом: ',
#  'Требования:',
#  'Требования:',
#  'Преимуществом будет:',
#  'Требования:',
#  'Требования (по приоритетам): ',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Бонусы:',
#  'Важно!',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Преимуществом будет:',
#  'Требования:',
#  'Будет преимуществом:',
#  'Для нас важно: ',
#  'Требования:',
#  'Требования к опыту работы:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования (по приоритетам): ',
#  'Требования:',
#  'Требования (по приоритетам): ',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Бонусы:',
#  'Требования:',
#  'Требования:',
#  'Кого мы ищем:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Преимуществом будет:',
#  'Требования:',
#  'Требования:',
#  'Требования к образованию и квалификации:',
#  'Требования к опыту работы:',
#  'Требования к владению иностранными языками:',
#  'Требования (по приоритетам): ',
#  'Используемые технологии:',
#  'Требования:',
#  'Будет плюсом:',
#  'Используемые технологии:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Ключевые требования: ',
#  'Будет плюсом:',
#  'Требования:',
#  'Приветствуется:',
#  'Что ходим увидеть в резюме кандидата:',
#  'Желательно там также найти:',
#  'Мы ожидаем:',
#  'Будет плюсом:',
#  'Требования: ',
#  'Requirements: ',
#  'Требования:',
#  'Необходимо знать:',
#  'Кого мы ищем:',
#  'Requirements:',
#  'Мы ожидаем:',
#  'Обязательно: \\u200b',
#  'Требования:',
#  'Основные требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Будет плюсом опыт работы с некоторыми из наших технологий/инструментов:',
#  'Хотим познакомится с тобой, если ты:',
#  'Required: ',
#  'Additional requirements: ',
#  'Мы ожидаем:',
#  'Что важно для нас:',
#  'Требования к кандидатам:',
#  'Требования:',
#  'Requirements:',
#  'Требования:',
#  'Мы ожидаем:',
#  'Ключевые требования:',
#  'Requirements:',
#  'Требования:',
#  'Будет плюсом:',
#  'Requirements:',
#  'Ключевые требования:',
#  'Будет плюсом:',
#  'Мы ожидаем:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Личные качества:',
#  'Требования:',
#  'Технические требования:',
#  'Большим плюсом будут:',
#  'Требования:',
#  'Будет плюсом:',
#  'Личные качества:',
#  'Требования к кандидату',
#  'Ключевые требования:',
#  'Требования:',
#  'Дополнительно:',
#  'Требования:',
#  'Требования:',
#  'Мы ожидаем:',
#  'Требования:',
#  'Не обязательно, но будет плюсом:',
#  'Требования:',
#  'Плюсом будет:',
#  'Требования:',
#  'Дополнительными плюсами будут:',
#  'Требования к кандидату:',
#  'Обязательно:',
#  'Желательно:',
#  'Необходимые знания:',
#  'Требования к кандидату:',
#  'Желательно:',
#  'Требования:',
#  'Желательно:',
#  'Что Вам необходимо для этого:',
#  'щё желательно:',
#  'Ожидаем от вас:',
#  'Дополнительными плюсами будут:',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом',
#  'Технические требования:',
#  'Большим плюсом будут:',
#  'Требования:',
#  'Желательно:',
#  'Ключевые требования:',
#  'Будет плюсом:',
#  'Мы ожидаем:',
#  'Будет преимуществом:',
#  'Основные требования:',
#  'Требования:',
#  'Обязательно: \\u200b',
#  'Требования:',
#  'Обязательно:',
#  'Очень желательно:',
#  'Желательно:',
#  'Уникальный проект и возможность стать частью очень сильной команды разработки;',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Обязательно:',
#  'Желательно:',
#  'Уникальный проект и возможность стать частью очень сильной команды разработки;',
#  'Обязательно:',
#  'Желательно:',
#  'Уникальный проект и возможность стать частью очень сильной команды разработки;',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования:',
#  'Требования к кандидату',
#  'Мы ожидаем что Вы:',
#  'Основные требования:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования к кандидату',
#  'Будет плюсом:',
#  'качества',
#  'Требования:',
#  'Дополнительными плюсами будут:',
#  'Мы ожидаем:',
#  'Мы ожидаем:',
#  'Плюсом будет:',
#  'Ключевые требования:',
#  '<em>Английский язык не ниже уровня upper-intermediate (навыки общения в письменной форме, лично и по телефону)</em>',
#  'Qualification Requirements',
#  'Knowledge, skills and abilities',
#  'Must have',
#  'Functional knowledge and skills',
#  'Personal Skills:',
#  'Мы ожидаем',
#  'Желательно что-то из нижеперечисленного',
#  'Требования:',
#  'Требования:',
#  'Сербский – обязательно.',
#  'Требования:',
#  'Желательно:',
#  'Требования:',
#  'Будет плюсом:',
#  'Мы ожиданем:',
#  'Желательно:',
#  'От кандидата ожидаем:',
#  '<em>Не обязательно, но мы будем рады, если у тебя</em>',
#  'Мы ожидаем:',
#  'Основные требования:',
#  'Что от Вас требуется:',
#  'Мы ожидаем:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования:',
#  'Основные требования:',
#  'Приветствуются:',
#  'Требования к кандидату:',
#  'Обязательно:',
#  'Желательно:',
#  'Требования:',
#  'Ждем от вас:',
#  'Требования:',
#  'Мы ожидаем:',
#  'Требования:',
#  'Мы ожидаем:',
#  'Обязательн',
#  ' требовани',
#  'Приветствуются:',
#  'Мы ждём от тебя:',
#  'Требования:',
#  'Обязательно:',
#  'Желательно:',
#  'Личные качества:',
#  'Требования:',
#  'Желательно:',
#  'Мы ждём от тебя:',
#  'Мы ждём от тебя:',
#  'Ждем от вас:',
#  'Обязательно:',
#  'Будет плюсом:',
#  'Мы ожидаем:',
#  'Требования:',
#  'Дополнительно:',
#  'Необходимые знания:',
#  'Наши ожидания:',
#  'Требования:',
#  'Требования:',
#  'Дополнительным плюсом будет:',
#  'Мы рассчитываем, что вы умеете:',
#  'Что надо будет делать:',
#  'Мы ждем, что у вас есть:',
#  'Плюсом будет, если у вас есть:',
#  'Требования:',
#  'Основные требования:',
#  'Обязательно: \\u200b',
#  'Навыки и знания:',
#  'Требования',
#  'Желательно:',
#  'Мы ожидаем:',
#  'Требования:',
#  'Требования:',
#  'Требования:',
#  'Хотим познакомится с тобой, если ты:',
#  'Мы ожидаем:',
#  'Будет плюсом:',
#  'Requirements: ',
#  'Требования:',
#  'Requirements',
#  'Требования:',
#  'Желательно:',
#  'Требования к соискателям:',
#  'Желательно',
#  'Требования:',
#  'Обязательно:',
#  'Желательно:',
#  'Требования:',
#  'Обязательно:',
#  'Желательно:',
#  'Требования:',
#  'Требования:',
#  'Будет плюсом:',
#  'Требования к кандидату',
#  'Мы ожидаем:',
#  'Плюсом будет:',
#  'Мы ожидаем:',
#  'Мы ожидаем',
#  'Желательно что-то из нижеперечисленного',
#  'Мы ожидаем:',
#  'Плюсом будет:',
#  'Требования:',
#  'Дополнительными плюсами будут:',
#  'Мы ищем того, кто:',
#  'Ключевые требования:',
#  'Требования к соискателям:',
#  'Желательно:',
#  'Требования:',
#  'Желательно',
#  'Требования:',
#  'Требования:',
#  ...]

# %% [markdown]
# ### Получение списка требований
#     код, скопированный из предыдущего рабочего файла

# %%
import re

# %%
# удаление html-кода из текста
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, ' ', raw_html)
    return ' '.join(cleantext.split())

# %%
all_paragraphs = {}
errors = []
punct = '«•»∙!"#$%&\'()*+-./:;<=>?@[\\]^_`{|}~'
table = str.maketrans({key: None for key in punct})

for job in final_db:
    text = job[5]
    if '<strong>' in text:
        paragraphs = [x.split('</strong>') for x in text.split('<strong>') if '</strong>' in x]
        all_paragraphs[job[0]] = {x[0].translate(table).strip().lower(): x[1] for x in paragraphs}
    else:
        errors.append(job[0])

# %%
keywords = ['требования', 'желательно', 'плюсом', 'необходимо', 'ожидаем', 'requirements', 'обязательно', 
            'приветствуется', 'плюсами', 'знание', 'ожидания', 'компетенции', 'приветствуются', 
            'backend', 'технологии', 'требуется', 'если', 'бонусы', 'ждём', 'важно', 'плюсы', 'плюс', 
            'навыки', 'будет', 'ищем', 'уровень', 'вас', 'дополнительно', 'желательны', 'техническое',
            'ждем', 'стек', 'ожиданем', 'умеете', 'приветствуем', 'навыки', 'нужно', 'стеке', 'потребуется', 
            'преимуществом', 'нужен', 'ожиданием', 'пригодится', 'expect', 'fullstack', 'качества', 
            'looking', 'хотелось', 'требовани', 'обязательн', 'must', 'skills', 'мастхэв', 'required',
            'ходим', 'обязателен', 'тебя', 'преимущества', 'знаниеумения', 'пожелания', 'стэк', 'компетенция', 
            'желательные', 'преимущество', 'хотим', 'знания', 'желание', 'хотели', 'have', 'применяется', 'технологий',
            'видим', 'обязательные', 'разработки']

# %%
requirements = {}
requirements_l = []
for id_ in all_paragraphs: 
    for paragraph in all_paragraphs[id_]:
        word_list = paragraph.split()
        if set(word_list) & set(keywords) != set():              # а что если несколько заголовков подойдут?
            new_reqs = all_paragraphs[id_][paragraph].strip()
            if cleanhtml(new_reqs) != '':
                requirements[id_] = new_reqs
                requirements_l.append(new_reqs)
            else:
                errors.append(id_)

# %%
work_list = []
for i in requirements_l:
    work_list.append(i.split('>'))

# %%
new_work_list = []
for i in work_list:
    ap_list = []
    for j in i:
        ap_list.append(j.split('<'))
    new_work_list.append(ap_list)

# %%
flatten_list = []
for i in new_work_list:
    for j in i:
        for k in j:
            flatten_list.append(k)

# %%
trash_list = ['ul', 'li', 'p', 'b', '/ul', '/li', 
              '/p', '/b', 'em','/em','div','/div',
              'br','/br', 'ol', '/ol', '/span', 'u', '/u',
             ' ', '', 'br/', 'span', ':', 'br /']

# %%
requirements_final = []
for i in flatten_list:
    if i not in trash_list:
        requirements_final.append(i)

# %% [markdown]
# ### Анализ наименований
#     в конечном массиве каждая строка приведена к нижнему регистру, а и знаков препинания имеет только слэш, скобки и запятые.

# %%
new_punct = '«•»∙!"#$%&\'*-.:;<=>?@[\\]^_`{|}~'
new_table = str.maketrans({key: None for key in new_punct})
requirements = [x.translate(new_table).strip().lower() for x in requirements_final]

# %%
requirements[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-ec7cfc52f3b7> in <module>()
# ----> 1 requirements[:5]
#
# NameError: name 'requirements' is not defined

# %% [markdown]
# ### Формирование окончательного списка технологий

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
from nltk.corpus import stopwords
import collections

# %%
def prepare_text(text):
    return [gensim.utils.simple_preprocess(str(sentence), deacc=True) for sentence in text]

# %%
punct = ',)(«•»∙!"#$%&\'*-.:;<=>?@[\\]^_`{|}~'
table = str.maketrans({key: None for key in punct})
clean_requirements = [x.translate(table).strip().lower() for x in requirements]

# %%
techs = []
flatten = []
for sent in clean_requirements:
    line = []
    for token in sent.split():
        if set(token) & alph_en != set() and set(token) & alph_ru == set():
            line.append(token)
            flatten.append(token)
    if line != []:
        techs.append(line)

# %%
techs[:5]
# Out:
# [['ms', 'windows', 'ms', 'office'],
#  ['macos/ios', 'linux'],
#  ['windows'],
#  ['web', 'html', 'html5', 'css', 'javascript', 'css'],
#  ['angularjs', 'reactjs']]

# %%
bigram = gensim.models.phrases.Phrases(techs, min_count=4, threshold=10)
text_bigram = [bigram[sent] for sent in techs]

# %%
text_bigram[:5] # не очень чистый, но список технологий по предложениям
# Out:
# [['ms', 'windows', 'ms_office'],
#  ['macos/ios', 'linux'],
#  ['windows'],
#  ['web', 'html', 'html5', 'css', 'javascript', 'css'],
#  ['angularjs', 'reactjs']]

# %%
from_reqs_techs = [x[0] for x in sorted(dict(collections.Counter(flatten)).items(), key = lambda x: x[1], \
                                        reverse = True) if x[1] > 30]

# %%
from_reqs_techs = [x for x in from_reqs_techs if x not in stopwords.words('english')]

# %%
not_mine = ['a', 'and', 'd', 'e', 'etc', 'experience', 'in', 
            'intermediate', 'it', 'j', 'knowledge', 'of', 'e', 
            'j', 'self', 'the']

# %%
full_techs = set(list(set(from_reqs_techs + base).difference(not_mine)))

# %%
len(full_techs)
# Out:
# 206

# %%
full_techs
# Out:
# {'5th',
#  '8th',
#  'abap/4',
#  'ability',
#  'action script',
#  'active c#',
#  'ada',
#  'agile',
#  'amp',
#  'android',
#  'angular',
#  'ansible',
#  'apache',
#  'api',
#  'aspectc++',
#  'aspectj',
#  'aspnet',
#  'awk',
#  'bash',
#  'basic',
#  'bcpl',
#  'befunge',
#  'brainfuck',
#  'breeze',
#  'byter',
#  'c',
#  'c#',
#  'c++',
#  'c++/cli',
#  'c/c++',
#  'caesarj',
#  'cat',
#  'cg',
#  'chuck',
#  'ci',
#  'cilk',
#  'clarion',
#  'clean',
#  'clipper',
#  'coldfusion',
#  'compose*',
#  'confluence',
#  'core',
#  'corn',
#  'cosy',
#  'css',
#  'curry',
#  'data',
#  'dataflex',
#  'dbase',
#  'delphi',
#  'deque',
#  'design',
#  'development',
#  'devops',
#  'docker',
#  'dylan',
#  'eiffel',
#  'elm',
#  'emptyscript',
#  'enchilada',
#  'erlang',
#  'euphoria',
#  'excel',
#  'f#',
#  'factor',
#  'false',
#  'fbd',
#  'forth',
#  'foxpro',
#  'framework',
#  'freelang',
#  'game maker language (gml)',
#  'gentee',
#  'git',
#  'gnu bc',
#  'golang',
#  'gpss',
#  'groovy',
#  'haskell',
#  'haxe',
#  'hope',
#  'html',
#  'http',
#  'ibm',
#  'il',
#  'intercal',
#  'io',
#  'ios',
#  'is',
#  'java',
#  'java\njoin java\nx10',
#  'javascript',
#  'jenkins',
#  'jira',
#  'join java',
#  'join-calculus',
#  'joule',
#  'jovial',
#  'joy\nfactor\n5th\nenchilada\ncat\nraven\nonyx\nstaapl\nlviv\ndeque\nom\nkitten\nmoy\nbreeze\nfreelang\n8th\nmjoy\ncosy',
#  'jquery',
#  'js',
#  'kafka',
#  'kitten',
#  'kotlin',
#  'ladder diagram',
#  'limbo',
#  'linux',
#  'lolcode',
#  'lua',
#  'lviv',
#  'malbolge',
#  'management',
#  'maple',
#  'mathematica',
#  'matlab',
#  'mc#',
#  'mercury',
#  'metaquotes language mql4/mql5',
#  'microsoft',
#  'mjoy',
#  'ml',
#  'moy',
#  'mozart',
#  'ms',
#  'nemerle',
#  'net',
#  'netp',
#  'nosql',
#  'object pascal',
#  'objective-c',
#  'objectteams',
#  'ocaml',
#  'occam',
#  'om',
#  'onyx',
#  'openedge advanced business language',
#  'or',
#  'oracle',
#  'os',
#  'parallel c#',
#  'pascal',
#  'perl',
#  'php',
#  'pict',
#  'piet',
#  'pike',
#  'pixilang',
#  'pl/m',
#  'pl/sql',
#  'postgresql',
#  'postscript',
#  'powershell',
#  'prolog',
#  'python',
#  'qbasic',
#  'rabbitmq',
#  'raven',
#  'react',
#  'rest',
#  'rexx',
#  'ruby',
#  'rust',
#  'scala',
#  'scheme',
#  'scilab',
#  'security',
#  'sequential function chart',
#  'server',
#  'sh',
#  'simula',
#  'skills',
#  'smalltalk',
#  'soap',
#  'software',
#  'solid',
#  'spark',
#  'spclk',
#  'spring',
#  'sql',
#  'sql\nsql-92',
#  'sql-92',
#  'sr',
#  'staapl',
#  'strong',
#  'swift',
#  'tcl/tk',
#  'tcp/ip',
#  'tfs',
#  'to',
#  'transact-sql',
#  'typescript',
#  'ui',
#  'unix',
#  'vala',
#  'virtual machine',
#  'visual basic',
#  'visual dataflex',
#  'web',
#  'whitespace',
#  'windbg',
#  'windows',
#  'with',
#  'x++',
#  'x10',
#  'zonnon'}

# %% [markdown]
# ### Что из списка требуется по каждой вакансии?

# %%
results = []
for job in final_db:
    line = {x:0 for x in full_techs}
    text = cleanhtml(job[5])
    for tech in full_techs:
        if tech in text:
            line[tech] = 1
    results.append(line)

# %%
import pandas as pd

# %%
len([x[3] for x in final_db])
# Out:
# 1215

# %%
info_d = {
    'ids': [x[0] for x in final_db],
    'name': [x[1] for x in final_db],
    'city': [x[2] for x in final_db], 
    'employer': [x[3] for x in final_db],
    'publication date': [x[4] for x in final_db]
}

# %%
# лол, можно же как-то столбец добавлять а не вот это непонятно что
for tech in full_techs:
    line = [x[tech] for x in results]
    info_d.update({str(tech): line})

# %%
df = pd.DataFrame(info_d)

# %%
df.head()
# Out:
#         ids                                               name    city  \
# 0  29654783  Инженер удаленной технической поддержки рабочи...  Самара
# 1  29654641                               Frontend разработчик  Москва
# 2  29654639                             JavaScript разработчик  Москва
# 3  29654618                                    Ведущий инженер  Москва
# 4  29668611                   Главный инженер по сопровождению  Москва
#
#    employer          publication date
# 0  Сбербанк  2019-04-26T14:37:49+0300
# 1  Сбербанк  2019-01-15T10:15:40+0300
# 2  Сбербанк  2019-01-15T10:15:36+0300
# 3  Сбербанк  2019-01-15T10:15:10+0300
# 4  Сбербанк  2019-02-12T09:00:00+0300
