# %% [markdown]
# ### Что нужно сделать?
#     (+) переделать получение описаний с запроса к api на поиск по данной html-странице
#     (+) обработать все базы и выделить нужные вакансии, перенести в новую базу
#     (+) выделить из каждой вакансии список требований
#     (+) перенести сюда то, что скинул Саня
#
#     (-) сделать окончательную удобную! базу (id, работодатель, дата публикации, город, требования)
#     (-) попробовать сделать выделение одного требования через bs4
#     (-) проверить все на предмет неправильной работы (все этапы)
#     (-) ЗАПИХНУТЬ УЖЕ ВСЕ НАКОНЕЦ В SCIKIT.LEARN

# %% [markdown]
# ### Входные данные
#     > сделанная вручную база, в которой для каждой вакансии (из разных компаний) есть ее id и полный html-текст
#
#
#     БУДЕМ СЧИТАТЬ, ЧТО НИЧЕГО НЕ ПОТЕРЯЛИ НА ЭТАПЕ ОБРАБОТКИ ИСХОДНЫХ БАЗ

# %%
import sqlite3
import json
import request
from bs4 import BeautifulSoup

# %%
import re
import string
import collections

# %%
final = 'C:\\Users\\busya\\Desktop\\anaconda\\проекты\\курсовая\\final.db'

conn = sqlite3.connect(final)
cursor = conn.cursor()

cursor.execute('SELECT * from vacancy')
final_db = cursor.fetchall()
conn.close()

# %% [markdown]
# ### Небольшой предварительный анализ всех заголовков

# %% [markdown]
# #### Сбор всех заголовков

# %%
headers = []
headers_d = {} # для контроля качества
punct = '«»•∙' + string.punctuation 
table = str.maketrans({key: None for key in punct}) # таблица перевода знаков препинания в None-объект

for job in final_db:
    new_headers = [y for y in [x.text.translate(table).strip().lower() for x in BeautifulSoup(job[1]).findAll('strong')]
                   if len(y) >= 4]
    headers_d[job[0]] = new_headers
    headers += new_headers

# %%
headers[:5]
# Out:
# ['обязанности', 'требования', 'условия', 'требования', 'условия работы']

# %%
print(len(headers))      # неуникальных
print(len(set(headers))) # уникальных
# Out:
# 4810
# 779

# %%
# забыл, зачем делал (удаляет заголовки, в которых нет кириллического текста)

#for head in headers:
#    if set('abcdefghijklmnopqrstuvwxyz') & set(head) != set():
#        print(head)

# %% [markdown]
# #### Выделение нужных заголовков
#     ручная оценка заголовков, подборка ключевых слов, по которым будут отбираться нужные заголовки
#
#
#     БУДЕМ СЧИТАТЬ, ЧТО ВЗЯЛИ ВСЕ, ЧТО НУЖНО И НЕ ВЗЯЛИ ТО, ЧТО НЕ НУЖНО, НО ЭТО НЕ ТОЧНО))))))))0)

# %%
counter_d = sorted(collections.Counter(headers).items(), key = lambda x: x[1], reverse=True)
counter_d[:10]
# Out:
# [('требования', 569),
#  ('обязанности', 490),
#  ('мы предлагаем', 422),
#  ('условия', 331),
#  ('желательно', 153),
#  ('будет плюсом', 112),
#  ('для чего вы нам нужны', 101),
#  ('задачи', 92),
#  ('мы предлагаем кучу всего', 85),
#  ('что вам необходимо для этого', 82)]

# %%
keywords = ['требования', 'желательно', 'плюсом', 'необходимо', 'ожидаем', 'requirements', 'обязательно', 
            'приветствуется', 'плюсами', 'знание', 'опыт', 'ожидания', 'компетенции', 'приветствуются', 
            'backend', 'технологии', 'требуется', 'если', 'бонусы', 'ждём', 'важно', 'плюсы', 'плюс', 
            'навыки', 'будет', 'ищем', 'уровень', 'вас', 'дополнительно', 'желательны', 'техническое',
            'ждем', 'стек', 'ожиданем', 'умеете', 'приветствуем', 'навыки', 'нужно', 'стеке', 'потребуется', 
            'преимуществом', 'нужен', 'ожиданием', 'пригодится', 'expect', 'fullstack', 'качества', 
            'looking', 'хотелось', 'требовани', 'обязательн', 'must', 'skills', 'experience', 'мастхэв', 'required',
            'ходим', 'обязателен', 'тебя', 'преимущества', 'знаниеумения', 'пожелания', 'стэк', 'компетенция', 
            'желательные', 'преимущество', 'хотим', 'знания', 'желание', 'хотели', 'have', 'применяется', 'технологий',
            'видим', 'обязательные', 'разработки']

# %%
def check(word_list):
    global keywords
    return set(keywords) & set(word_list) != set()

# %%
for head in set(headers):
    word_list = head.split()
    if set(keywords) & set(word_list) != set():
        print(head)
# Out:
# мы ожидаем что вы имеете
# также будет огромным плюсом если у тебя есть
# стек технологий
# eщё желательно
# необходимые навыки
# чтобы быть успешным в этой роли потребуется
# что хотелось бы видеть в кандидате
# круто если вы так же
# проекты в которых будет задействован кандидат
# мы ожидаем
# очень хотим видеть у тебя
# плюсами будут навыки работы с
# желательно наличие опыта в
# бонусы
# желательно чтото из нижеперечисленного
# языки разработки
# ключевые требования
# мы ищем специалиста
# инструментальные требования
# профессиональные навыки и знания
# необходимые знания
# работая в данном проекте разработчик получит возможность использовать в своей работе самые передовые технологии и фреймоворки bigdata и стать одним из разработчиков такого фреймворка
# успешным кандидатам отобранным по резюме будет предложено тестовое задание
# личностные качества
# обязательно
# плюсом будут считаться
# если есть
# основные требования к кандидатам
# требования к кандидату
# в команду продукта polys  online voting мы ищем business development менеджера для развития на мировом рынке
# ищем qa инженера в команду тестирования
# mandatory skills
# мы ждем от кандидата
# навыки и знания
# вероятно вы нам подходите если
# технологии
# какие задачи вас ждут
# задачи которые тебя ожидают
# приветствуются
# мы ожидаем от кандидата наличие опыта и готовность
# дополнительные требования
# наши ожидания
# требования к навыкам
# обязательные требования
# ожидания от кандидата
# что необходимо делать
# убедительная просьба если у вас в резюме не указан ожидаемый уровень заработной платы  указать его в сопроводительном письме
# must have
# обязательные компетенции
# мы ищем сильного аналитика который вместе с нашей командой будет
# дополнительно
# круто если вы
# кого мы ждём
# знания и навыки
# какие компетенции мы ожидаем от вас
# что от вас требуется
# желательно знание
# приветствуются знания  опыт
# обязательн
# опыт
# также будет преимуществом
# необходимо знать
# если ты разработчик которому интересно развиваться в направлении big data и ml и если ты хочешь делать этот мир хотя бы немного безопаснее  откликайся на нашу вакансию
# дополнительные требования будет плюсом
# professional knowledge and skills
# нужно обязательно
# тем более будем рады если
# что вам для этого необходимо
# вот что мы предлагаем если ты будешь с нами
# стек
# другие требования
# будет преимуществом
# ты подходишь нам если ты
# а еще желательно
# мы ожиданием
# что вам необходимо для этого
# ждем
# personal skills
# что нужно делать
# мы ожидаем что ты
# для успешной работы необходимо
# опыт работы
# мы ожидаем от кандидата
# опыт работы одно из нижеперечисленного
# опыт управления проектами
# специализация в текстовом анализе и nlp обязательно
# мы используем следующие технологии
# кого мы ищем
# в нашу команду требуется аналитик
# нам нужно
# для начал работы с нами тебе необходимо
# преимуществом
# бонусы и скидки
# мы ждем что вы
# как плюс
# для тебя
# будет
# необходимые навыки и опыт
# приветствуется
# еще желательно
# плюсы
# крайне желательно
# spring hibernate gradle jms jaxws git jenkins uml junit знание основ рсубд
# компания сбербанк блок технологии приглашает разработчика
# other requirements
# требования к опыту
# знание специальных программ
# мы ожидаем от вас
# дополнительным плюсом было бы
# будет плюсом
# вакансия подойдёт если тебе важно качество выпускаемого продукта и ты стремишься к оптимизации работы и не забываешь про развитие в тестировании а также в курсе последних новинок и подходов
# what are we looking for
# что обязательно
# большим плюсом будут
# пожелания
# ожидания к кандидатам
# work experience
# “лаборатория касперского” ищет системного аналитика для работы в проекте департамента исследований и разработки
# профессиональные навыки
# что мы ждем от тебя
# требования к соискателям
# мы ищем того кто
# что для нас важно
# желательнобудет являться плюсом
# требовани
# качества кода
# наш идеальный кандидат
# хотим познакомится с тобой если ты
# технологический стек разработки
# что хотелось бы видеть в вашем опыте
# образование  высшее техническое образование
# ждем от тебя
# дополнительные плюсом будет
# будет плюсом если
# nice to have
# желаемый предыдущий опыт
# вам необходимо
# нужно уметь
# профессиональные знания и навыки
# мы ждем что вы умеетеобладаете
# если тебе интересно
# знаниеумения
# профессиональные компетенции
# наш технологический стек
# мы ждем тебя в нашу команду
# ы ждем тебя
# чем нужно будет заниматься
# мы ждём от тебя
# дополнительным плюсом будет один из пунктов
# fullstack
# в обмен на ваш опыт мы предлагаем
# приветствуется если у вас есть
# additional requirements
# что хотели бы видеть в кандидате
# основные качества успешного кандидата
# что требуется
# желательны
# что ждем от тебя
# требования к владению иностранными языками
# fullstack developer
# что мы ждем от кандидата
# навыки
# требования к кандидатам
# требования к опыту работы
# основные требования
# требования
# от тебя требуется
# мы ждем тебя в нашей команде если ты
# functional knowledge and skills
# от вас мы ожидаем
# плюсом будет если у вас есть
# большим плюсом будет
# что ходим увидеть в резюме кандидата
# что не нужно будет делать
# компетенция data scientist
# мы рассчитываем что вы умеете
# нужно будет
# особенно ждём людей которые идут с желанием не просто попробовать а прийти и изменить сделать хоть немного лучше чем уже есть ведь если не мы то — кто
# в обязанности будет входить
# что нужно будет делать
# на этой стажировке в зависимости от проекта тебе могут понадобиться такие знания как
# required
# очень важно
# чего ждем от кандидата
# качества
# мы будем рады с вами пообщаться если вы
# требования по приоритетам
# дополнительные преимущества для кандидата
# знание технологий
# технологий
# технические требования
# what we expect from you
# сбербанк объявляет набор специалистов которые хотят развиваться в направлении разработки но это не стандартная разработка на известных языках
# в нашу команду мы ищем
# важно
# требуемый опыт и знание технологий
# обязателен
# хорошо если вы
# ждем от вас
# “лаборатория касперского” ищет системного аналитика для работы в новом проекте департамента исследований и разработки
# в качестве системного аналитика инфраструктурных сервисов вам потребуется
# мы ждем от тебя
# ты подходишь нам если
# личные качества кандидата
# от вас мы ждем
# мы ожидаем у кандидата наличие следующих качеств
# что тебя ждет на проекте
# требуемые навыки и знания
# ожидаем от кандидата
# плюсом будут навыки
# желательно
# мы ищем
# мы будем рады если у вас есть
# что важно для нас
# вашим преимуществом будет
# что мы от вас ожидаем
# стэк
# для нас важно
# от тебя потребуется
# у тебя будет возможность
# уровень образования
# что мы ждем от наших кандидатов
# дополнительное преимущество
# тебя
# наши требования
# что вам для этого потребуется
# так же люсом будет знакомство с
# кого ждем
# техническое
# профиль успешного кандидата обязательно
# ждем тебя в команде профессионалов
# прочие важные качества
# дополнительные компетенции
# так же в плюсы
# россии  крупнейший российский банк с собственным центром разработки и внедрения программного обеспечения в блоке
# плюс к карме за каждый checkout
# крайне приветствуется
# что не обязательно для работы у нас
# кого мы видим хорошим кандидатом на эту вакансию
# knowledge skills and abilities
# мы ждем что у вас есть
# необходимый опыт
# что необходимо будет делать
# что требуется от вас
# и у тебя есть
# key requirements
# кто нужен нам
# какие задачи вас ожидают
# необходимые знания и навыки
# desired skills and experience
# технические компетенции кандидата
# крайне пригодится
# от кандидатов ждем
# используемые технологии
# плюсом будут
# в команду digital campaign operations ищем еще одного героя
# дополнительными плюсами будут
# приходи к нам если хочешь
# очень желательно
# твоими основными задачами будет
# требуемый опыт
# будет плюсом если вы
# опыт работы в каких компаниях предпочтителен предшествующий опыт длительность
# что тебе для этого потребуется
# мастхэв
# компетенции
# требования к знаниям
# требования к знаниям и умениям
# большим преимуществом для тебя будет
# сербский – обязательно
# дополнительно приветствуется
# технические компетенции
# английский язык не ниже уровня upperintermediate навыки общения в письменной форме лично и по телефону
# а также у вас есть опыт
# в работе применяется
# qualification requirements
# основной стек технологий и подходов
# мы ожиданем
# мы ожидаем что у вас есть
# необходимые навыки и технологии
# в твои обязанности будет входить
# личные качества
# существенный плюс
# must have soft skills
# тогда мы ждем тебя в нашу команду
# что хотим видеть в соискателях
# знания умения навыки
# опыт работы образование профессиональные навыки
# щё желательно
# для работы также потребуется знания мы готовы этому учить
# требования для
# bтехнические компетенции
# опыт разработки на c или c или java
# несомненными плюсами будут знания
# личностные характеристики общие навыки
# мы ждем тебя чтобы строить счастливое будущее вместе
# от вас нужно
# дополнительные навыки желательно
# мы ищем толкового и энергичного профессионала который поможет нам в
# дополнительным преимуществом будет являться
# требования обязательные
# плюсами будут
# чтобы быть успешным в данной роли необходимо
# уникальный проект и возможность стать частью очень сильной команды разработки
# дополнительно приветствуются
# что для этого необходимо
# мы приветствуем
# если ты
# будет здорово если вы
# плюсом будет
# наш текущий стек
# желательные
# что мы ожидаем от кандидатов
# мы будем рады если вы
# будет плюсом опыт работы с некоторыми из наших технологийинструментов
# желание
# компетенция python разработчик
# современный стек технологий и микросервисную архитектуру
# для этого необходимо
# дополнительным плюсом будет
# что будет делать стажер
# требуемый опыт работы
# идеальный кандидат
# дополнительными плюсами будет опыт работы с
# сейчас мы ищем нового героя в глобальную команду продуктового маркетинга b2b
# преимуществом будет
# мы ожидаем что вы
# желательно там также найти
# что надо будет делать
# requirements
# желательные знания
# общие требования
# в стеке технологий у нас последние версии
# требования к образованию и квалификации
# если ты хочешь
# современные технологии
# технологический стек
# от тебя ждем
# здорово если вы обладаете следующими профессиональными навыками
# будет большим плюсом
# плюсом будет опыт работы с
# обязательные навыки
# backend разработчика следующий
# обязательные
# основные технологии и инструменты
# обязательно u200b

# %% [markdown]
# #### Формирование словаря 'заголовок - содержание'
#     129/1215 вакансий не были обработаны должным образом, еще бог знает сколько требований нужно разделять вручную.

# %%
# удаление html-кода из текста
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, ' ', raw_html)
    return ' '.join(cleantext.split())

# %%
all_paragraphs = {}
errors = []
punct = '«•»∙' + string.punctuation
table = str.maketrans({key: None for key in punct})

for job in final_db:
    text = job[1]
    if '<strong>' in text:
        paragraphs = [x.split('</strong>') for x in text.split('<strong>') if '</strong>' in x]
        all_paragraphs[job[0]] = {x[0].translate(table).strip().lower(): x[1] for x in paragraphs}
    else:
        errors.append(job[0])

# %%
print(len(all_paragraphs))
print(len(set(errors)))
# Out:
# 1167
# 129

# %%
requirements = {}
requirements_l = []
for id_ in all_paragraphs: 
    for paragraph in all_paragraphs[id_]:
        word_list = paragraph.split()
        if set(word_list) & set(keywords) != set():              # а что если несколько заголовков подойдут?
            new_reqs = all_paragraphs[id_][paragraph].strip()
            if cleanhtml(new_reqs) != '':
                requirements[id_] = new_reqs
                requirements_l.append(new_reqs)
            else:
                errors.append(id_)

# %%
requirements_l[1]
# Out:
# '</p> <ul> <li>Опыт web разработки от 3 лет (HTML, HTML5, CSS, JavaScript, препроцессинг CSS)</li> <li>Опыт разработки на библиотеках и фреймворках (AngularJS, ReactJS)</li> <li>Активное использование инструментов контроля версий (Git, CVS)</li> <li>Умение работать с базами данных и языками запросов (SQL)</li> <li>Опыт работы с серверными технологиями (Node.js)</li> <li>Взаимодействие с бекендом (SOAP/REST)</li> </ul> <p> </p> <p>'

# %%
errors = errors + list(set(all_paragraphs.keys()).difference(set(requirements.keys()))) # добавил потерянные вакансии

# %% [markdown]
# #### а не 129 (??????)

# %%
len(set([x[0] for x in final_db]).difference(set(requirements.keys()))) # те вакансии, для которых не получен список требований
# Out:
# 116

# %% [markdown]
# #### Разделение на мысли (от Сани)
#     все равно берется куча требований, не имеющих отношения к тех. навыкам:
#      1. как будто какие-то рандомные заголовки
#      2. личные качества (soft skills)
#      3. какая-то хрень

# %%
work_list = []
for i in requirements_l:
    work_list.append(i.split('>'))

# %%
new_work_list = []
for i in work_list:
    ap_list = []
    for j in i:
        ap_list.append(j.split('<'))
    new_work_list.append(ap_list)

# %%
flatten_list = []
for i in new_work_list:
    for j in i:
        for k in j:
            flatten_list.append(k)

# %%
trash_list = ['ul', 'li', 'p', 'b', '/ul', '/li', 
              '/p', '/b', 'em','/em','div','/div',
              'br','/br', 'ol', '/ol', '/span', 'u', '/u',
             ' ', '', 'br/', 'span', ':', 'br /']

# %%
requirements_final = []
for i in flatten_list:
    if i not in trash_list:
        requirements_final.append(i)

# %%
requirements_final = [x.translate(table).strip().lower() for x in requirements_final]

# %%
requirements_final[:5]
# Out:
# ['законченное высшее образование по направлению информационные технологии возможно последний курс',
#  'желателен опыт работы в сфере ит',
#  'экспертное знание ms windows 7 и ms office 2010 и выше',
#  'опыт поддержки пк системного по в тч навыки удаленного администрирования пк',
#  'знание технического устройства пк и его аппаратных составляющих']

# %%
sorted(set(dict(collections.Counter(requirements_final)).items()), key=lambda x: x[1], reverse=True)
# Out:
# [('высшее техническое образование', 112),
#  ('технический английский', 73),
#  ('высшее образование', 58),
#  ('условия работы', 41),
#  ('умение работать в команде', 41),
#  ('технический английский – свободное чтение документации', 34),
#  ('интерес к исследовательской деятельности', 32),
#  ('желательно', 31),
#  ('знание классических алгоритмов и структур данных', 27),
#  ('опыт работы с git', 25),
#  ('будет плюсом', 24),
#  ('умение разбираться в чужом коде', 24),
#  ('опыт работы в соответствии с методологиями agile', 24),
#  ('ответственность исполнительность инициативность внимание к деталям', 20),
#  ('знание методологических подходов проектирования программного обеспечения',
#   19),
#  ('образование  высшее техническое образование предпочтительно в области ит',
#   19),
#  ('опыт разработки многопоточных приложений', 17),
#  ('умение самостоятельно и полностью доводить до конца поставленные задачи',
#   17),
#  ('знание python', 15),
#  ('знание методов обеспечения безопасности в современных ос', 15),
#  ('знание sql', 15),
#  ('знание алгоритмов и структур данных', 15),
#  ('', 14),
#  ('опыт работы с docker', 14),
#  ('грамотная устная и письменная речь', 13),
#  ('отличное знание cnet framework', 13),
#  ('понимание парадигм ооп на языке c', 13),
#  ('нацеленность на результат', 12),
#  ('обязательно', 12),
#  ('опыт разработки по для встраиваемых систем на базе linux', 12),
#  ('укладываться в согласованные и принятые вами сроки', 11),
#  ('находить предлагать и реализовывать наиболее оптимальные способы достижения требований',
#   11),
#  ('работать в agilescrum методологии в тесном взаимодействии с остальными членами команды',
#   11),
#  ('аналитический склад ума', 11),
#  ('программировать по заранее написанному кемто тз', 11),
#  ('работать в стол', 11),
#  ('технический английский язык', 11),
#  ('владение основами администрирования', 10),
#  ('большой плюс если есть опыт разработки высоконагруженных систем', 10),
#  ('опыт использования субд или nosql', 10),
#  ('знание и опыт коммерческой разработки на cc', 10),
#  ('английский язык на уровне понимания технической литературы', 10),
#  ('умение четко и ясно выражать мысли самостоятельность внимательность к деталям',
#   10),
#  ('знание технологий', 10),
#  ('наличие завершённых проектов в магазинах приложений', 10),
#  ('опыт применения posix api набора библиотек qt', 10),
#  ('понимание принципов тестирования по', 10),
#  ('опыт работы с системами контроля версий', 10),
#  ('знание архитектур современных микропроцессоров средств разработки для них',
#   10),
#  ('javascript', 9),
#  ('опыт разработки согласно принципам sdlc', 9),
#  ('проектировать и разрабатывать рабочие места арм для нескольких ролей – оператор супервизор администратор',
#   9),
#  ('опыт работы с tfs', 9),
#  ('проектировать создавать и оптимизировать взаимодействие с бд', 9),
#  ('хорошие коммуникативные навыки', 9),
#  ('знание стандартных моделей безопасности и особенностей их реализации в различных ос',
#   9),
#  ('опыт написания тестовых сценариев', 9),
#  ('знание английского языка на уровне чтения технической литературы', 9),
#  ('понимание принципов обеспечения безопасности в вебприложениях угрозы способы предотвращения',
#   9),
#  ('fluent english', 8),
#  ('знание теории тестирования', 8),
#  ('желание создавать лучшие в россии fintechпродукты', 8),
#  ('убежденность в важности тестов кодревью и командной работы', 8),
#  ('опыт решения задач интеграции с другими системами', 8),
#  ('умение как самостоятельно так и в команде полностью доводить до конца поставленные задачи',
#   8),
#  ('хорошие коммуникационные навыки', 8),
#  ('git', 8),
#  ('знание протокола http', 8),
#  ('опыт разработки приложений на kotlin', 8),
#  ('опыт работы с реляционными и документоориентированными субд', 8),
#  ('понимание архитектурных принципов построения итсистем', 8),
#  ('знание perl', 8),
#  ('свободное владение английским языком', 8),
#  ('хорошее знание c', 8),
#  ('высшее образование в области информационных технологий', 8),
#  ('опыт работы с базами данных средствами python знание sql', 8),
#  ('опыт работы с технологиями', 7),
#  ('умение писать тестируемый код', 7),
#  ('гибкий подход к работе с творческими людьми умение находить общий язык', 7),
#  ('приветствуется опыт в вендоре партнере или дистрибьюторе', 7),
#  ('практические навыки работы с os windows на уровне администратора', 7),
#  ('знание kotlin', 7),
#  ('apache kafka', 7),
#  ('опыт разработки многопоточныхасинхронных систем в net', 7),
#  ('знание sql на уровне написания простых запросов', 7),
#  ('опыт кроссбраузерной разработки', 7),
#  ('знания методологий разработки ооп принципов solid ioc паттернов проектирования рефакторинга и пр',
#   7),
#  ('знание и опыт коммерческой разработки на cc с применением posix api', 7),
#  ('опыт работы c ansible', 7),
#  ('знание основных алгоритмов и структур данных оценка сложности алгоритмов',
#   7),
#  ('знание uml', 7),
#  ('хорошие знания в области объектноориентированного программирования', 7),
#  ('опыт автоматизированного тестирования знание инструментов', 7),
#  ('знания ядра os windows', 7),
#  ('работать в 2х недельных scrum спринтах', 7),
#  ('английский на уровне достаточном для решения технических вопросов', 7),
#  ('опыт использования инструментов кросскомпиляции на основе gccllvm', 7),
#  ('уверенные знания ос на базе linux для разработки процессы файловые системы права доступа анализ проблем',
#   7),
#  ('образование  высшее техническое', 7),
#  ('mysql', 7),
#  ('способности к аналитической работе – на уровне анализа данных по продажам выделения закономерностей генерации выводов и выработки корректирующих мер',
#   7),
#  ('от 3 лет в канальных продажах в том числе в качестве менеджера среднего звена',
#   7),
#  ('опыт работы с вебсокетами', 6),
#  ('знание систем автоматизации сборки makefiles automake cmake', 6),
#  ('опыт использования rxjava rxandroid', 6),
#  ('понимание принципов material design и руководств построения ui', 6),
#  ('знание шаблонов проектирования', 6),
#  ('наличие врожденной любознательности и приобретенного скилла шустрых пальцев',
#   6),
#  ('опыт проведения нефункционального тестирования', 6),
#  ('знание основных технологий и протоколов передачи данных', 6),
#  ('сила духа и отвага ведь найденный вами баг может остановить релиз вся разработка возможно будет вас ненавидеть но пользователи будут вас обожать',
#   6),
#  ('опыт создания многопоточных приложений', 6),
#  ('наличие публикаций в google play', 6),
#  ('отличные коммуникативные навыки', 6),
#  ('навыки разработкиактуализации тестовых сценариев и планов тестирования', 6),
#  ('опыт разработки распределённых систем', 6),
#  ('писать авто и юнит тесты', 6),
#  ('умение оптимизировать производительность мобильных приложений', 6),
#  ('разговорный и письменный английский язык', 6),
#  ('понимание и использование принципов ооп', 6),
#  ('умение самостоятельно и эффективно разбираться со статьями и проектами на github',
#   6),
#  ('опыт работы с системой контроля версий git', 6),
#  ('понимание документов rfc с описанием сетевых протоколов', 6),
#  ('желателен опыт проведения аудитов информационной безопасности', 6),
#  ('понимание актуальных угроз информационной безопасности базовые знания о методах атак и уязвимостях желание обучаться и повышать компетенцию в области практической информационной безопасности',
#   6),
#  ('опыт организации автоматизированного тестирования знание инструментов', 6),
#  ('powershell', 6),
#  ('знание основ обеспечения безопасности ос субд приложений сетей', 6),
#  ('опыт создания клиентсерверных приложений', 6),
#  ('опыт использования скриптовых языков для автоматизации например powershell',
#   6),
#  ('опыт работы с базами данных', 6),
#  ('react js', 6),
#  ('знание c c контейнеров stl jni android ndk', 6),
#  ('уверенные знания сетевых технологий в рамках ccna', 6),
#  ('опыт разработки ui использование support library', 6),
#  ('умение писать unitтесты инструментальные unitтесты и uiтесты', 6),
#  ('опыт webразработки', 6),
#  ('опыт создания приложений с использованием mvp и unitтестов', 6),
#  ('понимание жизненного цикла процесса разработки по методологий agile и места тестирования в этом процессе',
#   6),
#  ('опыт разработки серверных приложений', 6),
#  ('опыт разработки приложений для android от двух лет', 6),
#  ('опыт настройки сборки модульных проектов android на базе gradle с использованием proguard',
#   6),
#  ('знание java android sdk базовые знания sql', 6),
#  ('опыт по поддержке', 6),
#  ('английский технический', 6),
#  ('знание общих принципов понимание целей и задач тестирования и его места в разработке по',
#   6),
#  ('корпоративная мобильная связь', 6),
#  ('опыт работы от 3х лет', 6),
#  ('понимание и опыт работы с системой контроля версий git', 6),
#  ('врач и массаж в офисе', 6),
#  ('опыт работы в сфере иб от одного года', 6),
#  ('базовые знания основных стандартов и регламентирующих документов в области иб стандарты iso pci dss и др',
#   6),
#  ('знание базовых принципов построения современных операционных систем', 6),
#  ('понимание работы паттернов проектирования mvc', 6),
#  ('как большой плюс владение одним из языков ruby java kotlin и опыт использования автотестов в работе',
#   6),
#  ('ответственность', 6),
#  ('важно понимать нам нужен джедай мобильного тестирования обучать навыкам и теории тестирования к сожалению сейчас мы не готовы',
#   6),
#  ('инициатива изобретательность искренний интерес к необычным задачам', 6),
#  ('знание принципов agile ci cd tdd', 6),
#  ('опыт работы с ms tfs git либо любой другой системой контроля версий и багтрекером',
#   6),
#  ('опыт технического руководства программными проектами не менее 5 лет', 6),
#  ('знание гайдлайнов и основных принципов material дизайна', 6),
#  ('знание android иили ios на уровне выше установки кэнди краш', 6),
#  ('внимательное отношение к чистоте и качеству кода следование стандартам', 6),
#  ('опыт работы в распределенной команде', 6),
#  ('знание принципов проведения анализа рисков желателен опыт в данной области',
#   6),
#  ('опыт проектирования и оптимизации баз данных ms sql server', 6),
#  ('опыт работы с любым тестовым фреймворком mstestnunit', 6),
#  ('знание основ функционирования протоколов стека tcpip', 6),
#  ('опыт создания микросервисов', 6),
#  ('знание принципов построения корпоративных сетей', 6),
#  ('умение работать с git', 6),
#  ('креативность хорошие коммуникативные навыки', 6),
#  ('умение самостоятельно и полностью доводить до конца поставленные задач', 6),
#  ('желание развиваться в профессиональном плане изучать новое и решать интересные задачи',
#   6),
#  ('понимание процессов гибкой разработки', 6),
#  ('знание ооп и паттернов проектирования', 6),
#  ('знания сетевых технологий сетей протоколов', 5),
#  ('внушительную программу релокации для кандидатов из других регионов', 5),
#  ('опыт разработки bashunix shellскриптов', 5),
#  ('опыт разработки по', 5),
#  ('опыт работы в unixподобном окружении', 5),
#  ('опыт работы с msmq  rabbitmq  servicebus и др технологии работы с очередями',
#   5),
#  ('понимание базовых принципов вебразработки протокол http htmlcssjs', 5),
#  ('опыт разработки кроссплатформенных приложений', 5),
#  ('уверенное знание java core android sdk supportpackage', 5),
#  ('php react', 5),
#  ('wcf', 5),
#  ('умение работать с системой контроля версий git  console ide web stash', 5),
#  ('опыт автоматизации в тестировании или автоматизации рутинных рабочих задач',
#   5),
#  ('дресскод обошел нас стороной к счастью', 5),
#  ('готовность к командной работе в структуре компании', 5),
#  ('уверенное понимание принципов ооп и знание основных паттернов проектирования',
#   5),
#  ('опыт программирования написания тестов на c mstest nunit или аналоги', 5),
#  ('хочет разбираться в работе драйверов планировщиков и сервисов', 5),
#  ('опыт функционального программирования', 5),
#  ('htmlcss', 5),
#  ('понимание цикла разработки по', 5),
#  ('опыт работы с windows azure table  blob storage  queue cloud services amp vms',
#   5),
#  ('образование обязательно', 5),
#  ('стандартные бонусы', 5),
#  ('immutablejs', 5),
#  ('преимуществом будет', 5),
#  ('любит писать точно и ёмко', 5),
#  ('phpшаблоны', 5),
#  ('понимание жизненного цикла разработки по', 5),
#  ('опыт написания кода согласно стандартам стиля airbnb для js jsx eslint psr14 для php pep9 для python',
#   5),
#  ('python 35', 5),
#  ('крутые тимбилдинги с выездами и корпоративные мероприятия с привлечением топхэдлайнеров',
#   5),
#  ('уверенный коммуникатор способный корректно взаимодействовать и влиять на собеседника любого уровня топменеджмент средний менеджмент линейный персонал как у партнёра так и внутри компании',
#   5),
#  ('знание принципов ooп', 5),
#  ('опыт работы с docker ci amp cd', 5),
#  ('momentjs', 5),
#  ('zend framework 25', 5),
#  ('позитивный опыт выстраивания взаимодействия между крупными контрагентами в тч с распределенной территориальной структурой наличие подтвержденных примеров из практики',
#   5),
#  ('опыт работы с бд oracle sqlite', 5),
#  ('понимание интеграции клиентского приложения в существующую систему', 5),
#  ('twitter bootstrap 3 reactbootstrap', 5),
#  ('понимание процессов управления проектами по разработке программных продуктов pmi agilescrum waterfall rup',
#   5),
#  ('владение технологией wcf', 5),
#  ('опыт кроссбраузерной верстки для современных браузеров никаких старых ie',
#   5),
#  ('желание учиться новому модернизировать действующие процессы и внедрять изменения на пользу команде',
#   5),
#  ('опыт работы с системами контроля версий git tfs', 5),
#  ('умение работать с требованиями', 5),
#  ('unittest', 5),
#  ('redux reactredux', 5),
#  ('reduxthunk', 5),
#  ('готов узнать много нового и оформить это знание в виде текста', 5),
#  ('soap', 5),
#  ('высшее техническое образование желательно в области ит', 5),
#  ('желательно опыт работы с антивирусным программным обеспечением', 5),
#  ('знание принципов и паттернов проектирования программных систем умение применять их на практике',
#   5),
#  ('опыт применения пакетов кроссплатформенных библиотек', 5),
#  ('грамотная речь', 5),
#  ('опыт тестированияразработки wcf сервисов soap rest', 5),
#  ('опыт работы в тестировании не менее 2 лет', 5),
#  ('опыт тестированияразработки облачных решений в ms azure aws', 5),
#  ('развитые навыки публичных выступлений и проведения тренингов', 5),
#  ('умение отстаивать свою точку зрения', 5),
#  ('английский язык разговорный и письменный на уровне достаточном для свободного чтения технической и научной литературы а также общения внутри команды и с зарубежными заказчиками',
#   5),
#  ('p alignleft', 5),
#  ('ability to work under heavy load and manage different tasks simultaneously',
#   5),
#  ('хорошие аналитические способности умение анализировать требования', 5),
#  ('fluent english and russian', 5),
#  ('опыт разработки серверных приложений java scala python', 5),
#  ('высокий уровень самостоятельности способность принимать решения и брать на себя ответственность',
#   5),
#  ('свободный английский', 5),
#  ('websocket', 5),
#  ('опыт написания масштабируемого кода', 5),
#  ('понимание методологий разработки по agile kanban', 5),
#  ('опыт разработки приложений использующих сетевое взаимодействие', 5),
#  ('docker', 5),
#  ('json rest api', 5),
#  ('суммарный опыт программирования от 3х лет', 5),
#  ('опыт работы с системами контроля исходного кода git и тп', 5),
#  ('опыт разработки под специализированные ос реального времени встраиваемые',
#   5),
#  ('опыт работы с ms tfs', 5),
#  ('умение адаптироваться и изучать технологии в сжатые сроки', 5),
#  ('опыт системной разработки под разные архитектуры процессоров', 5),
#  ('знание windows native api', 5),
#  ('опыт codereview контроль качества кода', 5),
#  ('компенсация питания в денежном эквиваленте', 5),
#  ('опыт проектирования баз данных', 5),
#  ('знание основных паттернов программирования', 5),
#  ('опыт frontend разработки не менее 3 лет', 5),
#  ('глубокие знания в одной или нескольких сферах it', 5),
#  ('навыки отладки программ с использованием windbg в тч по крэшдампам', 5),
#  ('желание осваивать новые для себя технологии', 5),
#  ('способность эффективно работать в команде', 5),
#  ('заработную плату выше рынка обсуждаемую по итогам интервью', 5),
#  ('python', 5),
#  ('знакомство с архитектурой микроядерных операционных систем', 5),
#  ('jquery', 5),
#  ('опыт работы системным администратором или инженером по тестированию', 5),
#  ('базовые знания python и bash', 5),
#  ('sql', 5),
#  ('ansi sql', 5),
#  ('знание ооп паттернов проектирования по', 5),
#  ('опыт написания unitтестов работы с моками python', 5),
#  ('хорошее знание принципов работы сетей', 5),
#  ('опыт работы с библиотекой react js', 5),
#  ('understanding of software development process and quality management', 5),
#  ('проведение кодревью', 5),
#  ('reactrouter', 5),
#  ('понимание внутреннего устройства oc windows и знание сетевых протоколов',
#   5),
#  ('asyncio', 5),
#  ('отличное знание javascript', 5),
#  ('php 7', 5),
#  ('опыт работы в области разработки и проектирования операционных систем', 5),
#  ('знание английского языка', 5),
#  ('знание языков программирования', 5),
#  ('опыт написания вебтестов с использованием selenium', 5),
#  ('хорошее понимание принципов разработки продукта', 5),
#  ('разработка на net c не менее трёх лет', 5),
#  ('английский – intermediate желательно', 5),
#  ('бесплатный тренажерный зал в офисе и др', 5),
#  ('опыт написания unitтестов', 5),
#  ('понимание в разработке пользовательского интерфейса', 5),
#  ('опыт асинхронного программирования python asyncio', 5),
#  ('внимательность к деталям', 5),
#  ('знание основных видов web атак xss csrf', 5),
#  ('disciplined and detailed approach highly resultsoriented', 5),
#  ('хорошее знание сетевых сервисов и протоколов', 5),
#  ('уверенное владение c', 5),
#  ('живой ум', 5),
#  ('дмс для вас и ваших детей включая стоматологию и страхование жизни', 5),
#  ('внимательность к деталям и пытливость ума', 4),
#  ('опыт проведения полного цикла аудита', 4),
#  ('should be able to work to specific measurable objectives with minimal direct supervision',
#   4),
#  ('английский язык на уровне чтения технической документации', 4),
#  ('составляли и поддерживали в актуальном состоянии тестовую документацию чеклисты тесткейсы тестпланы тестрепорты',
#   4),
#  ('experience of working in a global role is highly desired', 4),
#  ('опыт работы с серверами на базе windows и unix', 4),
#  ('знание алгоритмов структур данных', 4),
#  ('умение и желание драйвить процессы конструктивно решать возникающие проблемы  вопросы',
#   4),
#  ('умеете анализировать информацию и хотите развиваться в сфере тестирования',
#   4),
#  ('знание ос microsoft windows на уровне системного администратора устройство сети osi базовые знания по виртуализации',
#   4),
#  ('знание ssis ssrs', 4),
#  ('excellent presentation skills with publicspeaking background', 4),
#  ('разговорный английский язык', 4),
#  ('уверенные знания linux', 4),
#  ('salesforce salesservice cloud experience', 4),
#  ('perfect communication skills presentation experience', 4),
#  ('знание javascript умение ориентироваться в стандартах понимание механизмов наследования es3 es5 es6',
#   4),
#  ('знание почтовых систем sendmail postfix exim qmail cgp samba squid', 4),
#  ('a minimum of 5 years’ in productweb leadership is essential for the role',
#   4),
#  ('опыт участия в переговорах и презентациях для itсотрудников itдиректоров коммерческих сотрудников',
#   4),
#  ('опыт работы с react и redux', 4),
#  ('умение самостоятельно доводить до конца поставленные задачи', 4),
#  ('проектирование структуры бд', 4),
#  ('английский язык на уровне достаточном для свободного чтения технической и научной литературы',
#   4),
#  ('опыт работы техническим писателемтестировщикомразработчиком от 2 лет', 4),
#  ('опыт создания проектов с помощью фреймворка django', 4),
#  ('опыт разработки rest api и wcfсервисов', 4),
#  ('знание sql опыт с nosql как плюс', 4),
#  ('salesforce best practices', 4),
#  ('знание английского языка умение читать документацию', 4),
#  ('excellent understanding of ecommerce platforms and it technology is vital',
#   4),
#  ('уверенное знание ос windows', 4),
#  ('продакшн опыт разработки приложений на scala', 4),
#  ('знание основ программирования', 4),
#  ('опыт работы с elasticsearchsolr', 4),
#  ('коммуникабельность и умение переключаться между задачами', 4),
#  ('spring 3', 4),
#  ('also a plus is expertise in presales or system analyst roles', 4),
#  ('желание разрабатывать spaприложения на angular научим если не было опыта',
#   4),
#  ('хорошее знание python', 4),
#  ('знание скриптовых языков javascriptpowershell', 4),
#  ('готовность быстро осваивать новые технологии и получать недостающие знания',
#   4),
#  ('постоянное повышение заработной платы при улучшении качества выполняемой работы и увеличении самостоятельности профессиональный рост',
#   4),
#  ('системное мышление аккуратность и усидчивость', 4),
#  ('понимание принципов rest чем отличается от rpc', 4),
#  ('опыт работы c jiraconfluence', 4),
#  ('большое желание читать исходный код на c', 4),
#  ('более года опыта работы в области автоматизации тестирования предпочтительно на мобильных устройствах',
#   4),
#  ('понимание работы распределённых бд', 4),
#  ('автоматизация процессов teamcity openstack docker octopus deploy atlassian tools slack bots',
#   4),
#  ('опыт работы в области разработки и проектирования встраиваемых решений', 4),
#  ('знаете ос семейства windows на уровне продвинутого пользователя', 4),
#  ('опыт работы с os linuxunix', 4),
#  ('базовые знания и понимание принципов работы основных сетевых протоколов tcpip http etc',
#   4),
#  ('базовые знания сетевых технологий сетей протоколов файловых систем и устройства os',
#   4),
#  ('опыт профессиональной командной разработки проектов на python от одного года',
#   4),
#  ('опыт android разработки от 1 года javakotlin', 4),
#  ('знание типовой архитектуры и особенностей информационных систем крупных государственных и коммерческих компаний',
#   4),
#  ('хорошее знание nosql баз данных предпочтительно clickhouse cassandra elasticsearch',
#   4),
#  ('опыт работы c системами виртуализации vmware esx  hyperv', 4),
#  ('опыт настройки и администрирования клиентсерверных приложений банкклиентов почтовых серверов и интернетшлюзов',
#   4),
#  ('умение объяснять устно и письменно', 4),
#  ('работа с большими объёмами терабайты данных', 4),
#  ('опыт построения высоконагруженных систем', 4),
#  ('знание jsфреймворков reactredux backbone jquery', 4),
#  ('опыт многопоточного программирования', 4),
#  ('желание работать над решением нетривиальных задач', 4),
#  ('опыт профилирования приложений', 4),
#  ('умение работать с регулярными выражениями будет плюсом', 4),
#  ('умение работать с фреймворками flask celery redis rabbitmq и тд', 4),
#  ('английский язык работа с требованиями переписка', 4),
#  ('базовые знания sql', 4),
#  ('умение анализировать ситуацию предлагать эффективные нестандартные идеи и решения',
#   4),
#  ('опыт разработки на net c от 5 лет', 4),
#  ('владение основными инструментами тестирования на проникновение', 4),
#  ('свободное владение одним из следующих языков  ruby java или kotlin', 4),
#  ('опыт работы с системами контроля версий git', 4),
#  ('модель osi принципы работы основных протоколов', 4),
#  ('опыт автоматизации тестирования или любой другой разработки на python и желание развиваться в этом направлении',
#   4),
#  ('опыт проектирования oltpolap хранилищ', 4),
#  ('frontend angular javascripttypescript webpack lessscss rxjs protractor jest',
#   4),
#  ('понимание процесса разработки и тестирования', 4),
#  ('3 year in software development andor it security industry', 4),
#  ('hive hdfs scala', 4),
#  ('опыт spaразработки angular 2 rxjs', 4),
#  ('знание и опыт работы с', 4),
#  ('желание вникать в бизнесконтекст понимать задачи и проблемы пользователей и стремиться делать понастоящему полезные продукты за которые не стыдно',
#   4),
#  ('участие в профессиональных тренингах itмероприятиях', 4),
#  ('backend net 46xnet core aspnet signalr ef akkanet rabbitmq', 4),
#  ('оказывать консультации коллегам по вашей области экспертизы', 4),
#  ('знание c и net', 4),
#  ('работа в ца сбербанк', 4),
#  ('kernel windows debugging windbg', 4),
#  ('опыт программирования на plsql от 1 года', 4),
#  ('базовые знания pythoncjava или других языков программирования', 4),
#  ('знание linux', 4),
#  ('ориентирование в современном стеке webразработки постоянная работа над собой анализ существующих и новых инструментов и их внедрение для оптимизации решений',
#   4),
#  ('автоматизацию работы посредством скриптов', 4),
#  ('понимание таких критериев качества как тестируемость расширяемость и безопасность',
#   4),
#  ('опыт работы с git tfs', 4),
#  ('знание основных паттернов разработки по', 4),
#  ('знание', 4),
#  ('ability to work with both qualitative and quantitative datasets implement successful web strategies',
#   4),
#  ('понимание принципов работы сетей', 4),
#  ('умение декомпозировать задачи и предлагать архитектурные решения', 4),
#  ('знание lua', 4),
#  ('знание ms exchange ibm lotus domino kerio control connect и подобных продуктов',
#   4),
#  ('software version control git or other', 4),
#  ('службу каталогов active directory и групповые политики', 4),
#  ('владение html и css в тч html5 и css3 приветствуется опыт работы с api для работы с csscелекторами jquery queryselector api',
#   4),
#  ('понимание математических принципов на которых основаны методы работы с нейросетями',
#   4),
#  ('знание методологий разработки по теории тестирования', 4),
#  ('опыт работы в виртуальных средах vmware vsphereworkstation или чтото другое',
#   4),
#  ('умение самостоятельно доводить до конца поставленные задачи и добиваться результата',
#   4),
#  ('отличное знание sql', 4),
#  ('знание linux ubuntu на уровне опытного пользователя', 4),
#  ('знание react', 4),
#  ('typescript', 4),
#  ('опыт работы тестировщиком или системным администратором от 1 года', 4),
#  ('знание различных баз данных и умение писать sqlзапросы', 4),
#  ('желание проявлять инициативу в поисках путей развития проектов как со стороны архитектуры и развития внутренних процессов разработки так и со стороны product management',
#   4),
#  ('практики гибкой разработки перекрёстное codereview короткие итерации частые релизы философия непрерывного совершенствования',
#   4),
#  ('скилы dba приветствуются', 4),
#  ('опыт использования c111417', 4),
#  ('понимание процесса разработки по', 4),
#  ('опыт работы с контейнерами docker', 4),
#  ('знание операционных систем unixlinux на уровне продвинутого пользователя',
#   4),
#  ('опыт работы с jenkins', 4),
#  ('желание развиваться в сфере информационной безопасности', 4),
#  ('опыт работы в agile', 4),
#  ('spark либо похожие движки распределённых бд', 4),
#  ('понимание сетевых технологий и протоколов уверенное понимание модели osi особенностей архитектуры файловых систем принципов интеграции автоматизированных систем принципов построения высоконагруженныхвысокодоступных систем',
#   4),
#  ('ssis', 4),
#  ('опыт разработки embedded – приложений для архитектур arm и x86', 4),
#  ('понимание принципов работы http websockets', 4),
#  ('оптимизация запросов и индексов', 4),
#  ('навыки верстки на html5  css3 bootstrap', 4),
#  ('наличие высшего образования', 4),
#  ('знание ecmascript 5 и выше', 4),
#  ('опыт разработки на языках сс', 4),
#  ('обрабатывать бизнестребования на вход требования могут поступать в любом формате – от идеи продукта до детального сценария ваша задача – проанализировать обозначенную потребность и превратить её в согласованную со staсkeholder’ами спецификацию понятную команде разработки',
#   4),
#  ('знание stl boost winapi', 4),
#  ('тяга к новым знаниям', 4),
#  ('уверенное владение python 3x 2x', 4),
#  ('опыт разработки webприложений с применением стека aspnet', 4),
#  ('знание ос linuxunixmacos на уровне продвинутого пользователя', 4),
#  ('опыт нагрузочного тестирования', 4),
#  ('любовь всё упорядочивать', 4),
#  ('знакомство с принципами оптимизации кода как на уровне алгоритмов так и на уровне cpu в тч учитывая аспекты многопоточного режима работы',
#   4),
#  ('высшее техническое образование хорошая методологическая база', 4),
#  ('опыт программирования на любом языке', 4),
#  ('опыт проведения code review', 4),
#  ('microsoft exchange', 4),
#  ('понимание принципов и терминологии itilcobit', 4),
#  ('понимание принципов ооп знание паттернов проектирования принципов solid',
#   4),
#  ('опыт ручного и автоматизированного тестирования знание инструментов', 4),
#  ('знание паттернов проектирования и архитектуры', 4),
#  ('инициативность и умение внятно корректно обосновать логичность и правильность выбранного решения',
#   4),
#  ('опыт разработки фронтальных систем высокой нагрузки', 4),
#  ('опыт использования скриптовых языков', 4),
#  ('выполнять исследовательские задачи исследовать сторонние решения распространённые подходы и использовать всю доступную информацию для того чтобы предложить наиболее оптимальный подход к закрытию потребностей обозначенных в бизнестребованиях',
#   4),
#  ('knowledge of salesforce basics – security model sharing model workflow flow',
#   4),
#  ('опыт работы с любой системой контроля версий', 4),
#  ('знание основных методологий разработки программного обеспечения', 4),
#  ('умение кроссбраузерно респонсивно верстать положительное отношение к вёрстке обязательно',
#   4),
#  ('хорошее знание теории тестирования виды типы', 4),
#  ('базовые знания сетевых технологий принципы построения сетей базовые протоколы передачи данных средства диагностики',
#   4),
#  ('основы администрирование ms sql', 4),
#  ('знание assembler x86 на уровне написания больших проектов', 4),
#  ('a natural born leader with a strong commercial acumen', 4),
#  ('хорошее знание реляционных баз данных предпочтительно postgresql', 4),
#  ('умение пользоваться xcode и instruments', 4),
#  ('опыт работы в области написания промышленного кода от 15 лет', 4),
#  ('certification authority', 4),
#  ('опыт работы в продуктовой технической поддержке от 3х лет понимание принципов работы продуктовой технической поддержки',
#   4),
#  ('быть внимательным и аккуратным идея упущенная в ходе обсуждения или ошибка в тексте требования может стоить команде нескольких дней разработки поэтому мы ожидаем что вы внимательны к мелочам аккуратны и пунктуальны',
#   4),
#  ('уверенное знание javascript уверенное владение инструментами сборки webpack',
#   4),
#  ('proven trackrecord of process development implementation and improvement',
#   4),
#  ('в нашей реальности руководитель проекта всегда в той или иной степени системный аналитик плюсом будет умение видеть важное и формулировать требования понятные как команде так и заказчику',
#   4),
#  ('опыт разработки систем с высокими гарантиями по информационной безопасности',
#   4),
#  ('опыт работы с инструментами анализирующими трафик wireshark tcpdump и пр',
#   4),
#  ('у нас нет дресскода', 4),
#  ('знание гибких методологий разработки', 4),
#  ('опыт командной разработки', 4),
#  ('tsql', 4),
#  ('хорошее знание cc', 4),
#  ('владение python либо готовность разбираться', 4),
#  ('capable of working with seniorlevel teams to define web roadmaps and product portfolios',
#   4),
#  ('умение составлять простые запросы sql', 4),
#  ('хранение данных oracledb mongodb', 4),
#  ('технический бэкграунд', 4),
#  ('опыт работы в роли системного аналитика в проектах разработки программных продуктов или информационных систем от 2 лет',
#   4),
#  ('experience in ecommerce and marketing websites essential', 4),
#  ('интерес к устройству операционных систем', 4),
#  ('хорошие знания ccassembler', 4),
#  ('уникальные масштабные проекты работа в приоритетном направлении участие в российских и международных профессиональных мероприятиях корпоративное обучение',
#   4),
#  ('cassandra', 4),
#  ('понимаете принцип работы серверных ролей', 4),
#  ('понимание проектного подхода', 4),
#  ('понятие о принципах разработки по ооп паттернах проектирования', 4),
#  ('a proven track record of successfully creating designing and delivering new ecommerceweb products to the market',
#   4),
#  ('базовые знания сетевых протоколов', 4),
#  ('опыт работы с логами и крэшдампами', 4),
#  ('верифицировать корректность документации и тестовых сценариев по вашим требованиям',
#   4),
#  ('знание windows на уровне продвинутого пользователя', 4),
#  ('опыт разработки архитектур нейронных сетей', 4),
#  ('опыт работы c ms visual studio tfs ida performance analyzer', 4),
#  ('языки python и c на высоком уровне продемонстрированном в конкретных проектах',
#   4),
#  ('понимание принципов ооп', 4),
#  ('написание хранимых процедур', 4),
#  ('completed degree bs ba msc ma phd in a relevant field', 4),
#  ('имеете больше одного года опыта тестирования не только отдельных модулей по api ui и тд но и продукта в целом',
#   4),
#  ('коммуникабельность целеустремленность и умение аргументированно доказывать свою точку зрения',
#   4),
#  ('выполнять исследовательские задачи и представлять отчёты по результатам исследований',
#   4),
#  ('знание jquery', 4),
#  ('понимание особенностей работы высоконагруженных отказоустойчивых и распределенных сервисов',
#   4),
#  ('опыт работы с microsoft azure', 4),
#  ('умение разбираться в чужом коде писать чистый и понятный код для других разработчиков опыт написания автотестов',
#   4),
#  ('опыт руководства от 3х лет', 4),
#  ('опыт создания одностраничных вебприложений', 4),
#  ('опыт профессиональной командной разработки проектов на python от 1 года',
#   4),
#  ('опыт работы с net веб стеком', 4),
#  ('владение инструментами ollydbg hiew ida', 4),
#  ('опыт программирования на javascript от 1 года', 4),
#  ('знание технологий контейнеризации и оркестрирования docker kubernetes ansible',
#   4),
#  ('опыт работы над автоматизацией тестирования', 4),
#  ('powerbi', 4),
#  ('previous experience devising strategic plans and budgets combined with an increased knowledge of the ux',
#   4),
#  ('data base developer ms sql 2016 или другие реляционные бд', 4),
#  ('умение следовать поставленным задачам с высокой степенью самостоятельности',
#   4),
#  ('английский не ниже intermediate', 4),
#  ('знание bash стандартных консольных nix приложений и какоголибо скриптового языка предпочтительно python',
#   4),
#  ('good communication skills', 4),
#  ('сетевые сервисы dhcp dns ntp', 4),
#  ('приветствуется хорошая математическая подготовка', 4),
#  ('solid understanding of system architecture and system design sfdccrm and forcecom',
#   4),
#  ('previous experience working within an agile development environment whilst also developing customerfacing websites',
#   4),
#  ('опыт проведения функционального модульного интеграционного тестирования',
#   4),
#  ('разновидности и особенности raid массивов', 4),
#  ('хорошее знание sql и умение оптимизировать запросы', 4),
#  ('опыт управления негативной обратной связью от пользователей', 4),
#  ('опыт работы в agileкоманде', 4),
#  ('знакомство со стандартами iso и опыт прохождения внешних аудитов', 4),
#  ('опыт работы с c', 4),
#  ('опыт компонентноориентированной разработки', 4),
#  ('опыт работы с vmware esxi', 4),
#  ('опыт работы с hibernate', 4),
#  ('знание c', 4),
#  ('знания современных антивирусных технологий и особенностей работы антивирусного по ведущих разработчиков антивирусных программ',
#   4),
#  ('знание os семейства linux на уровне опытного пользователя или администратора',
#   4),
#  ('знание архитектуры windows dos структуры ne и peфайлов', 4),
#  ('опыт работы с системами безопасности', 4),
#  ('умение работать в команде увлеченность желание работать над решением нетривиальных задач',
#   4),
#  ('ability to influence executive and seniorlevel leaders regarding product vision roadmaps and priorities',
#   4),
#  ('знание технологий appium cucumber jenkins stf allur', 4),
#  ('опыт написания и актуализации автотестов согласно правилам оформления', 4),
#  ('restsoap web services integration working experience', 4),
#  ('знание ос linux на уровне опытного пользователя', 4),
#  ('опыт работы с visual studio tfs git', 4),
#  ('experience of overseeing endtoend ux amp design processes for developing websites with strong emphasis on the role of content',
#   4),
#  ('знаете и понимаете процессы тестирования и разработки программного обеспечения',
#   4),
#  ('уверенное знание языка c и net framework', 4),
#  ('опыт работы в аналогичной должности – от двух лет', 4),
#  ('ssrs ssas', 4),
#  ('опыт написания скриптов для unixlike систем', 4),
#  ('логирование мониторинг метрики elasticsearch kibana grafana prometheus splunk и serilog',
#   4),
#  ('отличное знание c не менее 3 лет опыта коммерческой разработки', 4),
#  ('опыт тестирования desktop приложений для windows', 4),
#  ('опыт тестирования webсервисов http rest api', 4),
#  ('web development skills htmlcssjavascript', 4),
#  ('умение анализировать и формализовать требования к информационной системе',
#   4),
#  ('опыт работы с многопоточностью', 4),
#  ('опыт разработки клиентсерверных приложений', 4),
#  ('понимание методов и сценариев организации целевых атак', 3),
#  ('знание принципов и технологий построения распределенных систем', 3),
#  ('стремление развиваться изучать новые технологии выяснять как это работает под капотом делать людям удобно и красиво писать понятный и безопасный код который удобно поддерживать',
#   3),
#  ('знание сетевых протоколов и протоколов авторизации различных систем', 3),
#  ('знание современного рынка оборудования и компьютерных комплектующих', 3),
#  ('успешный опыт управления продуктовым напрвлением не менее 3х лет', 3),
#  ('знание системы управления версиями у нас git', 3),
#  ('знание и опыт применения принципов', 3),
#  ('умение слушать мнения членов команды', 3),
#  ('знания в области информационной безопасности', 3),
#  ('опыт работы с системами распределенного вычисления mapreduce', 3),
#  ('навыки проведения нефункциональных видов тестирования', 3),
#  ('опыт настройки систем мониторинга вычислительных ресурсов', 3),
#  ('навыки работы с требованиями составленияактуализации тестовых сценариев и планов тестирования',
#   3),
#  ('опыт работы с одной или нескольких библиотек для построения моделей tensorflow pytorch',
#   3),
#  ('опыт работы с ansible', 3),
#  ('быть центром экспертизы по вашим требованиям и продуктам в зоне ответственности',
#   3),
#  ('английский на уровне не ниже intermediate', 3),
#  ('знание инфраструктуры разработки git jira confluence', 3),
#  ('опыт работы в поддержке пользователей', 3),
#  ('уверенное знание систем автоматизации сборки makefiles automake cmake', 3),
#  ('понимание базовых принципов маркетинга умение выявлять и формулировать потребности пользователей',
#   3),
#  ('aspnet mvc', 3),
#  ('умение прототипировать', 3),
#  ('умение работать по описанным процедурам', 3),
#  ('планирования проекта', 3),
#  ('аккуратность грамотность склонность к простым и изящным решениям', 3),
#  ('опыт автоматизированного тестирования от модульного до интеграционного', 3),
#  ('vast experience in crossfunctional coordination of marketing projects', 3),
#  ('знание git', 3),
#  ('знание скриптовых языков программирования – perlphppython или др', 3),
#  ('autofacunity', 3),
#  ('понимание процессов поддержки и выстраивания уровней обслуживания', 3),
#  ('умение проводить переговоры убеждать договариваться', 3),
#  ('x81опыт руководства иткомандой или подразделением', 3),
#  ('опыт разработки приложений для macos или ios', 3),
#  ('умение писать понятный код и разбираться в чужом', 3),
#  ('навыки работы с заказчиками управления ожиданиями', 3),
#  ('знание систем управления конфигурацией chef ansible etc', 3),
#  ('опыт использования принципов event sourcing cqrs и ddd', 3),
#  ('· высшее образование', 3),
#  ('понимание основных принципов работы протоколов tcpip', 3),
#  ('опыт работы с ngrx', 3),
#  ('опыт работы с субд oracle', 3),
#  ('любой дополнительно как преимущество', 3),
#  ('опыт разработки spa с использованием react angular vue или тп желание разрабатывать на react',
#   3),
#  ('взаимодействовать с менеджерами продукта экспертами в области безопасности командой разработки и представителями смежных команд для выработки технических решений и документирования достигнутых договоренностей',
#   3),
#  ('опыт работы с reactnative', 3),
#  ('владение c', 3),
#  ('практический опыт настройки маршрутизаторов и управляемых коммутаторов хотя бы одного из cisco extreme mellanox',
#   3),
#  ('опыт работы с большими объемами данных', 3),
#  ('rxjs', 3),
#  ('понимание архитектурных принципов построения мобильных приложений', 3),
#  ('опыт сбора и формализации требований написания технических заданий', 3),
#  ('практический опыт работы с корпоративными решениями лаборатории касперского наличие сертификатов',
#   3),
#  ('готовность выполнять как рутинные так и нестандартные задачи', 3),
#  ('опыт работы с ms team foundation server visual studio test manager', 3),
#  ('strong experience in visualforce lightning development', 3),
#  ('представление о cmake', 3),
#  ('умение быстро осваивать новый материал', 3),
#  ('опыт написания отладочного тестирующего кода', 3),
#  ('наличие собственных open source проектов', 3),
#  ('опыт использования стандартов posix', 3),
#  ('знание стандартов в области защиты информации', 3),
#  ('высшее образование техническое', 3),
#  ('умение быстро находить причину и локализовать неисправность', 3),
#  ('знание одного из скриптовых языков программирования python perl ruby etc',
#   3),
#  ('желание развиваться и решать сложные задачи', 3),
#  ('ability to analyze business results and make conclusions', 3),
#  ('понимание функций менеджмента', 3),
#  ('опыт работы с багтрекинговыми системами', 3),
#  ('опыт коммерческой разработки продуктов более 5 лет', 3),
#  ('знание нотаций моделирования процессов например в среде aris bpmn', 3),
#  ('навыки создания анимаций интерфейса', 3),
#  ('javascripttypescriptangular 2htmlcss', 3),
#  ('знание powershell и понимание его отличий от других способов администрирования и разработки',
#   3),
#  ('знакомство с nonwindows системами', 3),
#  ('опыт кроссплатформенной разработки', 3),
#  ('знание современных стандартов языка', 3),
#  ('опыт работы в команде', 3),
#  ('опыт разработки пми и эксплуатационных документов', 3),
#  ('умение разрабатывать прототипы ui с помощью например axure pixate invision protoio и тд',
#   3),
#  ('ms office advanced user', 3),
#  ('опыт работы от года системным администратором или специалистом корпоративной службы технической поддержки',
#   3),
#  ('опыт работы в проектах связанных с интернетом вещей или системами промышленной автоматизации',
#   3),
#  ('опыт релиза моделей в продакшн', 3),
#  ('опыт программирования на с от 2 лет', 3),
#  ('отличная математическая подготовка знание теории вероятностей математической статистики',
#   3),
#  ('понимание того как net управляет памятью', 3),
#  ('опыт разработки технических спецификаций к программным продуктам хорошее знание uml',
#   3),
#  ('опыт тестирования по от 2х лет', 3),
#  ('способность к самообучению', 3),
#  ('опыт участия в проектах с активным использованием машинного обучения', 3),
#  ('опыт разработки серверных приложений на aspnet core', 3),
#  ('опыт работы в команде планирование задач и определение их трудоёмкости', 3),
#  ('умение доводить задачи до результата', 3),
#  ('опыт администрирования windows server', 3),
#  ('понимание методологии itsm', 3),
#  ('понимание принципов построения нагруженных вебприложений', 3),
#  ('умение проводить эксперименты и делать ab тестирование', 3),
#  ('net 40', 3),
#  ('выступления на международных конференциях и опубликованные исследования уязвимости',
#   3),
#  ('опыт работы с технологиями глубокого обучения и обучения с подкреплением',
#   3),
#  ('опыт разработки технических спецификаций на отдельные компоненты по', 3),
#  ('активно участвовать в формировании бизнестребований к новым версиям продукта  обсуждать концепцию собирать информацию о проблемах от заинтересованных лиц выявлять пользовательские потребности исследовать решения конкурентов',
#   3),
#  ('understanding of it andor telecom business is preferred', 3),
#  ('плюсом будет знание scssless и jquery', 3),
#  ('опыт использования индексов elastica sphinx', 3),
#  ('умение разбираться и работать с чужим кодом', 3),
#  ('опыт работы с системами виртуализации', 3),
#  ('управления качеством проекта', 3),
#  ('знание и опыт применения методик анализа защищенности ptes mitre attampck',
#   3),
#  ('навыки ведения деловой переписки на русском и английском языках', 3),
#  ('опыт работы с reactredux и разработки universalisomorphic приложений', 3),
#  ('strong experience in agile software development methodology', 3),
#  ('умение эффективно работать с entityframework 6 или core', 3),
#  ('знание скриптовых языков программирования powershell python', 3),
#  ('nservicebus или других messagingсистем', 3),
#  ('высшее образование желательно по специальности управление качеством бизнесинформатика менеджмент',
#   3),
#  ('опыт профессиональной командной разработки проектов на python от 2 лет', 3),
#  ('умение работать в командной строке unix', 3),
#  ('управления коммуникациями проекта', 3),
#  ('формирование и проверка продуктовых гипотез', 3),
#  ('опыт работы со spring core security integration aop etc', 3),
#  ('уметь выстраивать эффективные коммуникации общение составляет значительную часть работы любого аналитика эффективность этого общения отразится как в сроках так и в качестве аналитических артефактов',
#   3),
#  ('навыки планирования своего времени', 3),
#  ('умение работать в коллективе', 3),
#  ('экспертное знание принципов реляционных бд опыт проектирования и оптимизации бд',
#   3),
#  ('понимание проблем совместимости с разными браузерами в тч мобильными', 3),
#  ('опыт разработки многопоточных приложений на базе net', 3),
#  ('английский на уровне чтения технической документации', 3),
#  ('умение быстро разбираться в чужом коде оптимизировать и рефакторить как свой так и чужой код',
#   3),
#  ('cистема премирования дмс корпоративный университет льготные условия кредитования современный офис спортзал',
#   3),
#  ('аккуратность внимательность исполнительность коммуникабельность', 3),
#  ('публичные статьи по анализу защищенности различных систем', 3),
#  ('опыт работы инженером службы технической поддержки специалистом системного интегратора или системным администратором не менее 2 лет',
#   3),
#  ('экспертное знание html html5 sasslesscss', 3),
#  ('напишите сопроводительное письмо чем вас заинтересовала данная вакансия почему мы должны выбрать именно вас',
#   3),
#  ('умение писать и читать sql запросы', 3),
#  ('аккуратность', 3),
#  ('знание тематики безопасности gdpr персональные данные шифрование уязвимости',
#   3),
#  ('знание стандартных алгоритмов и структур данных', 3),
#  ('опыт тестирования rest api', 3),
#  ('общее представление о сетевых технологиях сети протоколы модель osi', 3),
#  ('знание жизненного цикла разработки по и распределения ролей в проектной команде',
#   3),
#  ('чёткое понимание цикла разработки по ведение разработки от бизнестребований до внедрения работа с репозиториями несколькими контурами',
#   3),
#  ('опыт администрирования рабочих станций', 3),
#  ('опыт проектирования и разработки высоконагруженных распределённых и отказоустойчивых систем',
#   3),
#  ('умение декомпозировать задачи и оценивать возможные варианты реализации',
#   3),
#  ('опыт работы с базами данных postgresql sas greenplum ос unixlinux', 3),
#  ('опыт работы с webstack typescript npmyarn webpack или его альтернативами знание одного или нескольких современных uiфреймворков в тч spfx react vue angular и др',
#   3),
#  ('знакомство с процессами организации сопровождения и развития ит решений на базе методологии itil',
#   3),
#  ('наличие навыков по диагностике неисправностей сети передачи данных', 3),
#  ('опыт разработки спецификаций технических требований к программным продуктам',
#   3),
#  ('обязательно знание и опыт работы со средами виртуализации vmware hyperv',
#   3),
#  ('не менее 1 года работы в должности системного администратора в компании с распределенной инфраструктурой',
#   3),
#  ('технический бекграунд в прошлом работа на позиции технического лида ведущего программиста или тестировщика специфика проектов требует погружения в технические детали и хорошего понимания того как все работает под капотом',
#   3),
#  ('опыт обслуживания компьютерной техники', 3),
#  ('опыт разработки высоконагруженных систем', 3),
#  ('навыки эффективного проведения совещаний', 3),
#  ('опыт работы с машинным обучением по данным многомерных временных рядов', 3),
#  ('знание основ антивирусной безопасности', 3),
#  ('mq', 3),
#  ('практический опыт настройки и работы с почтовыми службами web службами маршрутизацией',
#   3),
#  ('от 1 года', 3),
#  ('понимание процессов continuous integrationcontinuous delivery опыт работы с teamcity или jenkins',
#   3),
#  ('опыт автоматизированного тестирования по с использованием python pytest selenium docker tox',
#   3),
#  ('знание ad на уровне созданиеизменение уз', 3),
#  ('опыт установки и настройки стандартных офисных пакетов антивирусных приложений',
#   3),
#  ('опыт разработки по с использованием cc', 3),
#  ('английский – уровень достаточный для ведения переписки по техническим вопросам',
#   3),
#  ('знание почтовых систем', 3),
#  ('готовность к работе в режиме многозадачности', 3),
#  ('умение работать в режиме многозадачности и верно расставлять приоритеты',
#   3),
# ...
#  ('знание sketch figma photoshop illustrator', 3),
#  ('знание linuxwindows систем на уровне опытного пользователя  администратора',
#   3),
#  ('идеальная грамотность', 3),
#  ('умение декомпозировать задачи', 3),
#  ('понимание основ сетевого взаимодействия впо с их операторами', 3),
#  ('умение докопаться до сути', 3),
#  ('навыки разбора и анализа крэшдампов windbg vs', 3),
#  ('понимание принципов oop как работают паттерны mvc mvvm', 3),
#  ('опыт коммерческой разработки от 5 лет', 3),
#  ('умение работать с дизайн системой', 3),
#  ('опыт в тестировании api', 3),
#  ('понимание возможностей и проблем аутентификации через adfs', 3),
#  ('умение и желание объяснять сложные вещи простым языком', 3),
#  ('представление о проектировании сервисноориентированных систем', 3),
#  ('знакомство с team foundation server', 3),
#  ('понимание принципов построения операционных систем', 3),
#  ('уверенные навыки системного анализа в сложных проектах', 3),
#  ('html  js  css', 3),
#  ('наличие сертификатов ciscomicrosoftisc² прочих подтверждающих необходимую квалификацию',
#   3),
#  ('fluent english is a must', 3),
#  ('опыт работы c ms visual studio tfs preforce ida prefast performance analyzer',
#   3),
#  ('знания и опыт работы в высокоспециализированных областях будет плюсом телекоммуникационные сети промышленные системы цифровая обработка сигналов',
#   3),
#  ('hibernate', 3),
#  ('возможность организации гибкого графика работы', 3),
#  ('понимание принципов проектирования пользовательских сценариев и интерфейсов',
#   3),
#  ('представление о go', 3),
#  ('понимание и умение использовать шаблоны проектирования solid dry microservices',
#   3),
#  ('опыт разработки или опыт автоматизации тестирования сетевых приложений', 3),
#  ('навыки удаленного устранения проблем и неполадок по телефону и средствами удаленной поддержки',
#   3),
#  ('опыт разработки net core aspnet core и понимание архитектуры микросервисов',
#   3),
#  ('опыт настройки и поддержки любого сервера непрерывной интеграции', 3),
#  ('умение выявлять и формулировать потребности пользователей и быть представителем пользователя внутри компании',
#   3),
#  ('знание систем оркестрации ansible', 3),
#  ('знание продуктов в линейках ведущих мировых производителях программного обеспечения в области иб',
#   3),
#  ('хорошие навыки reverse engineering приложений под windows уверенное владение соответствующими инструментами такими как ida pro и windbg',
#   3),
#  ('опыт работы с siemсистемами', 3),
#  ('опыт разработки на языке java от 3 лет хорошие знания стека collections multithreading jmm jvm internal',
#   3),
#  ('опыт разработки сложных вебприложений', 3),
#  ('indepth understanding of theories and practices in branding digital marketing communication campaigns planning and production sponsorship and marketing projects',
#   3),
#  ('опыт проектного или функционального управления  доп преимущество', 3),
#  ('способность творчески мыслить генерировать идеи', 3),
#  ('опыт взаимодействия с системами контроля версий', 3),
#  ('опыт работы с nlp задачами знание классических методов  опыт применения нейронных сетей в nlp',
#   3),
#  ('управления рисками проекта', 3),
#  ('опыт подготовки и использования инструментов кросскомпиляции на основе gccllvm',
#   3),
#  ('опыт написания тесткейсов', 3),
#  ('опыт работы с unitтестами', 3),
#  ('tfs', 3),
#  ('опыт использования c ccli windbg', 3),
#  ('навыки управления проектами внедрения ибитсистем иили оказания услуг', 3),
#  ('знание golang или желание его освоить', 3),
#  ('experience with or in internationalglobal companies', 3),
#  ('опыт разработки на c aspnet и webstack от 3 лет понимание проблем производительности и способов их решения',
#   3),
#  ('понимание архитектуры распределённыхвысоконагруженных облачных систем', 3),
#  ('знание основных угроз иб актуальных для крупных и средних информационных систем',
#   3),
#  ('навыки продвижения брендапродуктауслуги', 3),
#  ('навыки работы с продуктами microsoft office word excel outlook', 3),
#  ('опыт автоматизированного тестирования по или вебсервисов', 3),
#  ('strong experience in salesforce apex', 3),
#  ('опыт написания sql запросов понимание принципов организации баз данных', 3),
#  ('msmq  rabbitmq  servicebus и др технологии работы с очередями', 3),
#  ('сильные лидерские и коммуникационные навыки', 3),
#  ('понимание основных принципов работы active directory exchange server', 3),
#  ('возможность изучать английский с высококлассными преподавателями на территории компании',
#   3),
#  ('опыт работы от 3 лет', 3),
#  ('пребывание в аспирантуре в сильной научной группе', 3),
#  ('навыки подготовки и представления отчетности о ходе и результатах работ',
#   3),
#  ('опыт настройки и администрирования windowsсетей 100 пользователей', 3),
#  ('strong experience in cicd using salesforce', 3),
#  ('аккуратность ответственность въедливость', 3),
#  ('опыт работы с linux умение выполнять деплой и администрирование проектов команды',
#   3),
#  ('высшее образование в области информационных технологий  иб', 3),
#  ('completed degree ma or phd in marketingeconomics field', 3),
#  ('знакомство с архитектурой ос windows и устройством приложений под эту ос',
#   3),
#  ('умение работать с keyvalue storage redis memcache и реляционными бд postgresql в приоритете понимание принципов работы индексирования',
#   3),
#  ('многопоточное и асинхронное программирование asyncawait примитивы синхронизации часть 5 из рихтера',
#   3),
#  ('опыт написания модульных тестов', 3),
#  ('умение писать юнит тесты', 3),
#  ('опыт работы с nintex workflow и forms', 3),
#  ('опыт использования git', 3),
#  ('знание wds sccm основ tcpiip будет хорошим плюсом', 3),
#  ('опыт работы с корпоративными продуктами лаборатории касперского', 3),
#  ('мы ожидаем что ты', 3),
#  ('aspnet mvcwebapiodata', 3),
#  ('опыт администрирования и оптимизации работы систем хранения данных', 3),
#  ('опыт администрирования windowslinux инфраструктур', 3),
#  ('опыт использования swift для разработки приложений', 3),
#  ('опыт поддержки приложений net является преимуществом', 3),
#  ('базовые навыки администрирования linuxunix систем', 3),
#  ('следовать внутренним процессам лаборатория касперского по работе с системными требованиями',
#   3),
#  ('желание развиваться с продуктовом дизайне', 3),
#  ('умение пользоваться системами контроля версий', 3),
#  ('базовые навыки работы с системой управления проектами microsoft project',
#   3),
#  ('понимание и владение принципами ооп domain driven design', 3),
#  ('знание plsql', 3),
#  ('навыки программирования на одном из языков c c c python java', 3),
#  ('понимание принципов разработки безопасного по', 3),
#  ('понимание парадигм ооп на языке c и знание основных паттернов проектирования gof',
#   3),
#  ('умение работать с базами данных в первую очередь интересует postgress', 3),
#  ('опыт администрирования почтовых систем', 3),
#  ('опыт работы с jsфреймоврками например backbone angular react reflux', 3),
#  ('опыт в администрировании linux', 3),
#  ('опыт участия в проектах связанных с системами промышленной автоматизации',
#   3),
#  ('участие и призы в соревнованиях kaggle', 3),
#  ('опыт работы с linuxсистемами продвинутый пользователь', 3),
#  ('наличие сертификатов linux windows cisco', 3),
#  ('опыт встраивания luaмашины в проекты на с', 3),
#  ('windows azure table  blob storage  queue cloud services amp vms', 3),
#  ('знание используемых в корпоративной или промышленной среде систем и технологий',
#   3),
#  ('опыт работы с angular 4', 3),
#  ('понимание особенностей и сценариев работы в защищенной инфраструктуре', 3),
#  ('entity framework', 3),
#  ('практический опыт работы с гибридными серверами', 3),
#  ('навыки проектирования интерфейсов', 3),
#  ('хорошие коммуникативные навыки системное мышление аккуратность и усидчивость',
#   3),
#  ('создавать и развивать эффективные финансовые продукты о которых говорят которыми пользуются и на которые равняются',
#   3),
#  ('умение использовать git docker', 3),
#  ('понимание основ html css', 3),
#  ('знание скриптовых языков', 3),
#  ('широкий кругозор знание современных технологий и решений', 3),
#  ('знания в области технологий', 3),
#  ('опыт работы с xml', 3),
#  ('опыт разработки по макетам и брэндбуку совместно с дизайнером', 3),
#  ('общее понимание современной архитектуры контактных центров', 3),
#  ('project management experience is a plus', 3),
#  ('хорошее ориентирование в современном стеке javaтехнологий', 3),
#  ('знание windowsплатформ на уровне администратора windows 7810 windows server 200820122016',
#   3),
#  ('minimum 7 years of experience in marketing area', 3),
#  ('уникальные возможности для занятий спортом футбол бокс хоккей лыжи баскетбол волейбол велоспорт теннис бильярд стрельба плавание',
#   3),
#  ('английский – intermediate или выше', 3),
#  ('умение работать с windbg для решения проблем с производительностью', 3),
#  ('проведение глубинных качественных custdevисследований', 3),
#  ('знание инструментальных средств разработки под nix таких как lldb clang makefiles cmake',
#   3),
#  ('проактивность', 3),
#  ('опыт разработки по для встраиваемых систем', 3),
#  ('профильное высшее образование магистр или специалист ученая степень по техническим или физикоматематическим наукам будет значительным преимуществом',
#   3),
#  ('уровень английского языка intermediateupper intermediate', 3),
#  ('обязательность исполнительность нацеленность на результат умение работать самостоятельно',
#   3),
#  ('опыт ведения переписки по электронной почте на английском языке', 3),
#  ('знание основных принципов верстки и сайтостроения', 3),
#  ('наличие продакшнпроектов в области рекомендательных систем', 3),
#  ('умение написания и поддержки тестов юниты и функциональные тесты', 3),
#  ('знание javascript от es6', 3),
#  ('опыт прототипирования интерфейсов', 3),
#  ('понимание архитектуры sharepoint и механизмов взаимодействия с этой платформой хорошее знание функционала из коробки в тч возможностей поиска workflow 35',
#   3),
#  ('опыт проведения нагрузочного тестирования и тестирования производительности',
#   3),
#  ('опыт поддержки сложных интеграций между системами', 3),
#  ('отличные знания сcassembler', 3),
#  ('опыт разработки под azureaws', 3),
#  ('знакомство с marketo будет большим плюсом', 3),
#  ('понимание и применение принципов разработки безопасного по', 3),
#  ('net core', 3),
#  ('уметь быстро разобраться в актуальных статьях по nlp с arxiv', 3),
#  ('важно наличие портфолио', 3),
#  ('понимание стандартной объектной модели salesforcecom sales cloud', 3),
#  ('умение работать с технической информацией', 3),
#  ('знание typescript либо flow', 3),
#  ('опыт работы с системами bug tracking и управления проектами', 3),
#  ('коммуникабельность умение собирать и систематизировать требования пользователей а также излагать их структурировано для дальнейшей обработки',
#   3),
#  ('опыт работы с различным железом pc embedded', 3),
#  ('опыт работы с restсервисами', 3),
#  ('желание делать приложения для macos', 3),
#  ('знание docker и опыт работы с kubernetes', 3),
#  ('опыт webразработки aspnet mvcweb api angularjs css вёрстка', 3),
#  ('знание основных принципов построения сетей передачи данных', 3),
#  ('опыт работы с webpack уметь собрать проект с картинками и стилями скриптами',
#   3),
#  ('хорошее знание python и навык программирования на нем', 3),
#  ('формирование и согласование бизнес требований', 3),
#  ('базовые знания языков программирования c c c и python', 3),
#  ('аналитические навыки и навыки решения проблем', 3),
#  ('опыт разработки коммерческих вебприложений на javascript  typescript от 3х лет',
#   3),
#  ('опыт работы в области практического анализа защищенности и тестирования на проникновение',
#   3),
#  ('опыт разработки на python', 3),
#  ('опыт работы с ms tfs git', 3),
#  ('взаимодействие с командами для достижения поставленных целей отслеживание возникающих проблем и предпринимать меры для их решения',
#   3),
#  ('опыт работы с серверами приложений настройка оптимизация', 3),
#  ('опыт работы по agile методологии', 3),
#  ('знания и практические навыки разработки безопасного по', 3),
#  ('хорошее понимание sql server проблем производительности и способов их диагностики и решения',
#   3),
#  ('понимание многопоточности', 3),
#  ('опыт публикации приложений в app store', 3),
#  ('опыт работы в компании которая разрабатывает программное обеспечение', 3),
#  ('опыт работы с программами удаленного администрирования', 3),
#  ('опыт участия в проектах с использованием машинного обучения', 3),
#  ('уметь настраивать sota алгоритмы под данные чтобы получить на них лучшие результаты',
#   3),
#  ('умение пользоваться системами ревью кода', 3),
#  ('хорошая обучаемость умение работать в команде клиентоориентированность', 3),
#  ('опыт работы в создании чатботов в особенности используя ранжирующие модели dssm и тд',
#   3),
#  ('базовые принципы сетей знание linux на уровне администратора', 3),
#  ('базовые знания сетевых технологий сетей протоколов', 3),
#  ('опыт тестирования', 3),
#  ('опыт работы с docker kubernetes ci amp cd', 3),
#  ('практический опыт установки и настройки систем виртуализации kvm hyperv',
#   3),
#  ('опыт подготовки технических спецификаций технической части коммерческих предложений для клиентов и партнеров',
#   3),
#  ('знание английского языка на уровне не ниже intermediate чтение документации и переписка',
#   3),
#  ('понимание проблем поддержки обновления версий миграции данных', 3),
#  ('навыки webразработки', 3),
#  ('практический опыт сборки сложных научных пакетов из исходных кодов их установка настройка оптимизация работы',
#   3),
#  ('знания методологий разработки ооп принципов solid паттернов проектирования и рефакторинга',
#   3),
#  ('приветствуется знание ip телефонии 1с ms антивирусное по', 3),
#  ('опыт проектной работы с применением систем контроля версий например git svn и пр и систем управления проектами например jira youtrack redmine и пр',
#   3),
#  ('готовность решать сложные проблемы в поддержке', 3),
#  ('уверенное владение c 35 лет', 3),
#  ('понимание устройства ос', 3),
#  ('visual studio понимание alm', 3),
#  ('высшее техническоематематическоеэкономическое образование', 3),
#  ('владение высокоуровневым языком программирования java иили scala', 3),
#  ('опыт работы с микросервисной архитектурой', 3),
#  ('experience in brand category management andor is preferred', 3),
#  ('проведение количественных пользовательских исследований', 3),
#  ('опыт разработки и отличное знание c c от 2х лет', 3),
#  ('способность ясно излагать мысли системное мышление аккуратность и усидчивость',
#   3),
#  ('успешный опыт создания и продвижения на рынок высокотехнологичных продуктовсервисов',
#   3),
#  ('опыт написания и поддержки автотестов на net либо скриптовых языках не менее 2х лет',
#   3),
#  ('ответственность за запуск продукта и стратегию выведения продукта на рынок',
#   3),
#  ('владение unix shell', 3),
#  ('навыки работы в agileкоманде scrum', 3),
#  ('опыт работы в продуктовой команде больше 2 лет', 3),
#  ('знание ос linux на уровне опытного пользователя программировать придется в основном под linux',
#   3),
#  ('желание монетизировать и запускать новые продукты', 3),
#  ('опыт разработки для sharepoint 20132016 от 2 лет знание возможностей вебсервисов csomjsom rest api',
#   3),
#  ('oracle plsql', 3),
#  ('опыт использования инструментов автоматизации ui тестирования', 3),
#  ('знание скриптовых языков javascript python', 3),
#  ('неполное высшее техническое образование', 3),
#  ('опыт работы в команде планирования задач и определения их трудоёмкости', 3),
#  ('дополнительным плюсом будет математическая подготовка приветствуется опыт в области математического моделирования машинного обучения data science поощряется наличие научных публикаций',
#   3),
#  ('знание систем виртуализации', 3),
#  ('знание и понимание принципов работы сетевых протоколов и служб dns email dhcp и тд',
#   3),
#  ('можно без опыта или от 1 года в сферах it или лингвистики', 3),
#  ('курсы повышения квалификации на ежегодной основе', 3),
#  ('практический опыт администрирования операционных систем семейства windows для серверов и рабочих станций опыт сборки и установки прикладных пакетов',
#   3),
#  ('знание react опыт работы с bootstrap ionic foundation и тд', 3),
#  ('знание стандартов iso серии 9000 20000 27000 методологий itil cobit babok lean',
#   3),
#  ('уверенные знания и опыт написания sql запросов ms sql понимание принципов организации баз данных',
#   3),
#  ...]

# %%
len([x for x in requirements_final if 'perl' in x])
# Out:
# 31
