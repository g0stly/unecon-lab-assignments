# %%
import requests
import json
import sqlite3
from bs4 import BeautifulSoup
import sqlite3

# %%
filtered_db = 'C:\\Users\\busya\\Desktop\\anaconda\\проекты\\курсовая\\final.db'

conn = sqlite3.connect(filtered_db)
cursor = conn.cursor()

cursor.execute('SELECT * from vacancy')
filtered = cursor.fetchall()
conn.close()

# %%
len(filtered)
# Out:
# 1215

# %%
main_list = []
for i in filtered:
    if "strong" in i[1]:
        texttest = i[1]
        teststrong = texttest.split('<strong>')
        cur_list = [j.split('</strong>') for j in teststrong if '</strong>' in j] 
        main_list.append(cur_list)

# %%
main_list[900]
# Out:
# [['Основные задачи:',
#   '</p> <ul> <li>Разработка продукта в Enterprise сегменте для защиты индустриальных объектов и предиктивной аналитки.</li> <li>Работа в составе слаженной и грамотной команды над крупным проектом</li> <li>Написание тестов</li> </ul> <p>'],
#  ['Требования:',
#   '</p> <ul> <li>Опыт разработки коммерческих веб-приложений на JavaScript / Typescript от 3-х лет</li> <li>Опыт работы с Angular 4+</li> <li>Навыки верстки на HTML5 / CSS3, Bootstrap</li> <li>Хорошие знания в области объектно-ориентированного программирования</li> <li>Ориентирование в современном стеке web-разработки. Постоянная работа над собой. Анализ существующих и новых инструментов и их внедрение для оптимизации решений</li> <li>Умение работать в коллективе.</li> </ul> <p>'],
#  ['Дополнительными плюсами будут:',
#   '</p> <ul> <li>Понимание и применение принципов разработки безопасного ПО</li> <li>Опыт работы с AWS/Azure</li> <li>Понимание и умение использовать шаблоны проектирования, SOLID, DRY, Microservices</li> <li>Опыт работы в UNIX-подобном окружении.</li> <li>Умение писать тестируемый код.</li> <li>Опыт работы с системами контроля версий: Git, TFS.</li> <li>Опыт разработки серверных приложений на ASP.NET Core</li> <li>Технический английский – свободное чтение документации. <p>'],
#  ['Мы предлагаем:',
#   '</p> </li> <li>Работу в команде крутейших экспертов - возможность профессионального роста: расширение технического кругозора, возможность поработать в тесной связке с командой системных программистов.</li> <li>Не предлагаем: серую з/п, дресс-код, скучные задачи, устаревшие технологии, унылых коллег</li> </ul></div>']]

# %%
keywords = ['требования', 'требуется', 'если', 'ждем', 'ждём', 'ожидаем', 'ищем', 'будет', 'компетенции', 'плюсом', 'желательно'
           'знание', 'стек', 'стэк', 'технологии', 'навыки', 'обязательно', 'от вас', 'опыт', 'ожидания', 'плюсами']

# %%
requir = []
for i in main_list:
    for j in i:
        for k in keywords:
            if k in j[0].lower():
                requir.append(j[1])
requir[901]
# Out:
# '</p> <ul> <li>Высшее техническое или лингвистическое образование (прикладная лингвистика)</li> <li>Английский язык на уровне уверенного Intermediate, владение ИТ терминологией</li> <li>Опыт работы с операционной системой MS Windows на уровне опытного пользователя</li> <li>Опыт работы в сфере IT (на позиции инженера по локализации, технического переводчика/редактора, инженера по тестированию)</li> <li>Знание принципов локализации и интернационализации программных продуктов</li> <li>Опыт работы с программами для автоматизированного перевода (CAT tools)</li> <li>Знание инструментов веб-разработки будет Вашим преимуществом (С# /Python / JavaScript)</li> <li>Знание инструментов для разработки нейронных сетей и компьютерного зрения (Tesseract/ OpenCV) будет плюсом</li> </ul> <p>'

# %%
work_list = []
for i in requir:
    work_list.append(i.split('>'))

# %%
new_work_list = []
for i in work_list:
    ap_list = []
    for j in i:
        ap_list.append(j.split('<'))
    new_work_list.append(ap_list)
new_work_list[0][0][1]
# Out:
# '/p'

# %%
flatten_list = []#А как какать? то есть хз как флеттен сделать
for i in new_work_list:
    for j in i:
        for k in j:
            flatten_list.append(k)
flatten_list
# Out:
# ['',
#  '/p',
#  ' ',
#  'p',
#  '• Законченное высшее образование по направлению Информационные технологии, возможно последний курс.',
#  '/p',
#  ' ',
#  'p',
#  '• Желателен опыт работы в сфере ИТ.',
#  '/p',
#  ' ',
#  'p',
#  '• Экспертное знание MS Windows 7 и MS Office 2010 и выше.',
#  '/p',
#  ' ',
#  'p',
#  '• Опыт поддержки ПК, системного ПО, в т.ч. навыки удаленного администрирования ПК.',
#  '/p',
#  ' ',
#  'p',
#  '• Знание технического устройства ПК и его аппаратных составляющих.',
#  '/p',
#  ' ',
#  'p',
#  '• Стрессоустойчивость, ответственность, коммуникабельность.',
#  '/p',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт web разработки от 3 лет (HTML, HTML5, CSS, JavaScript, препроцессинг CSS)',
#  '/li',
#  ' ',
#  'li',
#  'Опыт разработки на библиотеках и фреймворках (AngularJS, ReactJS)',
#  '/li',
#  ' ',
#  'li',
#  'Активное использование инструментов контроля версий (Git, CVS)',
#  '/li',
#  ' ',
#  'li',
#  'Умение работать с базами данных и языками запросов (SQL)',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с серверными технологиями (Node.js)',
#  '/li',
#  ' ',
#  'li',
#  'Взаимодействие с бекендом (SOAP/REST)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт web разработки от 3 лет (HTML, HTML5, CSS, JavaScript, препроцессинг CSS)',
#  '/li',
#  ' ',
#  'li',
#  'Опыт разработки на библиотеках и фреймворках (AngularJS, ReactJS)',
#  '/li',
#  ' ',
#  'li',
#  'Активное использование инструментов контроля версий (Git, CVS)',
#  '/li',
#  ' ',
#  'li',
#  'Умение работать с базами данных и языками запросов (SQL)',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с серверными технологиями (Node.js)',
#  '/li',
#  ' ',
#  'li',
#  'Взаимодействие с бекендом (SOAP/REST)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Высшее техническое образование (желательно в области ИТ);',
#  '/li',
#  ' ',
#  'li',
#  'Знание ITSM, ITIL;',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы в поддержке АС как 2-я линия сопровождения',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с Jira, Confluence;',
#  '/li',
#  ' ',
#  'li',
#  '(желательно) Опыт использования и построения отчётов в Grafana, Zabbix,',
#  '/li',
#  ' ',
#  'li',
#  '(желательно) Опыт использования технологий DevOps и версионного контроля (Jenkins, Bitbucket);',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с реляционными БД (Oracle, PostgreSQL) и NoSQL решениями',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с BigData решений на стеке технологий Cloudera Hadoop',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы с Apache Maven',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы по Agile методологии',
#  '/li',
#  ' ',
#  'li',
#  'Инициативность, коммуникабельность, конструктивность;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы (минимальный) 4 года',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы (функциональный) 3-5 лет',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Организация взаимодействия (средний уровень)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  'Согласовывает время, ресурсы, задачи сторон в небольшом проекте или процессе, учитывая их интересы и существующие процедуры Банка.',
#  '/p',
#  ' ',
#  'p',
#  'В случае возникновения сложных ситуаций предлагает варианты решения для согласования с руководством.',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Организация сервиса (средний уровень)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  'Делает выводы о потребностях клиентов на основании опыта и предлагает решения в рамках существующих процедур и практик Банка.',
#  '/p',
#  ' ',
#  'p',
#  'При возникновении нестандартных клиентских проблем предлагает решения для утверждения руководством.',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Анализ и моделирование данных (средний уровень)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  'Обладает базовой теоретической подготовкой в области ИТ. Знает характеристики систем анализа и моделирования данных. Может самостоятельно выбирать оптимальный вариант решения задач по разработке, доработке или сопровождению таких систем в рамках существующих процедур.',
#  '/p',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание процессов и стандартов',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание информационных систем',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Интерпретация и презентация данных',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Управление ИТ-услугами',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  'p',
#  '· Знание методологии ITSM и сервисного подхода;',
#  '/p',
#  '',
#  'p',
#  '· Опыт работы с платформой SAS на уровне администратора;',
#  '/p',
#  '',
#  'p',
#  '· Понимание типовых архитектур решений SAS;',
#  '/p',
#  '',
#  'p',
#  '· Знания продуктов SAS DI, LSF, SAS MC и языка программирования SAS BASE (SAS Macro);',
#  '/p',
#  '',
#  'p',
#  '· Знание SQL;',
#  '/p',
#  '',
#  'p',
#  '· Навыки и практический опыт написания документации для администраторов и пользователей, описания процессов и архитектуры;',
#  '/p',
#  '',
#  'p',
#  '· Навыки программирования и написания скриптов (bash/VBS/VBA/powershell/);',
#  '/p',
#  '',
#  'p',
#  '· Знание Linux;',
#  '/p',
#  '',
#  'p',
#  '· Личностные качества: активность, системное мышление, умение работать в команде и проактивно найти нужных людей и получить требуемую информацию;',
#  '/p',
#  '',
#  'p',
#  '· Знание английского языка, достаточное для чтения инструкций.',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'div',
#  '',
#  'p',
#  '',
#  '/p',
#  '',
#  'p',
#  '',
#  'b',
#  'Условия работы:',
#  '/b',
#  '',
#  '/p',
#  '',
#  'p',
#  '',
#  '',
#  '/u',
#  '',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  'Желательно, фул-стек (JAVA + UI). Если нет UI, то было бы хорошо, если есть желание развиваться в эту сторону.',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  'Для Java:',
#  'br/',
#  'Опыт работы с технологиями: Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit.',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  'Для UI:',
#  'br/',
#  'Знание JavaScript (es6/es7: классы, импорты декораторы, arrow-функции, генераторы, промисы)',
#  'br/',
#  'Экспертное знание HTML, HTML5, SASS/LESS/CSS',
#  'br/',
#  '• Опыт работы с js-фреймоврками (например, Backbone, Angular, React, Reflux).',
#  'br/',
#  '• Опыт работы с Webpack: уметь собрать проект с картинками и стилями, скриптами.',
#  'br/',
#  '• Опыт работы с REST-сервисами',
#  'br/',
#  '• Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  'br/',
#  '• Умение работать с Git Будет плюсом',
#  'br/',
#  '• Знание React Опыт работы с Bootstrap, Ionic, Foundation и т.д.',
#  'br/',
#  '• Умение разрабатывать прототипы UI с помощью, например, Axure, Pixate, Invision, Proto.io и т.д.',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  '',
#  'u',
#  '',
#  '',
#  '/p',
#  '',
#  '/div',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  '',
#  'ul',
#  '',
#  'li',
#  'Понимание принципов и технологий разработки пользовательских интерфейсов;',
#  '/li',
#  '',
#  'li',
#  'Системное мышление, способность видеть продукт частью системы;',
#  '/li',
#  '',
#  'li',
#  'Экспертиза в проектировании взаимодействия, визуальном дизайне, юзабилити;',
#  '/li',
#  '',
#  'li',
#  'Знание композиции, типографики;',
#  '/li',
#  '',
#  'li',
#  'создание прототипов высокой степени детализации;',
#  '/li',
#  '',
#  'li',
#  'Уверенное владение sketch, InVision;',
#  '/li',
#  '',
#  'li',
#  'Умение пользоваться Photoshop, Axure, Illustrator.',
#  '/li',
#  '',
#  '/ul',
#  '',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  'ul',
#  '',
#  'li',
#  'Доказанный опыт (портфолио) в дизайне информационных веб-приложений.',
#  '/li',
#  '',
#  '/ul',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'ul',
#  '',
#  'li',
#  'Опыт разработки на Java / Scala от 3 лет.',
#  '/li',
#  '',
#  'li',
#  'Знание Linux на уровне продвинутого пользователя.',
#  '/li',
#  '',
#  'li',
#  'Знание платформы Hadoop (HDFS, Spark, HBase, MapReduce, etc.).',
#  '/li',
#  '',
#  'li',
#  'Опыт работы с Git, Bitbucket.',
#  '/li',
#  '',
#  'li',
#  'Знание жизненного цикла разработки ПО.',
#  '/li',
#  '',
#  'li',
#  'Знание SQL.',
#  '/li',
#  '',
#  'li',
#  'Опыт работы с bugtracking системами и тестовой документацией.',
#  '/li',
#  '',
#  'li',
#  ' ',
#  '/li',
#  '',
#  '/ul',
#  '',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  'p',
#  ' ',
#  '/p',
#  '',
#  'ul',
#  '',
#  'li',
#  'Опыт работы с Jenkins или любым другим аналогичным инструментом.',
#  '/li',
#  '',
#  'li',
#  'Знание языков Python и/или Scala.',
#  '/li',
#  '',
#  'li',
#  'Умение работать по гибким методологиям разработки.',
#  '/li',
#  '',
#  'li',
#  'Знание современных инструментов devops (Jenkins).',
#  '/li',
#  '',
#  '/ul',
#  '',
#  'div',
#  '',
#  '/div',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы в сфере сопровождения/администрирования СУБД от 3х лет;',
#  '/li',
#  ' ',
#  'li',
#  'Опыт работы в области настройки мониторинга СУБД, объектов БД;',
#  '/li',
#  ' ',
#  'li',
#  'Знание стека протоколов TCP/IP;',
#  '/li',
#  ' ',
#  'li',
#  'Знание и понимание общих принципов работы реляционных СУБД;',
#  '/li',
#  ' ',
#  'li',
#  'Знание ОС Linux/AIX/Solaris на уровне продвинутого пользователя;',
#  '/li',
#  ' ',
#  'li',
#  'Понимание OLAP/OLTP технологий;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Разрабатывать, описывать и моделировать сложные схемы интеграционного взаимодействия',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Работать в 2х недельных SCRUM спринтах.',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт написания функциональных требований/бизнес-требований/технических спецификаций на разработку;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы на позиции системного аналитика/технолога в ИТ-компании или финансовой организации по направлению ДБО, либо разработке фронт-офисных решений, клиентских приложений от 3 лет;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Наличие высшего технического образования;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Понимание принципов continuous integration;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание и умение работы с пакетом MS Office, wiki-системой Confluence, трекинговыми системами (Jira, Redmine и т.д.);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Технический английский язык (свободное чтение и перевод специальной литературы);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание протоколов (REST, SOAP) и контейнеров данных (XML, JSON) для передачи информации между системами.',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание различных нотаций (UML, BPMN и т. д.);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт выполнения аналитических задач при разработке мобильных приложений под iOS, Android;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знания принципов разработки ПО, проектирования пользовательских интерфейсов, интеграции приложений;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы в Agile;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание основ сетевой инфраструктуры (балансировка, проксирование, порты и т.д.);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание основ информационной безопасности (сертификаты, VPN, TLS/SSL).',
#  '/li',
#  ' ',
#  '/ul',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание различных нотаций (UML, BPMN и т. д.);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт выполнения аналитических задач при разработке мобильных приложений под iOS, Android;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знания принципов разработки ПО, проектирования пользовательских интерфейсов, интеграции приложений;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт работы в Agile;',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание основ сетевой инфраструктуры (балансировка, проксирование, порты и т.д.);',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Знание основ информационной безопасности (сертификаты, VPN, TLS/SSL).',
#  '/li',
#  ' ',
#  '/ul',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'p',
#  '•опыт создания и внедрения сервисов по распознаванию речи и синтезу голоса;',
#  '/p',
#  ' ',
#  'p',
#  '•высшее образование в одной из областей - экономика, информационные технологии;',
#  '/p',
#  ' ',
#  'p',
#  '•опыт создания или развития технологических продуктов от 3х лет;',
#  '/p',
#  ' ',
#  'p',
#  '•опыт управления кросс-функциональными проектными командами;',
#  '/p',
#  ' ',
#  'p',
#  '•навыки внедрения ИТ-систем от стадии идеи до промышленной эксплуатации (знание проектной методологии, опыт ее практического применения, навыки ведения проектной документации);',
#  '/p',
#  ' ',
#  'p',
#  '•стратегическое мышление;',
#  '/p',
#  ' ',
#  'p',
#  '•отличные организаторские, коммуникационные и лидерские навыки;',
#  '/p',
#  ' ',
#  'p',
#  '•умение отстаивать свою точку зрения.',
#  '/p',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт коммерческой разработки в финансовой сфере от 5 лет, отличное понимание особенности разработки, внедрения и поддержки финансового ПО',
#  '/li',
#  ' ',
#  'li',
#  'Опыт управления командой разработки от 3 человек с использованием систем контроля версий, средств автоматизации сборки, управления требованиями и конфигурациями',
#  '/li',
#  ' ',
#  'li',
#  'Опыт интеграции разработанного ПО с другими системами',
#  '/li',
#  ' ',
#  'li',
#  'Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  '/li',
#  ' ',
#  'li',
#  'Умение работать по гибким методологиям (Scrum, kanban)',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Глубокое понимание Сore java 1.7+',
#  '/li',
#  ' ',
#  'li',
#  'Опыт разработки WEB-приложений на Java. Знание стека j2ee: jms, ejb, jax-ws, mbean, jndi',
#  '/li',
#  ' ',
#  'li',
#  'опыт работы с соответствующими серверами',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  'знания xml, sql, hibernate, quartz',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Умение проводить code-review',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Глубокое понимание Сore java 1.7+',
#  '/li',
#  ' ',
#  'li',
#  'Опыт разработки WEB-приложений на Java. Знание стека j2ee: jms, ejb, jax-ws, mbean, jndi',
#  '/li',
#  ' ',
#  'li',
#  'опыт работы с соответствующими серверами',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  'знания xml, sql, hibernate, quartz',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Умение проводить code-review',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт коммерческой разработки ПО под на IBM WebSphere MQ и IBM WebSphere Application Server.',
#  '/li',
#  ' ',
#  'li',
#  'Знание PL/SQL',
#  '/li',
#  ' ',
#  'li',
#  'Понимание принципов DevOps',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  ' ',
#  'ul',
#  ' ',
#  'li',
#  'Опыт коммерческой разработки ПО под на IBM WebSphere MQ и IBM WebSphere Application Server.',
#  '/li',
#  ' ',
#  'li',
#  'Знание PL/SQL',
#  '/li',
#  ' ',
#  'li',
#  'Понимание принципов DevOps',
#  '/li',
#  ' ',
#  '/ul',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  ' ',
#  '/p',
#  ' ',
#  'p',
#  '',
#  '',
#  '/p',
#  '',
#  '/div',
#  '',
#  '',
#  '/p',
#  ...]

# %%
tag_list = ['ul', 'li', 'p', 'b', '/ul', '/li', '/p', '/b', 'em','/em','div','/div','br','/br', 'ol', '/ol', '/span', 'u', '/u']

# %%
new_flatten_list = []
for i in flatten_list:#опять забыл как какать, почему то filter не сработал
    if i not in tag_list and i != "" and i != " ":
        new_flatten_list.append(i)

# %%
new_flatten_list
# Out:
# ['• Законченное высшее образование по направлению Информационные технологии, возможно последний курс.',
#  '• Желателен опыт работы в сфере ИТ.',
#  '• Экспертное знание MS Windows 7 и MS Office 2010 и выше.',
#  '• Опыт поддержки ПК, системного ПО, в т.ч. навыки удаленного администрирования ПК.',
#  '• Знание технического устройства ПК и его аппаратных составляющих.',
#  '• Стрессоустойчивость, ответственность, коммуникабельность.',
#  'Опыт web разработки от 3 лет (HTML, HTML5, CSS, JavaScript, препроцессинг CSS)',
#  'Опыт разработки на библиотеках и фреймворках (AngularJS, ReactJS)',
#  'Активное использование инструментов контроля версий (Git, CVS)',
#  'Умение работать с базами данных и языками запросов (SQL)',
#  'Опыт работы с серверными технологиями (Node.js)',
#  'Взаимодействие с бекендом (SOAP/REST)',
#  'Опыт web разработки от 3 лет (HTML, HTML5, CSS, JavaScript, препроцессинг CSS)',
#  'Опыт разработки на библиотеках и фреймворках (AngularJS, ReactJS)',
#  'Активное использование инструментов контроля версий (Git, CVS)',
#  'Умение работать с базами данных и языками запросов (SQL)',
#  'Опыт работы с серверными технологиями (Node.js)',
#  'Взаимодействие с бекендом (SOAP/REST)',
#  'Высшее техническое образование (желательно в области ИТ);',
#  'Знание ITSM, ITIL;',
#  'Опыт работы в поддержке АС как 2-я линия сопровождения',
#  'Опыт работы с Jira, Confluence;',
#  '(желательно) Опыт использования и построения отчётов в Grafana, Zabbix,',
#  '(желательно) Опыт использования технологий DevOps и версионного контроля (Jenkins, Bitbucket);',
#  'Опыт работы с реляционными БД (Oracle, PostgreSQL) и NoSQL решениями',
#  'Опыт работы с BigData решений на стеке технологий Cloudera Hadoop',
#  'Опыт работы с Apache Maven',
#  'Опыт работы по Agile методологии',
#  'Инициативность, коммуникабельность, конструктивность;',
#  'Опыт работы (минимальный) 4 года',
#  'Опыт работы (функциональный) 3-5 лет',
#  'Организация взаимодействия (средний уровень)',
#  'Согласовывает время, ресурсы, задачи сторон в небольшом проекте или процессе, учитывая их интересы и существующие процедуры Банка.',
#  'В случае возникновения сложных ситуаций предлагает варианты решения для согласования с руководством.',
#  'Организация сервиса (средний уровень)',
#  'Делает выводы о потребностях клиентов на основании опыта и предлагает решения в рамках существующих процедур и практик Банка.',
#  'При возникновении нестандартных клиентских проблем предлагает решения для утверждения руководством.',
#  'Анализ и моделирование данных (средний уровень)',
#  'Обладает базовой теоретической подготовкой в области ИТ. Знает характеристики систем анализа и моделирования данных. Может самостоятельно выбирать оптимальный вариант решения задач по разработке, доработке или сопровождению таких систем в рамках существующих процедур.',
#  'Знание процессов и стандартов',
#  'Знание информационных систем',
#  'Интерпретация и презентация данных',
#  'Управление ИТ-услугами',
#  '· Знание методологии ITSM и сервисного подхода;',
#  '· Опыт работы с платформой SAS на уровне администратора;',
#  '· Понимание типовых архитектур решений SAS;',
#  '· Знания продуктов SAS DI, LSF, SAS MC и языка программирования SAS BASE (SAS Macro);',
#  '· Знание SQL;',
#  '· Навыки и практический опыт написания документации для администраторов и пользователей, описания процессов и архитектуры;',
#  '· Навыки программирования и написания скриптов (bash/VBS/VBA/powershell/);',
#  '· Знание Linux;',
#  '· Личностные качества: активность, системное мышление, умение работать в команде и проактивно найти нужных людей и получить требуемую информацию;',
#  '· Знание английского языка, достаточное для чтения инструкций.',
#  'Условия работы:',
#  'Желательно, фул-стек (JAVA + UI). Если нет UI, то было бы хорошо, если есть желание развиваться в эту сторону.',
#  'Для Java:',
#  'br/',
#  'Опыт работы с технологиями: Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit.',
#  'Для UI:',
#  'br/',
#  'Знание JavaScript (es6/es7: классы, импорты декораторы, arrow-функции, генераторы, промисы)',
#  'br/',
#  'Экспертное знание HTML, HTML5, SASS/LESS/CSS',
#  'br/',
#  '• Опыт работы с js-фреймоврками (например, Backbone, Angular, React, Reflux).',
#  'br/',
#  '• Опыт работы с Webpack: уметь собрать проект с картинками и стилями, скриптами.',
#  'br/',
#  '• Опыт работы с REST-сервисами',
#  'br/',
#  '• Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  'br/',
#  '• Умение работать с Git Будет плюсом',
#  'br/',
#  '• Знание React Опыт работы с Bootstrap, Ionic, Foundation и т.д.',
#  'br/',
#  '• Умение разрабатывать прототипы UI с помощью, например, Axure, Pixate, Invision, Proto.io и т.д.',
#  'Понимание принципов и технологий разработки пользовательских интерфейсов;',
#  'Системное мышление, способность видеть продукт частью системы;',
#  'Экспертиза в проектировании взаимодействия, визуальном дизайне, юзабилити;',
#  'Знание композиции, типографики;',
#  'создание прототипов высокой степени детализации;',
#  'Уверенное владение sketch, InVision;',
#  'Умение пользоваться Photoshop, Axure, Illustrator.',
#  'Доказанный опыт (портфолио) в дизайне информационных веб-приложений.',
#  'Опыт разработки на Java / Scala от 3 лет.',
#  'Знание Linux на уровне продвинутого пользователя.',
#  'Знание платформы Hadoop (HDFS, Spark, HBase, MapReduce, etc.).',
#  'Опыт работы с Git, Bitbucket.',
#  'Знание жизненного цикла разработки ПО.',
#  'Знание SQL.',
#  'Опыт работы с bugtracking системами и тестовой документацией.',
#  'Опыт работы с Jenkins или любым другим аналогичным инструментом.',
#  'Знание языков Python и/или Scala.',
#  'Умение работать по гибким методологиям разработки.',
#  'Знание современных инструментов devops (Jenkins).',
#  'Опыт работы в сфере сопровождения/администрирования СУБД от 3х лет;',
#  'Опыт работы в области настройки мониторинга СУБД, объектов БД;',
#  'Знание стека протоколов TCP/IP;',
#  'Знание и понимание общих принципов работы реляционных СУБД;',
#  'Знание ОС Linux/AIX/Solaris на уровне продвинутого пользователя;',
#  'Понимание OLAP/OLTP технологий;',
#  'Разрабатывать, описывать и моделировать сложные схемы интеграционного взаимодействия',
#  'Работать в 2х недельных SCRUM спринтах.',
#  'Опыт написания функциональных требований/бизнес-требований/технических спецификаций на разработку;',
#  'Опыт работы на позиции системного аналитика/технолога в ИТ-компании или финансовой организации по направлению ДБО, либо разработке фронт-офисных решений, клиентских приложений от 3 лет;',
#  'Наличие высшего технического образования;',
#  'Понимание принципов continuous integration;',
#  'Знание и умение работы с пакетом MS Office, wiki-системой Confluence, трекинговыми системами (Jira, Redmine и т.д.);',
#  'Технический английский язык (свободное чтение и перевод специальной литературы);',
#  'Знание протоколов (REST, SOAP) и контейнеров данных (XML, JSON) для передачи информации между системами.',
#  'Знание различных нотаций (UML, BPMN и т. д.);',
#  'Опыт выполнения аналитических задач при разработке мобильных приложений под iOS, Android;',
#  'Знания принципов разработки ПО, проектирования пользовательских интерфейсов, интеграции приложений;',
#  'Опыт работы в Agile;',
#  'Знание основ сетевой инфраструктуры (балансировка, проксирование, порты и т.д.);',
#  'Знание основ информационной безопасности (сертификаты, VPN, TLS/SSL).',
#  'Знание различных нотаций (UML, BPMN и т. д.);',
#  'Опыт выполнения аналитических задач при разработке мобильных приложений под iOS, Android;',
#  'Знания принципов разработки ПО, проектирования пользовательских интерфейсов, интеграции приложений;',
#  'Опыт работы в Agile;',
#  'Знание основ сетевой инфраструктуры (балансировка, проксирование, порты и т.д.);',
#  'Знание основ информационной безопасности (сертификаты, VPN, TLS/SSL).',
#  '•опыт создания и внедрения сервисов по распознаванию речи и синтезу голоса;',
#  '•высшее образование в одной из областей - экономика, информационные технологии;',
#  '•опыт создания или развития технологических продуктов от 3х лет;',
#  '•опыт управления кросс-функциональными проектными командами;',
#  '•навыки внедрения ИТ-систем от стадии идеи до промышленной эксплуатации (знание проектной методологии, опыт ее практического применения, навыки ведения проектной документации);',
#  '•стратегическое мышление;',
#  '•отличные организаторские, коммуникационные и лидерские навыки;',
#  '•умение отстаивать свою точку зрения.',
#  'Опыт коммерческой разработки в финансовой сфере от 5 лет, отличное понимание особенности разработки, внедрения и поддержки финансового ПО',
#  'Опыт управления командой разработки от 3 человек с использованием систем контроля версий, средств автоматизации сборки, управления требованиями и конфигурациями',
#  'Опыт интеграции разработанного ПО с другими системами',
#  'Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  'Умение работать по гибким методологиям (Scrum, kanban)',
#  'Глубокое понимание Сore java 1.7+',
#  'Опыт разработки WEB-приложений на Java. Знание стека j2ee: jms, ejb, jax-ws, mbean, jndi',
#  'опыт работы с соответствующими серверами',
#  'знания xml, sql, hibernate, quartz',
#  'Умение проводить code-review',
#  'Глубокое понимание Сore java 1.7+',
#  'Опыт разработки WEB-приложений на Java. Знание стека j2ee: jms, ejb, jax-ws, mbean, jndi',
#  'опыт работы с соответствующими серверами',
#  'знания xml, sql, hibernate, quartz',
#  'Умение проводить code-review',
#  'Опыт коммерческой разработки ПО под на IBM WebSphere MQ и IBM WebSphere Application Server.',
#  'Знание PL/SQL',
#  'Понимание принципов DevOps',
#  'Опыт коммерческой разработки ПО под на IBM WebSphere MQ и IBM WebSphere Application Server.',
#  'Знание PL/SQL',
#  'Понимание принципов DevOps',
#  '· Высшее профильное образование;',
#  '· Опыт в автотестировании и практиках devops;',
#  '· Опыт работы с Java, Selenium, Cucumber, Allure',
#  '· Опыт выстраивания процессов автотестирования на масштабных проектах в банках или телеком-компаниях;',
#  '· Навыки эффективного управления проектными командами.',
#  'Разработчика АБС ЦФТ-Банк в команду развития кредитной подсистемы частных клиентов ПАО Сбербанк.',
#  'Опыт разработки АБС ЦФТ-Банк.',
#  'Знание языков программирования Java, Oracle PL/SQL.',
#  'Опыт проектирования и разработки высоконагруженных, распределённых и отказоустойчивых систем;',
#  'Экспертное знание принципов реляционных БД, опыт проектирования и оптимизации БД;',
#  'Опыт проектирования и разработки высоконагруженных, распределённых и отказоустойчивых систем;',
#  'Экспертное знание принципов реляционных БД, опыт проектирования и оптимизации БД;',
#  'От 1 года.',
#  '&gt;3 лет',
#  'Высшее техническое образование;',
#  'Опыт работы от 3 лет;',
#  'Опыт разработки в Navision версий от 3.7 и выше;',
#  'Опыт написания SQL-запросов и хранимых процедур;',
#  'Опыт разработки как по ТЗ, так и по Agile методологиям, без чётко поставленных задач;',
#  'Знание Navision версий от 3.7 и выше, модули: Финансы, ОС, Продажа и Покупки;',
#  'Знание T-SQL на уровне написания и оптимизации сложных запросов;',
#  'Знание высокоуровневых языков программирования (C#, Java) будет являться преимуществом.',
#  'Прекрасное знание JavaScript (es6/es7: классы, импорты декораторы, arrow-функции, генераторы, промисы)',
#  'Экспертное знание HTML, HTML5, SASS/LESS/CSS',
#  'Опыт работы с js-фреймоврками (например, Backbone, Angular, React, Reflux).',
#  'Опыт работы с Webpack: уметь собрать проект с картинками и стилями, скриптами.',
#  'Опыт работы с REST-сервисами',
#  'Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  'Умение работать с Git Будет плюсом',
#  'Знание React Опыт работы с Bootstrap, Ionic, Foundation и т.д.',
#  'Умение разрабатывать прототипы UI с помощью, например, Axure, Pixate, Invision, Proto.io и т.д.',
#  'Опыт тестирования от 3 лет ;',
#  'Опыт работы в инструменте тестирования: HP ALM (написание параметризованных тестовых сценариев);',
#  'Опыт работы с инструментами Atlassian: JIRA и Confluence (работа с дефектами, ведение статей);',
#  'Практический опыт функционального, интеграционного тестирования сервисных шин и процессов интеграции данных будет плюсом;',
#  'Опыт запуска, анализа результатов автотестов;',
#  'Владение навыками тест-анализа и тест-дизайна;',
#  'Знания SQL для составления запросов: выбор из таблиц, вставка в таблицу и фильтрация по нескольким полям, объединения;',
#  'Опыт автоматизации тестирования будет плюсом (Java+Cucumber);',
#  'Опыт работы с БД Oracle;',
#  'Опыт интеграционного тестирования программного обеспечения и использования инструментов API тестирования: SoapUI или rfhutil или MQ или Fiddler) будет плюсом;',
#  'Опыт работы с XML, XSD;',
#  'Опыт тестирования систем, участвующих в банковских процессах оценки рисков розничного и/или корпоративного кредитования будет плюсом. ',
#  'Условия работы:',
#  ':',
#  'Высшее техническое образование;',
#  'Позитивный взгляд на ИТ, и желание развиваться в ИТ;',
#  'Умение быстро сориентироваться в непонятной ситуации.',
#  'Опыт тестирования приложения от 1 года;',
#  'Опыт работы с Selenium;',
#  'Опыт участия в автоматизации тестирования;',
#  'Знание и умение пользоваться инструментами авто-тестирования;',
#  'Знание SQL на уровне написания простых запросов;',
#  'Плюсом будет: опыт разработки тестовой модели для новой системы с нуля; опыт работы с XML, Soap и MQ протоколами.',
#  'Высшее техническое образование;',
#  'Знание основных принципов работы ЛВС;',
#  'Знание основных принципов работы сетей и систем хранения данных;',
#  'Общие знания в вопросах информационной безопасности;',
#  'Знание ИТ-технологий и принципов работы сложных вычислительных систем;',
#  'Знание основ кластерных технологий;',
#  'Знание технологий резервного копирования и восстановления данных;',
#  'Английский технический (чтение профессиональной литературы);',
#  'Пунктуальность, исполнительность, целеустремленность, умение работать в команде, стрессоустойчивость, навыки самообучения.',
#  'Условия работы:',
#  '• Высшее техническое образование;',
#  '• Опыт работы системным аналитиком или разработчиком 1-2 года;',
#  '• Базовые знания SQL, PL/SQL, СУБД Oracle;',
#  '• Умение работать с функциональными и техническими требованиями;',
#  '• Знание аннотация BPMN, умение составления схем BPMN;',
#  '• Знание банковских бизнес-процессов корпоративного блока;',
#  '• Коммуникабельность, внимание к деталям, умение работать в режиме многозадачности, умение работать в команде, аккуратность, активность, хорошо развитые аналитические навыки, обязательность, ответственность, самостоятельность.',
#  'Условия работы:',
#  'Опыт в разработке или эксплуатации ПО от 5 лет ',
#  'Опыт эксплуатации и настройки инструментов Continuous Integration или Continuous Deploy/Delivery: ',
#  'Полное понимание механизмов работы систем контроля версий',
#  'Опыт и понимание механизмов работы систем управления сборкой',
#  'Опыт создания автосборок дистрибутивов ',
#  'Опыт и понимание механизмов построения модульных тестов ',
#  'Опыт и понимание механизмов работы систем функционального и автоматизированного тестирования ',
#  'Глубокое владение инструментами автоматического развертывания дистрибутивов и управления конфигурациями сред ',
#  'Опыт администрирования Linux ( предпочтение RHEL/CentOS )',
#  'Открытость, общительность, умение работать в команде. ',
#  'Технологии: Linux, Ansible, Jenkins, GIT, Nexus, экосистема Hadoop, Openstack, Контейнерные технологии, PostgreSQL, OracleSQL',
#  '\\u200b\\u200b\\u200b\\u200b',
#  'Опыт в области автоматизации функционального тестирования;',
#  'Знание процесса разработки ПО и теории тестирования;',
#  'Знание типов интеграционных взаимодействий и способов их тестирования;',
#  'Опыт работы с bug-tracking системами (Jira, HP ALM);',
#  'Понимание видов автоматизированного тестирования и необходимости их применения;',
#  'Знание протоколов прикладного уровня;',
#  'Навыки программирования (java);',
#  'Навыки написания SQL запросов (желательно Oracle);',
#  'Опыт работы системным аналитиком от года;',
#  'Знание sql;',
#  'Опыт использования Confluence, Jira;',
#  'Навыки командной работы и умение быстро найти общий язык с коллегами;',
#  'Грамотная устная и письменная речь.',
#  'Знание банковской специфики в сфере Collection;',
#  'Понимание стандартов SOAP (xsd/wsdl), REST;',
#  'Опыт работы в agile-команде.',
#  'Высшее образование;',
#  'Опыт ведения проектов;',
#  'Понимание инструментов и методологий исследований;',
#  'Опыт работы с большим массивом данных;',
#  'Владение грамотной речью;',
#  'Умение общаться с людьми в разных ситуациях;',
#  'Аналитический склад ума;',
#  'Желание развивать проект и развиваться самому.',
#  'Опыт работы на аналогичной должности от 3-х лет в сфере ИТ;',
#  'Опыт работы в рамках предметной области, связанной с автоматизацией массовых маркетинговых кампаний (желательно)',
#  'Опыт обследования и систематизации процессов «как есть»',
#  'Опыт проектирования процесс «как будет»',
#  'Опыт управления требованиями',
#  'Опыт постановки задач команде разработки',
#  'Опыт организации и проведения ПСИ',
#  'Опыт работы с инструментами сегментации (желательно, Oracle BI/SAS MA)',
#  'Экспертные знания методологий/нотаций/стандартов описания бизнес-процессов',
#  'Знание базового SQL, умение анализировать источники данных, опыт работы с СУБД Teradata,Oracle',
#  '• Аналогичный опыт работы - от 3 лет;',
#  '• Наличие портфолио обязательно;',
#  'br/',
#  '• Уверенное владение Sketch, XD, Photoshop и Illustrator;',
#  'br/',
#  '• Знание современных трендов Digital-дизайна;',
#  'br/',
#  '• Внимание к деталям и аккуратность;',
#  'br/',
#  '• Хорошие коммуникационные навыками, умением защищать свою позицию и адекватно воспринимать критику и комментарии команды;',
#  'br/',
#  '• Умение выдавать результат в запланированное время, планировать свое время и рассчитывать продолжительность выполнения поставленной задач.',
#  'br/',
#  '• Ключевые компетенции:',
#  'br/',
#  '1. UX/UI design',
#  'br/',
#  '2. Дизайн интерфейса/клиентского опыта',
#  'br/',
#  '3. JavaScript (React Native)',
#  'br/',
#  '• Дополнительные знания будут плюсом:',
#  'br/',
#  '1. Навыки фронтенд разработчика (знание CSS, HTML5)',
#  'br/',
#  '2. Разработка дашбордов QlikSense',
#  'Java 1.8',
#  'Spring 3+',
#  'Hibernate',
#  'Rest',
#  'MQ',
#  'Сборщик проекта Maven',
#  'Контроль версий Git',
#  'Высшее техническое ИТ образование',
#  'Базовые/начальные знания языка SQL, СУБД Oracle, языков программирования',
#  'Высокий порог ответственности, внимательность, аккуратность, готовность изучать инструменты и технологии.',
#  'br/',
#  '— знание трендов в дизайне и технологиях; понимание, когда и как их применять;',
#  'br/',
#  '— владение графическими редакторами;',
#  'br/',
#  '— понимание методологий продуктовой разработки (CJM, Service Blueprint, дизайн-мышление и т. д.);',
#  'br/',
#  '— самостоятельность;',
#  'br/',
#  '— критическое мышление.',
#  'br/',
#  'br/',
#  'Java 7 (core, multithreading) ∙ Oracle (знание архитектуры/принципов работы/умение писать запросы) ∙ Spring framework (IoC, batch, integration, jdbc) ∙ Websphere, WildFly',
#  'Процессы разработки, ∙ CI: gradle/jenkins, ∙ SCM: git/stash ∙ Wiki/Tasks: jira/confluence, ReactJS; Знание основ Agile,',
#  'Будет преимуществом опыт разработки на JAVA, ReactJS (UI), опыт работы с макросами Excel.',
#  'Желательно: ∙ знание IBM MQ/JMS, опыт проектирования БД',
#  'Будет преимуществом знание бизнес-процессов кредитования и залогового обеспечения в Банке.',
#  '- Экспертные знания языка PL/SQL (PL+ опционально).',
#  '- Умение работать с базами данных Oracle',
#  '- Знания ЦФТ-Банк (IBSO) на уровне разработчика',
#  '- Навыки системного анализа',
#  '- Базовые знания Java опционально',
#  '· Высшее образование',
#  '· Опыт разработки на языке Java от 3 лет (хорошие знания стека: collections, multithreading, JMM, JVM internal)',
#  '· Хорошее ориентирование в современном стеке Java-технологий',
#  '· Опыт работы с серверами приложений (настройка, оптимизация)',
#  '· Чёткое понимание цикла разработки ПО (ведение разработки от бизнес-требований до внедрения, работа с репозиториями, несколькими контурами)',
#  '· Знание стандартных алгоритмов и структур данных',
#  '· Знание принципов и технологий построения распределенных систем',
#  '· Опыт работы с СУБД (предпочтительней Oracle);',
#  '· Опыт работы со Spring (Core, Security, Integration, AOP, etc.);',
#  '· Знание инфраструктуры разработки (GIT, Jira, Confluence)',
#  '· Опыт работы с Linux-системами (продвинутый пользователь)',
#  '· Приветствуется опыт разработки промышленных бизнес критических систем',
#  '· Опыт работы с платформой PEGA - будет дополнительным преимуществом',
#  'Уверенное знание и опыт работы на С/С++;',
#  'Опыт написания технической документации;',
#  'Уверенное знание концепций ООП;',
#  'Умение разбираться в legacy коде;',
#  'Знание и опыт работы с сокетами;',
#  'Опыт разработки многопоточных приложений; Понимание способов межпоточных/межпроцессных взаимодействий/синхронизации;',
#  'Опыт разработки кроссплатформенных приложений;',
#  'Опыт разработки высоконагруженных систем;',
#  'Опыт написания аналитических документов;',
#  'Уверенное знание и практика использования шаблонов проектирования;',
#  'Понимание необходимости, важности и методов рефакторинга кода;',
#  'Опыт написания автотестов.',
#  'Java, Spring framework;',
#  'Желателен опыт работы с инструментами DevOps ( VCS, Jenkins, Ansible, Gradle, Junit и пр.).',
#  'br/',
#  'WildFly, IBM WAS;',
#  'Kafka, WS MQ;',
#  'RHEL;',
#  'ReactJS;',
#  'DB Oracle, PostgreSQL, NoSql (Mongo, Redis).',
#  'WildFly, IBM WAS;',
#  'Kafka, WS MQ;',
#  'RHEL;',
#  'ReactJS;',
#  'DB Oracle, PostgreSQL, NoSql (Mongo, Redis).',
#  'WildFly, IBM WAS;',
#  'Kafka, WS MQ;',
#  'RHEL;',
#  'ReactJS;',
#  'DB Oracle, PostgreSQL, NoSql (Mongo, Redis).',
#  'Event Sourcing, Event driven;',
#  'DDD, TDD;',
#  'Микросервисная архитектура;',
#  'Docker, OpenShift;',
#  'Стек ELK.',
#  'Управлять данными в соответствии с политикой и стандартами компании;',
#  'Определять бизнес-правила и стандарты для данных;',
#  'Разрабатывать процедуры валидации данных на соответствии требований;',
#  'Проверять новые инициативы и продуктовые доработки на соответствие политики компании в отношении работы с данными;',
#  'Развивать и совершенствовать стратегии по работе с данными;',
#  'Повышать качества данных в компании.',
#  'Управлять данными в соответствии с политикой и стандартами компании;',
#  'Определять бизнес-правила и стандарты для данных;',
#  'Разрабатывать процедуры валидации данных на соответствии требований;',
#  'Проверять новые инициативы и продуктовые доработки на соответствие политики компании в отношении работы с данными;',
#  'Развивать и совершенствовать стратегии по работе с данными;',
#  'Повышать качества данных в компании.',
#  'С опытом работы по специальности аналитик данных, дата стюард и тп;',
#  'Отлично знаешь SQL;',
#  'Знаешь Python + пакеты для работы с данными и data mining (numpy, pandas, scikit-learn).',
#  'Умение планировать рабочую деятельность, создание и ведение проектной деятельности в MS Project, декомпозиция задач',
#  'Грамотная и четкая речь, умение вести презентации и переговоры',
#  'Умение лаконично формулировать мысли как устно, так и письменно',
#  'Умение работать в команде',
#  'Умение и желание общаться с заказчиками, разработчиками, тестировщиками, аналитиками смежных систем',
#  'Умение понимать «общую картинку», планировать на квартал вперед',
#  'Наличие успешно завершенных проектов/задач на прежнем/предыдущем месте работы',
#  'Опыт работы в Agile командах',
#  'Опыт создания презентаций для руководства',
#  'Понимание жизненного цикла разработки ПО',
#  'Опыт написания функциональных требований/бизнес-требований/технических спецификаций на разработку;',
#  'Наличие успешно завершенных проектов/задач на прежнем/предыдущем месте работы',
#  'Опыт работы в Agile командах',
#  'Опыт создания презентаций для руководства',
#  'Понимание жизненного цикла разработки ПО',
#  'Опыт написания функциональных требований/бизнес-требований/технических спецификаций на разработку;',
#  'br/',
#  'Опыт разработки: от 2 лет;',
#  'br/',
#  'Отличное владение Java core, Java EE;',
#  'br/',
#  'Опыт работы с фреймворком Spring;',
#  'br/',
#  'Знание интеграций между системами через Web-сервисы XML/HTTPS, XML/MQ;',
#  'br/',
#  'Знание принципов, архитектуры и паттернов проектирования приложений;',
#  'br/',
#  'Знание принципов организации эффективной разработки;',
#  'br/',
#  'Владение инструментами DevOps: Maven и/или Git, и/или Jenkins, и/или Docker',
#  'Опыт сопровождения Unix серверов - от 3 лет',
#  'Опыт диагностики проблем ОС и ППО - от 3 лет',
#  'Широкие знания в области современной корпоративной инфраструктуры предприятия по направлениям: инфраструктурные программные решения, вычислительная инфраструктура, сетевая и телекоммуникационная инфраструктура',
#  'Знания технологий и решений на базе системного программного обеспечения коммерческих UNIX и Windows',
#  'Знания технологий, решений и оборудования в области систем хранения и обработки и данных (IBM, Oracle, HP, VMware, Citrix)',
#  'Экспертные знания серверного оборудования Hi-End класса (IBM, HP, Oracle)',
#  'Опыт поддержки высоконагруженных систем',
#  'Опыт работы с системами мониторинга (HP OpenView, IBM Tivoli Monitoring, Zabbix)',
#  'Программирования на скриптовых языках perl, awk, bash, python etc.',
#  'Знание принципов работы локальных сетей и основных сетевых сервисов (понимание TCP/IP, DNS, DHCP)',
#  'Знание принципов построения отказоустойчивых решений',
#  'Опыт работы с Veritas storage foundation; Veritas Cluster; LVM ОС AIX, Solaris, Linux',
#  'Опыт разработки технической документации',
#  'Знание английского на уровне, достаточном для чтения технической документации',
#  'Высшее техническое образование: информационные технологии, электронная или вычислительная техника',
#  'Компьютерная грамотность: работа в ОС Windows и Linux; владение Word, Excel, PowerPoint, Visio',
#  'Личностные качества: находчивость, клиентоориентированность; способность справляться со сложными ситуациями и выдерживать высокий темп работы; доброжелательность, умение работать в команде; стремление повышать знания и совершенствовать навыки.',
#  'Условия работы:',
#  'опыт тестирования приложений - от 2-х лет;',
#  'опыт написания тестовых сценариев;',
#  'опыт организации и проведения функционального, модульного, интеграционного и приемочного тестирования;',
#  'опыт выполнения оценки трудозатрат;',
#  'опыт работы с XML;',
#  'знание SQL на уровне написания запросов средней сложности (вставка, объединение, выбор, группировка);',
#  'обязательность, исполнительность, нацеленность на результат, умение работать самостоятельно.',
#  'Условия работы:',
#  'Разработка макетов и прототипов для мобильных приложений и web-систем;',
#  'Участие во всех стадиях разработки продукта;',
#  'Анализ и проработка пользовательского поведения;',
#  'Описание функциональных требований к разрабатываемым продуктам;',
#  'Развитие идей и концепций взаимодействия пользователя с системой учитывая уже существующие гайдлайны;',
#  'Разрабатывать микросервисы, интеграционные решения с основными продуктами Банка',
#  'Писать авто и юнит тесты',
#  'Работать в 2х недельных SCRUM спринтах.',
#  'Опыт разработки приложений с использованием Java-технологий от 3-5 лет',
#  'Хорошее владение Java (core), желательно знание стека Spring, JavaEE',
#  'Опыт работы с многопоточностью',
#  'Опыт работы с серверами приложений WebSphere AS, WildFly, Tomcat etc.',
#  'Опыт написания unit-тестов',
#  'Знание основных паттернов разработки ПО',
#  'Знание алгоритмов, структур данных',
#  'Понимание методологий разработки ПО: Agile, Kanban',
#  'Опыт работы с системами контроля версий (SVN, Git)',
#  'Разрабатывать мобильные приложения под платформу Android',
#  'Писать авто и юнит тесты',
#  'Работать в 2х недельных SCRUM спринтах.',
#  'Высшее техническое образование.',
#  'Опыт разработки Android приложений от 3-5 лет',
#  'Знание Java (core)',
#  'Знание Android SDK (API Level 15+)',
#  'Умение верстать сложные интерфейсы',
#  'Знание и понимание механизмов многопоточности',
#  'Опыт написания unit и ui-тестов',
#  'Знание основных паттернов разработки ПО',
#  'Знание алгоритмов, структур данных',
#  'Понимание методологий разработки ПО: Agile, Kanban',
#  'Опыт работы с системами контроля версий',
#  'Желательно, фул-стек (JAVA + UI). Если нет UI, то было бы хорошо, если есть желание развиваться в эту сторону.',
#  'Для Java:',
#  'br/',
#  'Опыт работы с технологиями: Spring, Hibernate, Gradle, JMS, JAX-WS, Git, Jenkins, UML, Junit.',
#  'Для UI:',
#  'br/',
#  'Знание JavaScript (es6/es7: классы, импорты декораторы, arrow-функции, генераторы, промисы)',
#  'br/',
#  'Экспертное знание HTML, HTML5, SASS/LESS/CSS',
#  'br/',
#  '• Опыт работы с js-фреймоврками (например, Backbone, Angular, React, Reflux).',
#  'br/',
#  '• Опыт работы с Webpack: уметь собрать проект с картинками и стилями, скриптами.',
#  'br/',
#  '• Опыт работы с REST-сервисами',
#  'br/',
#  '• Понятие о принципах разработки ПО, ООП, паттернах проектирования',
#  'br/',
#  '• Умение работать с Git Будет плюсом',
#  'br/',
#  '• Знание React Опыт работы с Bootstrap, Ionic, Foundation и т.д.',
#  'br/',
#  '• Умение разрабатывать прототипы UI с помощью, например, Axure, Pixate, Invision, Proto.io и т.д.',
#  'Разрабатывать мобильные приложения под iOS',
#  'Писать авто и юнит тесты',
#  'Работать в 2х недельных SCRUM спринтах.',
#  'Опыт разработки на Objective-C от 2-х лет (знания Swift приветствуются)',
#  'Знания принципов ООП.',
#  'Знания паттернов программирования на примере iOS.',
#  'Умения при работе с Xcode в качестве основной IDE и опыт работы с её компонентами (iOS Simulator, Interface Builder, Source Control, Application Loader)',
#  'Опыт работы с системами контроля версий',
#  'Представление об архитектуре MVC и других, таких как MVVM, MVP, VIPER.',
#  'Качественные знания в области управления памятью',
#  'Знание основ SOLID с примерами под iOS',
#  'Понимание жизненного цикл iOS-приложения',
#  'Понимание жизненного цикл UIViewController',
#  'Опыт создания контейнеров',
#  'Опыт верстки экранов с помощью Interface Builder',
#  'Опыт верстки экранов только кодом без Interface Builder',
#  'Навыки по работе с инструментами списков: UITableView и UICollectionView.',
#  'Понимание, что такое Autolayout, CoreData',
#  'Опыт при работе с серверным API',
#  'Опыт работы с многопоточностью',
#  'Опыт работы с зависимостями через Pods и Carthage',
#  'Понимание Unit-тестирования',
#  'Придумывать дизайн приложения;',
#  'Программировать по заранее написанному кем-то ТЗ;',
#  'Работать «в стол».',
#  'Опыт работы FE со схожим стеком от 2-х лет;',
#  'Опыт работы в Банках не обязателен. Продукт не оперирует банковской спецификой и не подразумевает глубоких интеграций с банковским ПО;',
#  'Желателен опыт работы над digital, web, mobile продуктами/системами, RTC;',
#  'Большим плюсом будет практический опыт работы с agile/scrum методологией;',
#  'Искренний интерес к цифровым технологиям.',
#  'br/',
#  '• СУО, СИМСУО, МП СБОЛ',
#  'br/',
#  '• Опыт тестирования приложений - от 1 года;',
#  'br/',
#  '• Опыт написания тестовых сценариев;',
#  'br/',
#  '• Опыт проведения функционального, модульного, интеграционного тестирования;',
#  'br/',
#  '• Знание SQL на уровне написания простых запросов;',
#  'br/',
#  '• Обязательность, исполнительность, нацеленность на результат, умение работать самостоятельно.',
#  ':',
#  'br/',
#  'Java EE',
#  'br/',
#  'Spring IOC',
#  'br/',
#  'Hibernate ORM',
#  'br/',
#  'Oracle Pl/SQL',
#  'br/',
#  'Git',
#  'br/',
#  'PostgreSQL',
#  'br/',
#  'JSON',
#  'br/',
#  '• Опыт работы разработчиком и/или тестировщиком от 1 года (Java, JavaScript);',
#  'br/',
#  '• Желательно знание одного из фреймоврков для автоматизированного тестирования (Selenium, Appium, Winium/WinAppDriver, Rest-Assured и прочее);',
#  'br/',
#  '• Знания методологий разработки и/или тестирования ПО, умение применять их на практике;',
#  'br/',
#  '• Желание и умение проектировать эффективные тесты.',
#  'Высшее техническое образование Информационные технологии или Математика',
#  'Опыт разработки корпоративных систем',
#  'Опыт разработки на Java(от 2х лет)',
#  'J2EE (JSP, JMS, Servlet, JDBC, JPA)',
#  'Web Services (SOAP &amp; REST)',
#  'Знание SQL',
#  'Опыт работы с Hibernate',
#  'Опыт работы с Gradle, Maven',
#  'Struts, Spring Framework',
#  'GIT',
#  'Приветствуется : опыт работы с Jenkins, IBM WAS, IntelliJ IDEA, Jira',
#  'Java core;',
#  'Spring;',
#  'JPA, Hibernate;',
#  'SQL (желательно);',
#  'React JS (желательно);',
#  'Kafka, ZeroMQ (желательно иметь представление);',
#  'WildFly.',
#  'Высшее техническое образование',
#  'Опыт сопровождения телекоммуникационной инфраструктуры входящей в состав услуги Wi-Fi (не менее 3 лет)',
#  'Умение планировать и внедрять обновления на телекоммуникационном оборудование инфраструктуры Wi-Fi',
#  'Наличие опыта проектирования зон покрытия Wi-Fi, выбора архитектуры решений, проведения пусконаладочных работ по направлению услуги Wi-Fi',
#  'Наличие опыта в подготовке технических заданий для закупки оборудования или услуг по направлению Wi-Fi',
#  'Условия работы:',
#  'Опыт от одного года в области Data Science;',
#  'Понимание базы алгоритмов машинного обучения;',
#  'Знание и опыт работы со стеком технологий и алгоритмов data science (обработка, очистка и трансформация данных, исследовательский анализ, построение моделей, оценка результатов) на инструментах Python/R;',
#  'Опыт работы с библиотеками машинного обучения;',
#  'Продвинутый уровень SQL.',
#  'Высшее техническое образование',
#  'Опыт сопровождения телекоммуникационной инфраструктуры входящей в состав услуги Wi-Fi (не менее 2 лет)',
#  'Наличие опыта разработки типовых инструкций и шаблонов конфигураций сетевого оборудования',
#  'Умение планировать и внедрять обновления на телекоммуникационном оборудование инфраструктуры Wi-Fi',
#  'Наличие опыта в подготовке технических заданий для закупки оборудования или услуг по направлению Wi-Fi',
#  ':',
#  'br/',
#  'Высшее техническое образование',
#  'br/',
#  'Опыт администрирования автоматизированных систем',
#  'br/',
#  'Опыт взаимодействия с разработчиками ПО (постановка задач, требований, контроль их исполнения)',
#  'br/',
#  'Навыки написания запросов с использованием SQL',
#  'br/',
#  'Понимание методологии ITSM',
#  'br/',
#  'Опыт написания инструкций',
#  'br/',
#  'Опыт работы с Microsoft Windows Server, Active Directory, знание СУБД Oracle будет плюсом (для высших должностей желателен высокий уровень), IBM Websphere, администрирование Linux-серверов',
#  'br/',
#  'Высокий порог ответственности, внимательность, аккуратность',
#  '•Высшее образование (экономическое/ИТ);',
#  '- Знания банковского ПО',
#  '•Продвинутый уровень владения Microsoft Excel (знание макросов, программирование на VBA);',
#  '- Навыки работы с SQL-запросами',
#  '•Уверенная работа с большим объемом данных, анализ данных и формирование отчётности',
#  '•Аналитический склад ума, креативный подход к решению поставленной задачи.',
#  'Высшее техническое образование (предпочтение отдается кандидатам из передовых технических ВУЗов Москвы (Бауманка, МАИ, МФТИ, МГУ);',
#  'Опыт работы руководителем группы от 2-х лет, ведущим разработчиком – не менее 3-х лет;',
#  'Опыт работы с Битрикс: управление сайтом не менее 3 лет;',
#  'Опыт разработки сложных высоконагруженных проектов, знание способов масштабирования проекта при росте нагрузки;',
#  'Опыт проектирования архитектуры построения высоконагруженных сайтов;',
#  'Опыт проведения тестирования и нагрузочных испытаний;',
#  'Использование систем контроля версий, например Git;',
#  'Высокая скорость разработки;',
#  'PHP, MySQL – экспертный уровень проектирования и написания кода, готовность подтвердить примерами. Опыт взаимодействия со сложными запросами (знание о триггерах);',
#  'Linux – уверенный пользователь, как плюс опыт devops;',
#  'Глубокое понимание реляционных БД, умение оптимизировать запросы, проектировать модель данных;',
#  'API, включая REST API – умение писать и проектировать свои и использовать чужие;',
#  'Знание Javascript, Jquery, CSS, HTML;',
#  'Умение ориентироваться в чужом коде, заниматься рефакторингом кода;',
#  'Проектное мышление;',
#  'Аналитический склад ума;',
#  'Инициативность;',
#  'Перфекционизм.',
#  'Практический опыт работы с ОС RedHat 5,6,7, Ubuntu LTS, 14,16 - администрирование ОС.',
#  'Опыт работы с HP UX, AIX, Solaris является плюсом.',
#  'Опыт перевода рабочих станция на Linux в условиях крупной организации.',
#  'Опыт в настройке, администрировании и сопровождении базовых сервисов - iptables, firewalld, dhcpd, named, nginx, etc...',
#  'Как плюс базовый опыт работы в сопровождении Apache Spark, Apache Tomcat, Apache Kafka.',
#  'Уверенные знания SElinux, AppArmor ( в зависимости от вендора ОС), работы PAM, интеграции с Microsoft AD, ролевой модели доступа.',
#  'Уверенные знания и практический опыт использования средств автоматизации и управления конфигурациями - Ansible, Salt, Puppet, Chief',
#  'Знания скриптовых языков программирования - bash, python',
#  'Базовые архитектурные знания построения клиент - серверных приложений, веб приложений.',
#  'Уверенные знания в настройке стека TCP/IP OS, резервирования и балансировки сетевого трафика средствами ОС.',
#  'Практический опыт работы с средствами виртуализации KVM, Vmware, а так же с контейнерами LXD, Docker, Docker CE.',
#  'Практический опыт сбора первичной информации для проведения аудита информационной безопасности.',
#  'Целеустремленность, желание познать новое, желание работать в интересной команде.',
#  'Условия работы:',
#  'Централизация управления и анализа моделей CashFlow',
#  'опыт использования Hadoop 2.x., Apache Spark;',
#  'Docker - уверенные знания и опыт работы: docker-compose, swarm или аналоги.',
#  'Linux - уверенные знания, работа с shell, CLI',
#  'Опыт промышленной разработки с использованием VCS, CI, CD, Git, PyCharm, понимание методологий разработки);',
#  'опыт использования Hadoop 2.x., Apache Spark;',
#  'Docker - уверенные знания и опыт работы: docker-compose, swarm или аналоги.',
#  'Linux - уверенные знания, работа с shell, CLI',
#  'Опыт промышленной разработки с использованием VCS, CI, CD, Git, PyCharm, понимание методологий разработки);',
#  'Умение общаться с бизнес-пользователями для формализации их требований;',
#  'Опыт написания функциональных и технических требований к разрабатываемой системе, написания технических проектов ИТ решений, согласования проектной документации с заказчиками и разработчиками;',
#  'Понимание принципа разработки сценариев тестирования;',
#  'Понимание принципов построения Хранилища Данных',
#  'Знания SQL, MS Office.',
#  'Знание инструментов Hadoop (Hive, Impala, Spark и т.п.), Teradat, инструментов Atlassian (Jira, Confluence), SAS',
#  'Условия работы:',
#  'Знание инструментов Hadoop (Hive, Impala, Spark и т.п.), Teradat, инструментов Atlassian (Jira, Confluence), SAS',
#  'Условия работы:',
#  'умение работать с ОС Linux на уровне продвинутого пользователя;',
#  'знание PL/SQL, TSQL или Teradata SQL, опыт оптимизации запросов;',
#  'понимание принципов REST API;',
#  'хороший английский. Быстрое погружение в новые темы.',
#  'Высшее техническое/математическое (технический ВУЗ)',
#  'опыт сбора и анализа бизнес требований к системам и отчетности, GAP -анализ;',
#  'опыт проектирования моделей бизнес-процессов AS IS и TO BE;',
#  'знание банковских бизнес-процессов по различным продуктам;',
#  'знание банковских технологий, документооборота и технгологий бухгалтерского учета;',
#  'понимание принципов взаимодействия систем, опыт работы с несколькими системами и интеграциями между ними;',
#  'опыт постановки задач для разработки;',
#  'опыт написания пользовательской документации;',
#  'участие в проектах по внедрению/ развитию автоматизированных систем банка в качестве аналитика;',
#  'продвинутый пользователь MS Visio, MS Excel, MS PowerPoint;',
#  'коммуникабельность, инициативность, опыт и желание работать по методологии Agile.',
#  'Условия работы:',
#  'Опыт JavaScript-разработки',
#  'Опыт разработки WEB-приложений/Single Page Application',
#  'Опыт работы с React.js',
#  'Опыт работы с SQL',
#  'От 2-х лет работы в коммерческих проектах.',
#  'Опыт HTML5/CSS3 разработки',
#  'Наличие портфолио реализованных проектов',
#  'Условия работы:',
#  '∙ Опыт в части обработки и моделирования данных – не менее 2х лет;',
#  '∙ Понимание и опыт практического применения математической статистики, теории вероятностей и линейной алгебры;',
#  '∙ Понимание и опыт практического применения алгоритмов машинного обучения: нейронные сети, композиционные алгоритмы (случайный лес, градиентный бустинг и т.д.), линейные алгоритмы (линейная и логистическая регрессии и т.д.);',
#  '∙ Опыт работы с временными рядами (LSTM, GRU, ARIMA, ETS и т.д.);',
#  '∙ Опыт программирования на SAS (Base/Guide/Miner) / Python (PyData: Pandas, NumPy, SkiPy, scikit-learn, keras/TensoFlow и т.д.) / R;',
#  '∙ Опыт работы с базами данных. Знание SQL;',
#  '∙ Опыт работы с фреймворками Hadoop (HDFS, Hive), Spark;',
#  '∙ Оформление результатов исследований в вид отчетов;',
#  '∙ Понимание методологий работы: Agile Scrum и Canban. Будет плюсом: ∙ Прохождение курсов на Coursera или аналогах. Например, Анализ данных и машинное обучение (Яндекс/МФТИ) и Data Science (John Hopkins University);',
#  'br/',
#  '- знание принципов работы и устройства веб-приложений и сервисов, принципов работы серверов приложений и реляционных баз данных, SQL, основы программирования, ООП.',
#  '- Программирование на Java и JS.',
#  'JavaScript, HTML, CSS',
#  'Python (Django)',
#  'Будет плюсом:',
#  'Опыт работы с React и Redux;',
#  'Навык работы с npm (Node.js Package Manager);',
#  'понимание гибких методологий разработки (Scrum)',
#  '- Высшее образование в одной из областей - Финансы, Экономика, Информационные технологии;',
#  '- Опыт работы на рынке fintech, в крупных интернет компаниях, в банках , R&amp;D, b2b saas сервисах',
#  '- Опыт создания новых технологических продуктов;',
#  '- Успешный опыт одновременного управления несколькими проектами;',
#  '- Опыт управления кросс-функциональными проектными командами',
#  '- Навыки внедрения ИТ-систем от стадии идеи до промышленной эксплуатации (знание проектной методологии, опыт ее практического применения, навыки ведения проектной документации);',
#  '- Опыт подготовки и презентации решений на уровень топ-менеджмента; прямое взаимодействие с топ-менеджментом организации;',
#  '- Стратегическое мышление;',
#  '- Отличные организаторские, коммуникационные и лидерские навыки;',
#  '- Умение отстаивать свою точку зрения.',
#  'Опыт работы в области Data science от одного года;',
#  'Опыт работы с Hadoop (Hive, Spark, HBase) является плюсом;',
#  'Опыт работы с инструментами для организации и автоматизации работы: GridSearchJira, Confluence;',
#  'Условия работы:',
#  'Глубокие навыки в сопровождения распределенных решений (HDFS, NoSQL, key-value storage)',
#  'Глубокое понимание работы сервисов NN/DN, Zookeeper, Solr, Flume, YARN (управление Resource Pools) и других сервисов Hadoop',
#  'Глубокое понимание работы JVM в части system software (java memory model, Garbage Collector algorithms)',
#  'Знания python, shell, SQL, приветствуется java',
#  'Опыт работы с реляционными СУБД',
#  'Знания OS Linux на уровне опытного пользователя',
#  'Английский язык на уровне ведения переписки и чтения технической документации, разговорный приветствуется',
#  'Условия работы:',
#  'экспертное знание Java Core;',
#  'опыт в роли Java -разработчика от 2-х лет и выше;',
#  'уверенное знание J2EE;',
#  'понимание технологий JMS, RMI;',
#  'широкий опыт работы с фреймворком Spring (spring.io);',
#  'экспертное знание и использование в работе git;',
#  'уверенная работа с реляционными БД с использованием DAO или JPA;',
#  'применение в своих практиках Unit-тестирования (модульное тестирование);',
#  'опыт реализации программных продуктов в паттернах MVC/MVVC;',
#  'успешное применение в работе паттернов Адаптер, Прокси, Декоратор, Фабрика и фабричный метод ;',
#  'br/',
#  '•Знание принципов ООП, шаблонов проектирования',
#  'br/',
#  '•Умение работать с Git, Maven',
#  'br/',
#  '•Отличное знание Java EE, опыт разработки от 2 лет',
#  'br/',
#  '•Отличное знание React.JS, опыт разработки от 1 лет',
#  'br/',
#  '•Опыт работы с Hibernate',
#  'br/',
#  '•Опыт работы с Oracle',
#  'br/',
#  '•Опыт использования Spring Framework',
#  'br/',
#  '•Опыт многопоточного программирования',
#  'br/',
#  '•Понимание принципов SOAP, REST, JMS',
#  'br/',
#  '•Опыт работы с Message Broker (IBM MQ)',
#  'br/',
#  '•Опыт работы с IBM WebSphere AppServer ,Liquibase',
#  'br/',
#  '•Опыт написания Unit-тестов (jUnit, jest)',
#  'обязательно',
#  '- основы ООП, желательно Java',
#  '- основы БД (суть нормальных форм, нормализация и денормализация, типы данных, нормализация, ключи, индексы, триггеры)',
#  '- умение понимать язык программистов и язык пользователей, аргументировать свою позицию',
#  'желательно',
#  '- основы HTML/CSS/Javascript',
#  '- понимание бизнес процессов банка',
#  '- представление о примерах промышеленной топологии приложений',
#  '- git/gitworkflow',
#  '- детали работы hibernate, jdbc и Oracle',
#  '- очереди сообщений (JMS)',
#  'br/',
#  '•Знание принципов ООП, шаблонов проектирования',
#  'br/',
#  '•Умение работать с Git, babel, webpack',
#  'br/',
#  '•Опыт работы с React.JS от 2-х лет',
#  'br/',
#  '•Знание TypeScript, ES6',
#  'br/',
#  '•Знание HTML, CSS, SCCS, SVG, BEM',
#  'br/',
#  '•Понимание HTTP-протокола (POST, GET, PATCH, авторизация, сессии, Cookie и т. д.)',
#  'br/',
#  '•Опыт работы с фреймворками Redux, React-router',
#  'br/',
#  '•Опыт работы с библиотеками lodash, moment',
#  'br/',
#  '•Понимание принципов SOAP, REST, JMS',
#  'br/',
#  '•Опыт написания Unit-тестов (jest)',
#  'br/',
#  '•Опыт использования библиотек UI-компонент',
#  'Опыт разработки клиентских приложений под iOS от 2 лет (возможны исключения)',
#  'Свободное владение iOS SDK',
#  'Понимание основных принципов и паттернов Objective-C',
#  'Опыт разработки клиент-серверных приложений',
#  'Понимание цикла разработки ПО, гибких методологий (Scrum/Kanban)',
#  'Умение разбираться в сложных проектах, владение GIT',
#  'Умение писать Clean Code (SOLID)',
#  'Опыт работы с потоками, GCD',
#  'Опыт работы с CoreData',
#  'Понимание блоков, делегатов, ARC',
#  'Знать что такое REST',
#  'Опыт работы в качестве системного аналитика в проектах разработки и внедрения ПО ',
#  'Опыт разработки спецификаций к программным продуктам',
#  'Наличие практического опыта разработки эксплуатационных требований к АС;',
#  'Общее понимание современной архитектуры контактных центров',
#  'Знание методик и инструментов системного анализа, описания бизнес-процессов',
#  'Навыки моделирования для предоставления требований',
#  'Опыт работы с реляционными БД, знание SQL',
#  'Знание технологий обработки вызовов и принципов работы КЦ',
#  'Условия работы:',
#  'Основы архитектуры АС, технологии интеграции, форматы и стандарты веб (обязательно);',
#  'Логическая модель структур реляционной БД, ER-диаграммы, типы данных, нормализация, ключи, индексы, триггеры, нереляционные БД (обязательно);',
#  'UML (обязательно);',
#  'Принципы работы ДБО (желательно);',
#  'Принципы работы платежных систем (желательно);',
#  'Различные методологии разработки ПО (желательно);',
#  'BPMN (обязательно);',
#  'Основы SQL (обязательно) и продвинутый SQL (желательно);',
#  'Основы тестирования и управления дефектами (обязательно);',
#  'Опыт работы в отделе ИТ банка или иной финансовой организации (желательно);',
#  'Техническое образование (обязательно).',
#  'Экспертные знания в области платформ Avaya;',
#  'Наличие практического опыта построения платформенных решений, разработки эксплуатационных требований к АС;',
#  'Общее понимание современной архитектуры контактных центров',
#  'Опыт работы с SIP-телефонией;',
#  'Опыт администрирования / построения автоматизированных систем контактных центров не менее 7 лет.',
#  'Условия работы:',
#  'Опыт коммерческой работы на Java от 2х лет',
#  'Опыт настройки высоконагруженных приложений',
#  'Знание архитектурных паттернов',
#  'Умение писать unit и функциональные тесты',
#  'Умение работать с командной строкой linux',
#  'Понимание многопоточности',
#  'Знание алгоритмов и структур данных',
#  'Английский на уровне чтения технической документации',
#  'Опыт выполнения архнадзора и code-review',
#  'Условия работы:',
#  'Высшее техническое образование;',
#  'Знание стека ELK, навыки настройки Elasticsearch и написания конфигов для Logstash;',
#  'Опыт работы с инстурментарием DevOps (Jenkins, Ansible, BitBucket, nexus). Опыт написания скриптов ansible;',
#  'Наличие практического опыта разработки эксплуатационных требований к АС;',
#  'Наличие практического опыта построения платформенных решений, разработки эксплуатационных требований к АС;',
#  'Общее понимание современной архитектуры контактных центров;',
#  'Экспертные знания в области платформ Java, IBM WAS, Apache tomcat, MS IIS; платформ виртуализаци, операционных систем класса Unix, Windows;',
#  'Опыт работы с реляционными БД, знание SQL;',
#  'Знание одного из скриптовых языков – python или bash;',
#  'Знание voicexml, yml;',
#  'Желателен опыт работы с балансировщиками nginx;',
#  'Опыт работы администрирования / построения автоматизированных систем контактных центров не менее 5 лет.',
#  'Разрабатывать микросервисы, интеграционные решения с основными продуктами Банка',
#  'Писать авто и юнит тесты',
#  'Работать в 2х недельных SCRUM спринтах.',
#  'Профессиональные компетенции',
#  'Опыт разработки приложений с использованием Java-технологий от 3-5 лет',
#  'Хорошее владение Java (core), желательно знание стека Spring, JavaEE',
#  'Опыт работы с многопоточностью',
#  'Опыт работы с серверами приложений WebSphere AS, WildFly, Tomcat etc.',
#  'Опыт написания unit-тестов',
#  'Знание основных паттернов разработки ПО',
#  'Знание алгоритмов, структур данных',
#  'Понимание методологий разработки ПО: Agile, Kanban',
#  'Опыт работы с системами контроля версий (SVN, Git)',
#  'Опыт управления командой разработчиков',
#  'знание Objective-C;',
#  'опыт коммерческой разработки iOS-приложений не менее года;',
#  'опыт параллельного и многопоточного программирования;',
#  'опыт разработки сетевых приложений как на уровне сокетов, так и на уровне HTTP;',
#  'опыт работы с Core Data;',
#  'опыт работы с Core Graphics;',
#  'опыт работы с XML-парсером в iOS SDK;',
#  'умение разбираться и работать с чужим кодом.',
#  'последний год вы работали в аналогичной должности.',
#  'опыт работы в Agile;',
#  'знакомство с инструментарием создания и проведения тестов;',
#  'знание распределенных систем контроля версий (Git);',
#  'опыт работы с bug tracking system;',
#  'опыт работы в команде.',
#  'опыт работы в Agile;',
#  'знакомство с инструментарием создания и проведения тестов;',
#  'знание распределенных систем контроля версий (Git);',
#  'опыт работы с bug tracking system;',
#  'опыт работы в команде.',
#  'опыт работы с построением архитектур. (идеально - образовательная область).',
#  '\\u200b\\u200b\\u200b\\u200b\\u200b\\u200b\\u200bаудит существующих решения и создать единую взаимодополняющую архитектуру.',
#  'опыт проблем солвера и креатора',
#  'желательно бывший программист без привязки к языкам.',
#  'опыт в сетях, баз данных, построении приложений.',
#  'понимание ООП',
#  ' Высшее образование;',
#  ' Опыт разработки на языке Java от 3 лет (хорошие знания стека: collections, multithreading, JMM, JVM internal);',
#  ' Хорошее ориентирование в современном стеке Java-технологий;',
#  ' Опыт работы с серверами приложений (настройка, оптимизация);',
#  ' Чёткое понимание цикла разработки ПО (ведение разработки от бизнес-требований до внедрения, работа с репозиториями, несколькими контурами);',
#  ' Знание стандартных алгоритмов и структур данных;',
#  ' Знание принципов и технологий построения распределенных систем;',
#  ' Опыт работы с СУБД (предпочтительней Oracle);',
#  ' Опыт работы со Spring (Core, Security, Integration, AOP, etc.);',
#  ' Знание инфраструктуры разработки (GIT, Jira, Confluence);',
#  ' Опыт работы с Linux-системами (продвинутый пользователь);',
#  ' Приветствуется опыт разработки промышленных бизнес критических систем.',
#  'Условия работы:',
#  'разработка web-приложений на PHP;',
#  'знание Yii2 (PHP-framework), PHP5 ООП и Git;',
#  'владение HTML\\\\Javascript\\\\CSS, MySQL (уровень построения запросов) и Linux (LAMP).',
#  'Специалист, умеющий описывать и декомпозировать бизнес-процессы и системы на составные элементы, разрабатывать функциональные и нефункциональные требования к ИТ-системам, проводить комплексное тестирование и документировать результаты.',
#  'Опыт работы аналитиком от 1 года;',
#  'Желателен опыт работы над продуктами в контактных центрах, digital, web, mobile продуктами и системами;',
#  'Крайне желателен опыт написания или использования готовых скриптов автоматизированного тестирования ИТ-систем, документирования результатов тестирования;',
#  'Большим плюсом будет практический опыт работы с agile/scrum методологией.',
#  'Уверенные знания ОС Linux (преимущественно RHEL);',
#  'Знание CI/CD (Jenkins);',
#  'Знание скриптовых языков Bash, Python;',
#  'Знание языка SQL;',
#  'Знание Git;',
#  'Знание серверов приложений (IBM WAS, WildFly, Tomcat);',
#  'Понимание принципов работы основных сетевых сервисов DNS, DHCP, HTTP, IMAP, POP, SMTP, TCP/IP;',
#  'Опыт настройки, оптимизации и резервного копирования PostgreSQL;',
#  'Опыт работы с системами управления конфигурацией (преимущественно Ansible);',
#  'Опыт работы с ELK Stack;',
#  'Опыт работы с системами мониторинга Prometeus, Zabbix.',
#  'Высшее техническое, ИТ образование;',
#  'Промышленный опыт разработки на Java;',
#  'Знание стека технологий Java (J2EE, J2SE), Spring, Hibernate, jms;',
#  'Опыт работы с реляционными СУБД (предпочтительно Oracle);',
#  'Опыт работы с одним из серверов приложений: WebSphere, Weblogic, JBoss, Tomcat;',
#  'Опыт работы с инструментами – intellij IDEA, SonarQube, nginx\\u200b;',
#  'Опыт работы с брокерами сообщений Kafka/MQ',
#  'Желателен опыт работы с DevOps - pipeline, liquebase, WAS, Jenkins;',
#  'Навыки работы в Linux, bash;',
#  'Опыт разработки Unit-тестов, использования инструментов покрытия тестами;',
#  'Базовые знания по разработке функциональных автотестов;',
#  'Знание алгоритмов и структур данных;',
#  'Отличное знание SQL;',
#  'Знание и умение работать с инструментами контроля версий (git,svn и прочие)',
#  'Желание постоянно расти и развиваться;',
#  'Опыт работы с командами Data Science;',
#  'Опыт внедрение моделей разработанных Data Scientist’ами ;',
#  'Знание Python;',
#  'Опыт работы с Teradata, Redis, GridGain/Apache Ignite;',
#  'Опыт разработки на Hadoop (Hive, Spark, HBase);',
#  'Опыт работы с Docker;',
#  'br/',
#  '- Опыт в сфере тестирования от 1 года;',
#  'br/',
#  '- Понимание процессов разработки и жизненного цикла ПО, основ тестирования;',
#  'br/',
#  '- Знание этапов жизненного цикла дефектов;',
#  'br/',
#  '- Опыт работы с системами управления тестирования (HP ALM/Attlasian Jira);',
#  'br/',
#  '- Опыт интеграционного тестирования ПО и использования инструментов API;',
#  'br/',
#  '- Умение работать с XML/Json;',
#  'br/',
#  '- Навыки тест-дизайна; тестовой аналитики',
#  'br/',
#  '- Знание специфики тестирования мобильных приложений/Web',
#  'br/',
#  '- Приветствуется практический опыт работы в Agile (SCRUM/Kanban).',
#  'br/',
#  '- Опыт работы с системой контроля версий GIT.',
#  '- Высшее математическое/финансовое/техническое образование;',
#  '- Знание способов финансового и операционного моделирования;',
#  '- Навыки построения экономических и операционных моделей;',
#  '- Реализация и внедрение решений;',
#  '- Знание SQL, Python, Teradata',
#  'Условия работы:',
#  'высшее образование;',
#  'опыт написания тестовых сценариев;',
#  'опыт проведения функционального, модульного, интеграционного тестирования;',
#  'знание SQL на уровне написания простых запросов;',
#  'опыт работы с системами JIRA/ HP ALM;',
#  'опыт тестирования пользовательских интерфейсов (Web-based, Mobile(IOS,Android), Desktop);',
#  'Знание и понимание методик тестирования;',
#  'Опыт тестирования API;',
#  'Коммуникационные навыки и умение работать в команде;',
#  'умение и готовность общаться с аналитиками, разработчиками;',
#  'активная и ответственная позиция по работе с системой.',
#  'опыт автоматизированного или нагрузочного тестирования;',
#  'опыт работы с Oracle DB: составление SQL запросов, чтение pl/sql процедур.',
#  '∙ Опыт работы и уверенные знания Java (Core, Collection framework, Servlets)',
#  '∙ Опыт работы и уверенные знания основных модулей Spring Framework',
#  '∙ Опыт работы и уверенные знания JPA (опыт работы с реализациями Hibernate/OpenJPA)',
#  '∙ Опыт разработки по методологии TDD и знание основных инструментов (TestNG/JUnit, Mockito)',
#  '∙ Опыт разработки REST-сервисов (с пониманием основных принципов обеспечения обратной совместимости)',
#  '∙ Понимание основных шаблонов проектирования',
#  ...]

# %%
listok = ['1','23','21','231','21','23','1','132','213','132']
a = list(filter(lambda a: a != '123', listok)
# Out:
#   File "<ipython-input-93-de9744c9c938>", line 2
#     a = list(filter(lambda a: a != '123', listok)
#                                                  ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # USELESS

# %%
main_list = []
for i in p_list:
    if "<span>" in i:
        texttest = i
        teststrong = texttest.split('<span>')
        cur_list = [j.split('</span>') for j in teststrong if '</span>' in j] 
        main_list.append(cur_list)

# %%
main_list
# Out:
# [[['Цели и задачи:',
#    '<ul><li>реализация задач бэклога</li><li>работа с дефектами и инцидентами</li><li>поддержка поставок при установке на тестовые и промышленный контур</li></ul>'],
#   ['Требования к кандидату:',
#    '<ul><li>Java 8 (Collections, Threading, отладка производительности)</li><li>Spring Boot (1.х, 2.х)</li><li>Знание TSQL (реляционные БД, индексы, транзакции)</li></ul>'],
#   ['Плюсом будет:',
#    '<ul><li>Опыт работы с Hibernate</li><li>Опыт работы с Netty 4</li><li>Знание фреймворков тестирования (TestNG, JUnit).</li><li>Знание Linux (RHEL, CentOS) на уровне локального администратора.</li><li>Знание принципов работы сети.</li><li>Опыт работы с Ansible (роли, инвентори, деплой на windows, ansible-vault)</li><li>Опыт работы с Jenkins (pipeline, declarative groovy dsl)</li><li>Опыт работы с Google Protobuff</li><li>Опыт работы с Git (gitflow)</li><li>Опыт работы с Maven</li><li>Опыт работы с Java-doc</li><li>Опыт работы с Sonatype Nexus (хранение бинарных файлов)</li><li>Опыт работы с SonarQube (статический анализ кода)</li><li>Опыт разработки веб-сервисов (с использованием rest)</li><li>Опыт проведения нагрузочного тестирования (используем HP Performance Center - LoadRunner)</li><li>Опыт работы с Jira, Confluence, Bitbucket</li></ul><div><p></p><p><b>Условия работы:</b></p><ul><li>Работа среди профессионалов банковского дела;</li><li>Профессиональное обучение и развитие;</li><li>Мотивирующая система оплаты труда;</li><li>Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);</li><li>Участие в интересных и инновационных проектах;</li><li>Отличные возможности для самореализации, результаты, которыми можно гордиться;</li><li>Высокий уровень корпоративной культуры;</li><li>Многофункциональный спортивный зал (бесплатно);</li><li>Вместительный паркинг.</li></ul></div></div>']],
#  [[' ', '', '</b>'],
#   ['<b> </b>', '<b>предприниматель - клиент Сбербанка,'],
#   [' ', '</b>', '<b>'],
#   ['c', ''],
#   ['мог решить любой вопрос за секунды через интернет или контактный центр',
#    '</b>'],
#   ['<b> </b>',
#    '<b>ц</b>ентра корпоративных решений корпоративного блока. Наша миссия превратить Сбербанк в Банк Секунд.',
#    '</p><p></p><p>'],
#   [' ', '<b>Владельца ИТ-продукта,'],
#   [' ',
#    '</b>чтобы он вместе с командой из 9 человек разрабатывал ПО для сотрудников контактных центров и предпринимателей-клиентов Банка. Создавал и внедрял прорывные технологии для улучшения клиентского опыта.',
#    '</p><p></p><p><b>'],
#   ['О продукте: <p></p>', '</b></p><p>'],
#   [' ', '', '', ''],
#   ['Ко-браузинг – новый продукт Корпоративного блока, который позволит быстрее и эффективнее обслуживать клиентов Сбербанка удаленно. <p></p>',
#    '</p><p>'],
#   [' ', '', '', ''],
#   ['Ко-браузинг – это возможность подключения сотрудника контактного центра к клиенту в доступном канале коммуникации для диагностики проблем, навигации по сайту, а также осуществления активных действий со стороны клиента в момент обращения.<p></p>',
#    '</p><p><b>'],
#   ['Нам нужны креативные лидеры новой формации, готовые:',
#    '</b></p><p><b></b></p><p>'],
#   [' ', '', '', ''],
#   [' ', '<b>реальную</b>'],
#   [' ', 'ценность для клиента;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   [' ', '<b>в гибком режиме'],
#   [' ', '</b>', '<b>'],
#   ['Agile', '</b><b>'],
#   [';', '</b></p><p></p><p>'],
#   [' ', '', '', '<b>'],
#   ['Вместе с командой', '</b>'],
#   [' ', '', ''],
#   ['достигать общие цели.', '</p><p></p><p><b>'],
#   ['Ежедневные задачи для нашего владельца продукта:',
#    '</b></p><p><b></b></p><p>'],
#   [' ', '', '', ''],
#   ['Формирование видения и дорожной карты продукта;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Вовлечение заинтересованных лиц в создание требований;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Управление бэклогом и расстановка приоритетов для команды;',
#    '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Управление ожиданиями и сроками поставки функциональности потребителю;',
#    '</p><p></p><p>'],
#   [' ', '', '', ''],
#   [' ', '', ''],
#   [' ', '', ''],
#   ['церемоний: Стендап, Планирование, Демо и др.;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Внедрение результатов работы команды и передача продукта в эксплуатацию.',
#    '</p><p></p><p><b>'],
#   ['Мы ожидаем от Вас:', '</b></p><p><b></b></p><p>'],
#   [' ', '', '', ''],
#   ['Опыт работы владельцем продукта или менеджером проекта не менее 3-х лет;',
#    '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Подтвержденный опыт разработки и внедрения цифровых продукт', ''],
#   [';', '', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Опыт управления командой разработки;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Знание современных технологий и инфраструктуры;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Самобытность и самостоятельность;', '</p><p></p><p>'],
#   [' ', '', '', ''],
#   ['Высшее образование.', '</p><p></p><p><b>'],
#   ['От нас:', '</b>'],
#   ['<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Работа среди профессионалов банковского дела;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Профессиональное обучение и развитие;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Мотивирующая система оплаты труда;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);<p></p>',
#    '</p><p>'],
#   [' ', '', '', ''],
#   ['Участие в интересных и инновационных проектах;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Отличные возможности для самореализации, результаты, которыми можно гордиться;<p></p>',
#    '</p><p>'],
#   [' ', '', '', ''],
#   ['Высокий уровень корпоративной культуры;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Отличный новый офис «Sbergile Home» в шаговой доступности от ст. Кутузовская (метро и МЦК);<p></p>',
#    '</p><p>'],
#   [' ', '', '', ''],
#   ['Многофункциональный спортивный зал (бесплатно).<p></p>', '</p><p>'],
#   ['<p></p>', '</p><div></div></div>']],
#  [['Обязанности:', '</b></p><p>'],
#   ['· Исследование и анализ различных систем Банка для извлечения значимой информации',
#    '</p><p>'],
#   ['· Загрузка и подготовка витрин данных из внутренних и внешних источников Банка для дальнейшего использования для разработки/обучения моделей',
#    '</p><p>'],
#   ['· Исследование качества данных в источниках', '</p><p>'],
#   ['· Документирование результатов и подготовка постановки на промышленную реализацию витрин данных',
#    '</p><p><b>'],
#   ['Требования:', '</b></p><p>'],
#   ['Обязательно', '</p><p>'],
#   ['· Владение инструментарием / технологиями анализа / обработки данных (SQL / ETL );',
#    '</p><p>'],
#   ['· Опыт работы с построением аналитических витрин;', '</p><p>'],
#   ['· Опыт работ с одной из промышленных СУБД (Oracle, MS SQL и т.д.)',
#    '</p><p>'],
#   ['Как плюс', '</p><p>'],
#   ['· Работа в роли системного/бизнес аналитика или разработчика Хранилищ данных;',
#    '</p><p>'],
#   ['· Знание предметной области банковских рисков, розничного или корпоративного кредитования',
#    '</p><p>'],
#   ['· Опыт работы с технологиями BigData (Hadoop, Hive, Spark и т.д.)',
#    '</p><p>'],
#   ['· Умение применять языки программирования (Python, SAS и пр.);',
#    '</p><p> </p><div><p></p><p><b>Условия работы:</b></p><p><b>'],
#   ['Условия:', '</b></p><p>'],
#   ['· Работа в крупной стабильной компании;', '</p><p>'],
#   ['· Профессиональный рост, обучение и сертификация за счет компании;',
#    '</p><p>'],
#   ['· Высокая 100% белая заработная плата (оклад и премии);', '</p><p>'],
#   ['· Льготные условия по кредитам Сбербанка;', '</p><p>'],
#   ['· ДМС, страхование от несчастных случаев, социальные гарантии, корпоративные мероприятия.',
#    '</p></div></div>']],
#  [['Обязанности:', '</b></p><p>'],
#   ['· Исследование и анализ различных систем Банка для извлечения значимой информации',
#    '</p><p>'],
#   ['· Загрузка и подготовка витрин данных из внутренних и внешних источников Банка для дальнейшего использования для разработки/обучения моделей',
#    '</p><p>'],
#   ['· Исследование качества данных в источниках', '</p><p>'],
#   ['· Документирование результатов и подготовка постановки на промышленную реализацию витрин данных',
#    '</p><p>'],
#   ['· Развитие направления DE, выработка подходов, шаблонов, принципов работы DE, набор и обучение членов команды;',
#    '</p><p><b>'],
#   ['Требования:', '</b></p><p>'],
#   ['Обязательно', '</p><p>'],
#   ['· Владение инструментарием / технологиями анализа / обработки данных (SQL / ETL );',
#    '</p><p>'],
#   ['· Опыт работы с построением аналитических витрин;', '</p><p>'],
#   ['· Опыт работ с одной из промышленных СУБД (Oracle, MS SQL и т.д.)',
#    '</p><p>'],
#   ['Как плюс', '</p><p>'],
#   ['· Работав роли системного/бизнес аналитика или разработчика Хранилищ данных;',
#    '</p><p>'],
#   ['· Знание предметной области банковских рисков, розничного или корпоративного кредитования',
#    '</p><p>'],
#   ['· Опыт работы с технологиями BigData (Hadoop, Hive, Spark и т.д.)',
#    '</p><p>'],
#   ['· Умение применять языки программирования (Python, SAS и пр.);',
#    '</p><p> </p><div><p></p><p><b>Условия работы:</b></p><p><b>'],
#   ['Условия:', '</b></p><p>'],
#   ['· Работа в крупной стабильной компании;', '</p><p>'],
#   ['· Профессиональный рост, обучение и сертификация за счет компании;',
#    '</p><p>'],
#   ['· Высокая 100% белая заработная плата (оклад и премии);', '</p><p>'],
#   ['· Льготные условия по кредитам Сбербанка;', '</p><p>'],
#   ['· ДМС, страхование от несчастных случаев, социальные гарантии, корпоративные мероприятия.',
#    '</p></div></div>']],
#  [['Подбираем разработчика в команду Платформы поддержки развития бизнеса. Партнеры POS.',
#    '',
#    '</p><p>'],
#   ['Команда занимается разработкой модуля для ведения условий, на которых Партнеры (юридические лица) могут осуществлять продажу товаров в Кредит Физическим лицам.',
#    '',
#    '</p><p> </p><p>'],
#   ['Основная задача – разработка функционала на Java 8. Сейчас команда заканчивает тестировать модуль и должна внедрить MVP. В 2019 году планируется расширение функционала модуля, возможно, переход на базовые платформенные сервисы.<br/>Это маленький винтик в большом проекте «Покупай со Cбербанком»',
#    '',
#    '</p><p> </p><p>'],
#   ['Требования к кандидату:', '', '</p><p>'],
#   ['-Опыт работы с Java от 3 лет<br/>-Желание и умение писать красивый и качественный код, за который потом не будет стыдно перед командой<br/>-Понимание, что такое SOLID',
#    '',
#    '</p><p> </p><p>'],
#   ['Мы ждем, что кандидат уверенно владеет:<br/>Java Core<br/>Spring Framework<br/>Hibernate<br/>Maven<br/>Git',
#    '',
#    '</p><p> </p><p>'],
#   ['Будет плюсом опыт работы с:<br/>React,<br/>Oracle,<br/>Gradle,<br/>Kotlin,<br/>Настройка Jenkins',
#    '',
#    '</p><p> </p><p>'],
#   ['Сертификат OCJP приветствуется', '', '</p><p> </p><p>'],
#   ['Наши условия:', '', '</p><p>'],
#   ['-Пятидневная рабочая неделя', '', '</p><p>'],
#   ['-Зарплата: оклад+годовая премия', '', '</p><p>'],
#   ['-Рабочее место на Энгельса 36', '', '</p><p>'],
#   ['-Официальное трудоустройство в ПАО Сбербанк', '', '</p><p>'],
#   ['-Бессрочный трудовой договор', '', '</p><p>'],
#   ['-Программа ДМС', '', '</p><p>'],
#   ['-Возможность роста и развития внутри компании',
#    '',
#    '</p><div></div></div>']],
#  [['WFM',
#    ' в роли аналитика (согласование с бизнес заказчиками правил и моделей, настройка правил построения смен, предпочтений и контрактов операторов Контактного центра и проч.);</li><li>Взаимодействие с инженерами по внедрению в ходе реализации проекта;</li><li>Общение с пользователями, проведение тренингов по внедренной платформе '],
#   ['WFM',
#    ';</li><li>Разработка пользовательской документации;</li><li>Подготовка бизнес-требований'],
#   ['.',
#    '<p></p></li></ul><p><b></b></p><p><b> </b></p><p><b>Требования:</b></p><ul><li>Опыт работы с системами '],
#   ['WFM', ';</li><li>Способность к быстрому обучению другим платформам '],
#   ['WFM',
#    ', не входящих в базовую компетенцию кандидата, от различных вендоров;</li><li>Ориентированность на результат, способность к работе в режиме сжатых сроков проекта;</li><li>Желательно: наличие сертификатов от вендоров '],
#   ['WFM',
#    ', подтверждающих компетенцию и специализацию;</li><li>Опыт написания пользовательской документации'],
#   ['.', ''],
#   [' ',
#    '<p></p></li></ul><p></p><p> </p><p><b>Условия:</b></p><ul><li>Работа среди профессионалов банковского дела;</li><li>Профессиональное обучение и развитие;</li><li>Мотивирующая система оплаты труда;</li><li>Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);</li><li>Участие в интересных и инновационных проектах;</li><li>Отличные возможности для самореализации, результаты, которыми можно гордиться;</li><li>Высокий уровень корпоративной культуры;</li><li>Отличный новый офис «Sbergile Home» в шаговой доступности от ст. Кутузовская (метро и МЦК);</li><li>Многофункциональный спортивный зал (бесплатно);</li><li>Вместительный подземный паркинг.<p></p></li></ul><div></div></div>']],
#  [['Цель нашей команды сделать удобную и функциональную Базу знаний для сотрудников Банка, которые обслуживают более 1 000 000 корпоративных клиентов.<p></p>',
#    '</p><p>'],
#   ['<p> </p>', '</p><p>'],
#   ['Нашим сервисом уже пользуются более 3 000 сотрудников контактного центра и банка и это не предел, наши амбиции – более 20 тыс. пользователей.<p></p>',
#    '</p><p>'],
#   ['<p> </p>', '</p><p>'],
#   ['Мы ищем разработчика-профессионала, который готов не просто делать таски, а помогать бизнесу решать его задачи. Поэтому разработчик и бизнес сидят рядом и часто общаются.<p></p>',
#    '</p><ul><li>'],
#   ['В своей работе мы используем принципы Agile;', '</li><li>'],
#   ['Даем и показываем результат спринтами (длина 3 недели);', '</li><li>'],
#   ['Готовы в процессе разработки гибко подстраиваться под требования заказчика;',
#    '</li><li>'],
#   ['Для нас сделано это когда фича работает на prode, поэтому релизимся максимально часто;',
#    '</li><li>'],
#   ['Ищем баланс между скорость и качеством разработки.', '</li></ul><p><b>'],
#   ['<p> </p>', '</b></p><p><b>'],
#   ['Мы ждем что вы:<p></p>', '</b></p><ul><li><b>'],
#   ['<p> </p>', '</b>'],
#   ['Знаете и уверенно владеете технологиями: ', ''],
#   ['JAVA', ''],
#   [', ', ''],
#   ['OSGI', ''],
#   [', ', ''],
#   ['Java', ''],
#   [' ', ''],
#   ['Script', ''],
#   [', ', ''],
#   ['jQuery', ''],
#   [', ', ''],
#   ['LESS', ''],
#   [', ', ''],
#   ['CSS', ''],
#   [', ', ''],
#   ['HTML', ''],
#   [', ', ''],
#   ['SQL', ''],
#   [';', '</li><li>'],
#   ['Знаете и имеете опыт работы с:<p></p>', '</li></ul><p>'],
#   ['- ', ''],
#   ['фреймворками', ''],
#   [': Spring, React / AngularJS;<p></p>', '</p><p>'],
#   ['- ', ''],
#   ['шаблонизаторами', ''],
#   [' (', ''],
#   ['мы', ''],
#   [' ', ''],
#   ['используем', ''],
#   ['Apache Velocity, Closure Templates);<p></p>', '', '</p><p>'],
#   ['- системами контроля версий (', ''],
#   ['Git', ''],
#   [');', '</p><p>'],
#   [' ', '', '', ''],
#   ['Знаете технический английский язык;', '</p><p>'],
#   ['<p></p>', ''],
#   [' ', '', '', ''],
#   ['Владеете гибкими методиками разработки ПО (', ''],
#   ['Agile', ''],
#   [') и умеете выстраивать процесс по ним.<p></p>', '</p><p><b>'],
#   ['<p> </p>', '</b></p><p><b>'],
#   ['Будет большим плюсом:<p></p>', '</b></p><p>'],
#   [' ', '', '', ''],
#   ['Опыт разработки для продуктов Atlassian (', ''],
#   ['Confluence', ''],
#   [', ', ''],
#   ['Jira', ''],
#   [');<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Знание и понимание принципов работы Apache Lucene;<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Опыт работы с СУБД ', ''],
#   ['PostgreSQL', ''],
#   [';<p></p>', '</p><p>'],
#   [' ', '', '', ''],
#   ['Базовые навыки работы в ', ''],
#   ['bash', ''],
#   ['.<p></p>', '</p><p>'],
#   ['<p> </p>', '</p><p>'],
#   ['<p> </p>', '</p><p><b>'],
#   ['Обязанности:', '</b></p><ul><li>'],
#   ['Разработка новых плагинов и доработок для ', ''],
#   ['Atlassian', ''],
#   [' ', ''],
#   ['Confluence', ''],
#   [';', '</li><li>'],
#   ['Разработка сервиса аналитики для оперативной и ', ''],
#   ['of', ''],
#   ['-', ''],
#   ['line', ''],
#   [' ', ''],
#   ['отчетности;', '</li><li>'],
#   ['Разработки интеграций с другими системами;', '</li><li>'],
#   ['Выстраивание процесса разработки и управление командой разработки.<p></p>',
#    '</li></ul><p>'],
#   ['<p> </p>', '</p><p><b>'],
#   ['Условия', '</b></p><ul><li>'],
#   ['Работа среди профессионалов банковского дела;', '</li><li>'],
#   ['Профессиональное обучение и развитие;', '</li><li>'],
#   ['Мотивирующая система оплаты труда;', '</li><li>'],
#   ['Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);',
#    '</li><li>'],
#   ['Участие в интересных и инновационных проектах;', '</li><li>'],
#   ['Отличные возможности для самореализации, результаты, которыми можно гордиться;',
#    '</li><li>'],
#   ['Высокий уровень корпоративной культуры;', '</li><li>'],
#   ['Отличный новый офис «Sbergile Home» в шаговой доступности от ст. Кутузовская (метро и МЦК);',
#    '</li><li>'],
#   ['Многофункциональный спортивный зал (бесплатно);', '</li><li>'],
#   ['Вместительный подземный паркинг.<p></p>', '</li></ul><div></div></div>']],
#  [['<b>Желаемый предыдущий опыт и требования к кандидату:</b>',
#    '</p><ul><li>'],
#   ['Опыт в автоматизации тестирования (Java, Javascript, Selenium Webdriver, Junit, TestNG);',
#    '</li><li>'],
#   ['Знание теории тестирования;', '</li><li>'],
#   ['Знание жизненного цикла ПО и дефекта;', '</li><li>'],
#   ['Опыт проведения ручного функционального, интеграционного тестирования;',
#    '</li><li>'],
#   ['Знание SQL на уровне написания простых запросов, опыт работы с СУБД Oracle;',
#    '</li><li>'],
#   ['Знания инструментов сборки (Maven);', '</li><li>'],
#   ['Опыт работы с системами контроля версии (git); ', '</li><li>'],
#   ['Готовность к работе с новым ПО.', '</li></ul><p>'],
#   ['<b>Желательно:</b>', '</p><ul><li>'],
#   ['Практический опыт работы по Agile;', '</li><li>'],
#   ['Опыт разработки эмуляторов/заглушек;', '</li><li>'],
#   ['Опыт написания тестовых сценариев;', '</li><li>'],
#   ['Знание практик DevOps (Continuous Integration, Continuous Delivery, Continuous Deployment) и опыт работы с инструментами (Jenkins, Ansible).',
#    '</li></ul><p> </p><p>'],
#   ['<b>Что нужно будет делать:</b>', '</p><p> </p><ul><li>'],
#   ['Разработка автотестов по готовым тесткейсам c последующей актуализацией;',
#    '</li><li>'],
#   ['Встраивание автотестов в целевую схему Сбербанка', '</li><li>'],
#   ['Анализ результатов прогонов автотестов, работа с логами;', '</li><li>'],
#   ['Настройка тестового окружения;', '</li><li>'],
#   ['Коммуникации с вовлеченными в процесс участниками.',
#    '</li></ul><p> </p><p>'],
#   ['<b>Что не нужно будет делать:</b>', '</p><ul><li>'],
#   ['Писать тесткейсы, которые позже будут автоматизированы', '</li><li>'],
#   ['Много заниматься ручным тестированием (но быть готовым помочь команде при регрессе)',
#    '</li></ul><p></p><p></p><div></div></div>']],
#  [['Задачи:', '</b>', '</p><ul><li>'],
#   ['Подготовка встреч, совещаний, проводимых руководителем;', '', '</li><li>'],
#   ['Сбор необходимых материалов, оповещение участников о времени совещания, месте проведения и повестке дня, протоколирование;',
#    '',
#    '</li><li>'],
#   ['Ведение деловой переписки, подготовка писем, запросов, служебных записок и других документов по поручению руководства;',
#    '',
#    '</li><li>'],
#   ['Работа с поручениями: доведение до сотрудников, контроль исполнения ответственными сотрудниками распоряжений и указаний руководителя;',
#    '',
#    '</li><li>'],
#   ['Информационно-аналитическая поддержка руководителя;', '', '</li><li>'],
#   ['Взаимодействие и решение оперативных вопросов с соответствующими подразделениями компании.',
#    '',
#    '</li></ul><p> </p><p>'],
#   ['Мы ценим своих сотрудников и предлагаем:', '</b>', '</p><ul><li>'],
#   ['Работа в команде профессионалов;', '', '</li></ul><ul><li>'],
#   ['ДМС, тренажерный зал, ежегодное обучение;', '', '</li></ul><ul><li>'],
#   ['График работы – стандартный, но с гибким подходом;',
#    '',
#    '</li></ul><ul><li>'],
#   ['Широкий спектр дисконт–программ, скидок и привилегий от компаний-партнеров;',
#    '',
#    '</li></ul><ul><li>'],
#   ['Льготное кредитование в Сбербанке;', '', '</li></ul><div></div></div>']],
#  [['Управление реестром бизнес-сервисов/процессов Банка и Экосистемы (обеспечение консистентности и переиспользования бизнес-сервисов, выявление дублирования);',
#    '',
#    '</li><li>'],
#   ['Валидация и разработка/ актуализация карт бизнес-сервисов подразделений Банка;',
#    '',
#    '</li><li>'],
#   ['Валидация Корпоративных Архитектур функциональных областей в части бизнес-архитектуры;',
#    '',
#    '</li><li>'],
#   ['Разработка методологии и стандартов проектирования бизнес-архитектуры;',
#    '',
#    '</li><li>'],
#   ['Формирование требований на доработку инструментов управления корпоративной архитектурой Банка;',
#    '',
#    '</li><li>'],
#   ['Разработка и актуализация карты бизнес-компетенций Банка и Экосистемы;',
#    '',
#    '</li><li>'],
#   ['Анализ карты бизнес-компетенций на соответствие Стратегии Банка, проведение gap-анализа;',
#    '',
#    '</li><li>'],
#   ['Подготовка материалов по бизнес-архитектуре для руководства, проведение презентаций для подразделений Банка.',
#    '',
#    '</li></ul><p> </p><p><b><u>Требования:</u></b></p><ul><li>'],
#   ['Высшее образование (предпочтительно ведущих технических ВУЗов);',
#    '',
#    '</li><li>'],
#   ['Опыт написания бизнес-, функциональных требований к продуктам - от 5 лет;',
#    '',
#    '</li><li>'],
#   ['Опыт реализации больших интеграционных проектов в качестве бизнес-аналитика, бизнес-архитектора;',
#    '',
#    '</li><li>'],
#   ['Знание основных продуктов, бизнес-процессов и функциональной структуры банка;',
#    '',
#    '</li><li>'],
#   ['Опыт проведения стратегического анализа, разработки KPI и дашбордов по бизнес-архитектуре Банка;',
#    '',
#    '</li><li>'],
#   ['Навыки ведения переговоров, отличные коммуникативные навыки;',
#    '',
#    '</li><li>'],
#   ['Знание одной из методологий построения Корпоративной архитектуры организации (TOGAF, DoDAF, Gartner-Meta и т.д.);',
#    '',
#    '</li><li>'],
#   ['Знание жизненного цикла разработки продуктов, опыт работы в проектных и Agile командах;',
#    '',
#    '</li><li>'],
#   ['Навыки визуализации идей, подготовки презентаций;', '', '</li><li>'],
#   ['Знание английского языка не ниже Intermediate.',
#    '',
#    '</li></ul><p> </p><div><p></p><p><b>Условия работы:</b></p><p><b><u>Условия</u></b><b><u>:</u></b></p><p> </p><ul><li>'],
#   ['Место работы: м. Ленинский проспект', '', '</li><li>'],
#   ['График работы с 9:00 до 18:00, пятница - до 16:45', '', '</li><li>'],
#   ['Оформление согласно ТК РФ', '', '</li><li>'],
#   ['Социальный пакет: ДМС, спортзал (фитнес, йога), бассейн, возможность обучения за счет компании, льготные условия кредитования',
#    '',
#    '</li><li>'],
#   ['Премии по итогам успешной работы', '', '</li></ul></div></div>']],
#  [['https://www.youtube.com/watch?v=H2duWgKxyQU&amp;list=FLoHSpXwHzoPPzI-QKGmI11Q&amp;index=8&amp;t=104s',
#    '<br/>'],
#   ['https://www.youtube.com/watch?v=DwNU3P2cZUE&amp;list=FLoHSpXwHzoPPzI-QKGmI11Q&amp;index=7&amp;t=17s',
#    '<br/>'],
#   ['https://www.youtube.com/watch?v=QywUpQMkfNM&amp;list=FLoHSpXwHzoPPzI-QKGmI11Q&amp;index=4&amp;t=48s',
#    '<br/>'],
#   ['https://www.youtube.com/watch?v=-NtyYKDA864&amp;list=FLoHSpXwHzoPPzI-QKGmI11Q&amp;index=2&amp;t=10s',
#    ''],
#   ['https://vc.ru/marketing/48169-kak-my-vystraivali-marketing-nebankovskih-servisov',
#    '</p><p> </p><p><b>Обязанности:</b></p><ul><li>Создавать, защищать, имплементировать концепцию SberBusiness ID;</li><li>Продвигать продукт на разных уровнях;</li><li>Отвечать за финансовый результат ;</li><li>Руководить Agile-командой разработки;</li><li>Разрабатывать внутренние нормативные документы по техническому и организационно-финансовому сопровождению;</li><li>Подготавливать и согласовывать договорные отношения с подрядчиками, партнерами и прочими исполнителями;</li><li>Создавать синергетические взаимодействия со смежными продуктами Экосистемы.</li></ul><p> </p><p><b>Требования:</b></p><ul><li>Опыт создания или эффективного использования социальной авторизации;</li><li>Опыт в создании, развитии, монетизации продуктов для массовой аудитории не менее трех лет (IT - или интернет-проекты, телеком, банковская сфера);</li><li>Способность к стратегическому мышлению и при этом – к <b>оперативному руководству;</b></li><li>Глубокие знания продуктового менеджмента;</li><li>Продвинутые презентационные навыки;</li><li>Глубокое понимание процессов создания и разработки продуктов для массовой аудитории;</li><li>Опыт работы в Agile-командах в роли ВП не менее трех лет;</li><li>Аналитическое мышление, способность быстро принимать решения;</li><li>Умение агрегировать и визуализировать большие объёмы разнородной информации.</li></ul><p> </p><p><b>Плюсом будет:</b></p><ul><li>Опыт ведения собственного бизнеса;</li><li>Опыт работы в fintech компаниях и банках;</li><li>Понимание тенденций и перспектив развития fintech рынка;</li><li>Опыт публичных выступлений.<br/></li></ul><p><b><i>В случае заинтересованности, большая просьба зайти по ссылке и пройти небольшое, но важное тестирование!!!</i></b></p><p>https://www.surveymonkey.com/r/CSGRV83 </p><div></div></div>']],
#  [['Разработку уникальных продуктов для крупнейшего банка',
#    '',
#    '',
#    '</li><li>'],
#   ['Перспектива карьерного роста', '', '', '</li><li>'],
#   ['Бесплатное обучение для дальнейшего трудоустройства в штат ',
#    '',
#    '',
#    '</li><li>'],
#   ['Курс проводят наши тимлидами разработки и специалисты с большим опытом',
#    '',
#    '',
#    '</li><li>'],
#   ['Цикл бесплатных практических занятий длится 2,5 месяца ',
#    '',
#    '',
#    '</li><li>'],
#   ['График - 3 занятия в неделю в вечернее время (4 академических часа)',
#    '',
#    '',
#    '</li><li>'],
#   ['Перед оформлением в штат ты пройдешь интервью (После успешного окончания занятий)',
#    '',
#    '',
#    '<br/>'],
#   [' ', '', '<br/>'],
#   ['<u>В программу входит:</u>', '', '</li></ul><ul><li>'],
#   ['TCP/IP, HTTP, рендер', '', '', '</li><li>'],
#   ['Основы HTML/CSS', '', '', '</li><li>'],
#   ['Основы Javascript', '', '', '</li><li>'],
#   ['Современный SPA. Angular, Vue, React', '', '', '</li><li>'],
#   ['Экосистема React', '', '', '</li><li>'],
#   ['Создание своего Workflow', '', '', '<br/>'],
#   [' ', '', '<br/>'],
#   ['<u>Чтобы стать участником, нужно:</u>', '', '</li></ul><ul><li>'],
#   ['Откликнуться на эту вакансию, отправив свое резюме', '', '', '</li><li>'],
#   ['Пройти тестирование и собеседование в Сбербанке', '', '', '</li></ul><p>'],
#   [' ', '', '<br/>'],
#   ['<b>Мы ждем тебя, если:</b>', '', '</p><ul><li>'],
#   ['Если ты знаешь, что HTML не язык программирования', '', '', '</li><li>'],
#   ['Если ты открывал инструменты разработчика в браузере',
#    '',
#    '',
#    '</li><li>'],
#   ['Пробовал писать код на JavaScript или другом языке программирования',
#    '',
#    '',
#    '</li><li>'],
#   ['Если тебе интересна веб разработка и ты хочешь развиваться в этом направлении',
#    '',
#    '',
#    '</li><li>'],
#   ['У тебя есть опыт в разработке ПО или образование - информационные и компьютерные технологии, прикладная математика, физика и другие смежные специальности',
#    '',
#    '',
#    '<br/>'],
#   [' ', '', '<br/>'],
#   ['<u>Будет здорово, если:</u>', '', '</li></ul><ul><li>'],
#   ['Понимаешь основы объектно-ориентированного программирования',
#    '',
#    '',
#    '</li><li>'],
#   ['Использовал систему контроля версий', '', '', '</li><li>'],
#   ['Знаешь алгоритмы и типа данных', '', '', '</li><li>'],
#   ['Знаешь как работает event loop в браузере', '', '', '</li><li>'],
#   ['Использовал Node.js для pet-проектов', '', '', '</li><li>'],
#   ['Если ты умеешь верстать и хочешь развиваться в сторону разработки',
#    '',
#    '',
#    '</li></ul><p>'],
#   [' ', '', '<br/>'],
#   ['<b>Твои возможности при трудоустройстве:</b>', '', '</p><ul><li>'],
#   ['График работы 5/2 (с 10.00 или 9.00)', '', '', '</li><li>'],
#   ['Посещение спортзала ', '', '', '</li><li>'],
#   ['Корпоративные льготы и скидки', '', '', '</li><li>'],
#   ['ДМС', '', '', '</li><li>'],
#   ['Работа в комфортном офисе и в Agile Home Сбербанка', '', '', '</li><li>'],
#   ['Участие в масштабных интересных проектах крупнейшего банка страны',
#    '',
#    '',
#    '</li><li>'],
#   ['Работа в молодой и сильной команде профессионалов', '', '', '</li><li>'],
#   ['Высокая оплата своего труда (оклад, развитая система премирования)',
#    '',
#    '',
#    '</li><li>'],
#   ['Продолжить обучение за счет компании',
#    '',
#    '',
#    '</li></ul><div></div></div>']],
#  [['Сбербанк - крупнейший банк в России (88 млн активных клиентов), один из ведущих международных финансовых институтов. Самый дорогой российский бренд, входящий в топ - 25 брендов мира.',
#    ''],
#   [' Мы создаем новую технологическую ',
#    'платформу, которая обеспечивает безопасность клиентов с помощью данных и алгоритмов.',
#    '',
#    '',
#    '<p>'],
#   ['Мы разрабатываем удобные цифровые решения для наших внутренних клиентов - сотрудников Банка. Наша команда, которая на текущий момент насчитывает уже более 120 сотрудников различных компетенций, создает программный комплекс, обеспечивающий для внутренних клиентов и поставщиков услуг единую точку контакта, канал взаимодействия в процессе заказа различных сервисов.',
#    '</p><p>'],
#   ['Для разработки мобильных решений наша команда ищет ', ''],
#   ['Android', ''],
#   ['-разработчика. Желателен опыт разработки мобильных приложений от 1 года и более.',
#    '</p><p> </p><p><b>'],
#   ['Мы ожидаем, что Вы обладаете следующими знаниями и навыками:',
#    '</b></p><p> </p><p>'],
#   [' ', '', ''],
#   ['Знание Kotlin, Android SDK;', '</p><p>'],
#   [' ', '', ''],
#   ['Знание support library / Jetpack;', '</p><p>'],
#   [' ', '', ''],
#   ['Хорошее понимание модели жизненного цикла activity/fragment;', '</p><p>'],
#   [' ', '', ''],
#   ['Знание специфики разработки под разные версии Android (версии 4 и выше);',
#    '</p><p>'],
#   [' ', '', ''],
#   ['Уверенное Знание принципов ООП;', '</p><p>'],
#   [' ', '', ''],
#   ['Опыт', ''],
#   [' ', ''],
#   ['работы', ''],
#   [' ', ''],
#   ['с', ''],
#   [' REST API (', ''],
#   ['стек', ''],
#   [' Retrofit/Gson/Moshi);', '</p><p>'],
#   [' ', '', ''],
#   ['Приветствуется умение реализовывать нестандартные элементы UI;',
#    '</p><p>'],
#   [' ', '', ''],
#   ['Умение работать с асинхронным кодом (RxJava или корутины);', '</p><p>'],
#   [' ', '', ''],
#   ['Ответственны, хотите работать в команде и развиваться.',
#    '</p><p> </p><p><b>'],
#   ['Вам предстоит:', '</b></p><p> </p><p>'],
#   [' ', '', ''],
#   ['разрабатывать, планировать, и запускать новые функции для десятков тысяч пользователей;',
#    '</p><p>'],
#   [' ', '', ''],
#   ['участвовать в развитии архитектуры в области ', ''],
#   ['Android', ''],
#   ['-разработки;', '</p><p>'],
#   [' ', '', ''],
#   ['использовать современные подходы, инструменты и технологии.',
#    '</p><p> </p><p><b>'],
#   ['Работа у нас — это:', '</b></p><p> </p><p>'],
#   [' ', '', ''],
#   ['команда профессионалов, готовых поддержать ваши инициативы;', '</p><p>'],
#   [' ', '', ''],
#   ['мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;',
#    '</p><p>'],
#   [' ', '', ''],
#   ['возможность работы с новыми технологиями;', '</p><p>'],
#   [' ', '', ''],
#   ['обучение за счёт компании;', '</p><p>'],
#   [' ', '', ''],
#   ['гибкий график;', '</p><p>'],
#   [' ', '', ''],
#   ['ДМС;', '</p><p>'],
#   [' ', '', ''],
#   ['прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.',
#    '</p><div></div></div>']]]

# %%
keywords = ['требования', 'требуется', 'если', 'ждем', 'ждём', 'ожидаем', 'ищем', 'будет', 'компетенции', 'плюсом', 'желательно'
           'знание', 'стек', 'стэк', 'технологии', 'навыки', 'обязательно', 'от вас', 'опыт', 'ожидания']

# %%
requir = []
for i in main_list:
    rab_list = []
    for j in i:
        for k in keywords:
            if k in j[0].lower():
                rab_list.append(j)
    requir.append(rab_list)
requir
# Out:
# [[['Требования к кандидату:',
#    '<ul><li>Java 8 (Collections, Threading, отладка производительности)</li><li>Spring Boot (1.х, 2.х)</li><li>Знание TSQL (реляционные БД, индексы, транзакции)</li></ul>'],
#   ['Плюсом будет:',
#    '<ul><li>Опыт работы с Hibernate</li><li>Опыт работы с Netty 4</li><li>Знание фреймворков тестирования (TestNG, JUnit).</li><li>Знание Linux (RHEL, CentOS) на уровне локального администратора.</li><li>Знание принципов работы сети.</li><li>Опыт работы с Ansible (роли, инвентори, деплой на windows, ansible-vault)</li><li>Опыт работы с Jenkins (pipeline, declarative groovy dsl)</li><li>Опыт работы с Google Protobuff</li><li>Опыт работы с Git (gitflow)</li><li>Опыт работы с Maven</li><li>Опыт работы с Java-doc</li><li>Опыт работы с Sonatype Nexus (хранение бинарных файлов)</li><li>Опыт работы с SonarQube (статический анализ кода)</li><li>Опыт разработки веб-сервисов (с использованием rest)</li><li>Опыт проведения нагрузочного тестирования (используем HP Performance Center - LoadRunner)</li><li>Опыт работы с Jira, Confluence, Bitbucket</li></ul><div><p></p><p><b>Условия работы:</b></p><ul><li>Работа среди профессионалов банковского дела;</li><li>Профессиональное обучение и развитие;</li><li>Мотивирующая система оплаты труда;</li><li>Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);</li><li>Участие в интересных и инновационных проектах;</li><li>Отличные возможности для самореализации, результаты, которыми можно гордиться;</li><li>Высокий уровень корпоративной культуры;</li><li>Многофункциональный спортивный зал (бесплатно);</li><li>Вместительный паркинг.</li></ul></div></div>'],
#   ['Плюсом будет:',
#    '<ul><li>Опыт работы с Hibernate</li><li>Опыт работы с Netty 4</li><li>Знание фреймворков тестирования (TestNG, JUnit).</li><li>Знание Linux (RHEL, CentOS) на уровне локального администратора.</li><li>Знание принципов работы сети.</li><li>Опыт работы с Ansible (роли, инвентори, деплой на windows, ansible-vault)</li><li>Опыт работы с Jenkins (pipeline, declarative groovy dsl)</li><li>Опыт работы с Google Protobuff</li><li>Опыт работы с Git (gitflow)</li><li>Опыт работы с Maven</li><li>Опыт работы с Java-doc</li><li>Опыт работы с Sonatype Nexus (хранение бинарных файлов)</li><li>Опыт работы с SonarQube (статический анализ кода)</li><li>Опыт разработки веб-сервисов (с использованием rest)</li><li>Опыт проведения нагрузочного тестирования (используем HP Performance Center - LoadRunner)</li><li>Опыт работы с Jira, Confluence, Bitbucket</li></ul><div><p></p><p><b>Условия работы:</b></p><ul><li>Работа среди профессионалов банковского дела;</li><li>Профессиональное обучение и развитие;</li><li>Мотивирующая система оплаты труда;</li><li>Расширенный социальный пакет, корпоративные льготы (в т.ч. по внутренним программам кредитования и программам лояльности партнёров);</li><li>Участие в интересных и инновационных проектах;</li><li>Отличные возможности для самореализации, результаты, которыми можно гордиться;</li><li>Высокий уровень корпоративной культуры;</li><li>Многофункциональный спортивный зал (бесплатно);</li><li>Вместительный паркинг.</li></ul></div></div>']],
#  [['Управление ожиданиями и сроками поставки функциональности потребителю;',
#    '</p><p></p><p>'],
#   ['Мы ожидаем от Вас:', '</b></p><p><b></b></p><p>'],
#   ['Мы ожидаем от Вас:', '</b></p><p><b></b></p><p>'],
#   ['Опыт работы владельцем продукта или менеджером проекта не менее 3-х лет;',
#    '</p><p></p><p>'],
#   ['Подтвержденный опыт разработки и внедрения цифровых продукт', ''],
#   ['Опыт управления командой разработки;', '</p><p></p><p>']],
#  [['Требования:', '</b></p><p>'],
#   ['Обязательно', '</p><p>'],
#   ['· Опыт работы с построением аналитических витрин;', '</p><p>'],
#   ['· Опыт работ с одной из промышленных СУБД (Oracle, MS SQL и т.д.)',
#    '</p><p>'],
#   ['· Опыт работы с технологиями BigData (Hadoop, Hive, Spark и т.д.)',
#    '</p><p>']],
#  [['Требования:', '</b></p><p>'],
#   ['Обязательно', '</p><p>'],
#   ['· Опыт работы с построением аналитических витрин;', '</p><p>'],
#   ['· Опыт работ с одной из промышленных СУБД (Oracle, MS SQL и т.д.)',
#    '</p><p>'],
#   ['· Опыт работы с технологиями BigData (Hadoop, Hive, Spark и т.д.)',
#    '</p><p>']],
#  [['Требования к кандидату:', '', '</p><p>'],
#   ['-Опыт работы с Java от 3 лет<br/>-Желание и умение писать красивый и качественный код, за который потом не будет стыдно перед командой<br/>-Понимание, что такое SOLID',
#    '',
#    '</p><p> </p><p>'],
#   ['-Опыт работы с Java от 3 лет<br/>-Желание и умение писать красивый и качественный код, за который потом не будет стыдно перед командой<br/>-Понимание, что такое SOLID',
#    '',
#    '</p><p> </p><p>'],
#   ['Мы ждем, что кандидат уверенно владеет:<br/>Java Core<br/>Spring Framework<br/>Hibernate<br/>Maven<br/>Git',
#    '',
#    '</p><p> </p><p>'],
#   ['Будет плюсом опыт работы с:<br/>React,<br/>Oracle,<br/>Gradle,<br/>Kotlin,<br/>Настройка Jenkins',
#    '',
#    '</p><p> </p><p>'],
#   ['Будет плюсом опыт работы с:<br/>React,<br/>Oracle,<br/>Gradle,<br/>Kotlin,<br/>Настройка Jenkins',
#    '',
#    '</p><p> </p><p>'],
#   ['Будет плюсом опыт работы с:<br/>React,<br/>Oracle,<br/>Gradle,<br/>Kotlin,<br/>Настройка Jenkins',
#    '',
#    '</p><p> </p><p>']],
#  [],
#  [['Мы ищем разработчика-профессионала, который готов не просто делать таски, а помогать бизнесу решать его задачи. Поэтому разработчик и бизнес сидят рядом и часто общаются.<p></p>',
#    '</p><ul><li>'],
#   ['Готовы в процессе разработки гибко подстраиваться под требования заказчика;',
#    '</li><li>'],
#   ['Ищем баланс между скорость и качеством разработки.', '</li></ul><p><b>'],
#   ['Мы ждем что вы:<p></p>', '</b></p><ul><li><b>'],
#   ['Знаете и имеете опыт работы с:<p></p>', '</li></ul><p>'],
#   ['Будет большим плюсом:<p></p>', '</b></p><p>'],
#   ['Будет большим плюсом:<p></p>', '</b></p><p>'],
#   ['Опыт разработки для продуктов Atlassian (', ''],
#   ['Опыт работы с СУБД ', ''],
#   ['Базовые навыки работы в ', '']],
#  [['<b>Желаемый предыдущий опыт и требования к кандидату:</b>',
#    '</p><ul><li>'],
#   ['<b>Желаемый предыдущий опыт и требования к кандидату:</b>',
#    '</p><ul><li>'],
#   ['Опыт в автоматизации тестирования (Java, Javascript, Selenium Webdriver, Junit, TestNG);',
#    '</li><li>'],
#   ['Опыт проведения ручного функционального, интеграционного тестирования;',
#    '</li><li>'],
#   ['Знание SQL на уровне написания простых запросов, опыт работы с СУБД Oracle;',
#    '</li><li>'],
#   ['Опыт работы с системами контроля версии (git); ', '</li><li>'],
#   ['Практический опыт работы по Agile;', '</li><li>'],
#   ['Опыт разработки эмуляторов/заглушек;', '</li><li>'],
#   ['Опыт написания тестовых сценариев;', '</li><li>'],
#   ['Знание практик DevOps (Continuous Integration, Continuous Delivery, Continuous Deployment) и опыт работы с инструментами (Jenkins, Ansible).',
#    '</li></ul><p> </p><p>'],
#   ['<b>Что нужно будет делать:</b>', '</p><p> </p><ul><li>'],
#   ['<b>Что не нужно будет делать:</b>', '</p><ul><li>']],
#  [],
#  [['Опыт написания бизнес-, функциональных требований к продуктам - от 5 лет;',
#    '',
#    '</li><li>'],
#   ['Опыт реализации больших интеграционных проектов в качестве бизнес-аналитика, бизнес-архитектора;',
#    '',
#    '</li><li>'],
#   ['Опыт проведения стратегического анализа, разработки KPI и дашбордов по бизнес-архитектуре Банка;',
#    '',
#    '</li><li>'],
#   ['Навыки ведения переговоров, отличные коммуникативные навыки;',
#    '',
#    '</li><li>'],
#   ['Знание жизненного цикла разработки продуктов, опыт работы в проектных и Agile командах;',
#    '',
#    '</li><li>'],
#   ['Навыки визуализации идей, подготовки презентаций;', '', '</li><li>']],
#  [],
#  [['Курс проводят наши тимлидами разработки и специалисты с большим опытом',
#    '',
#    '',
#    '</li><li>'],
#   ['<b>Мы ждем тебя, если:</b>', '', '</p><ul><li>'],
#   ['<b>Мы ждем тебя, если:</b>', '', '</p><ul><li>'],
#   ['Если ты знаешь, что HTML не язык программирования', '', '', '</li><li>'],
#   ['Если ты открывал инструменты разработчика в браузере',
#    '',
#    '',
#    '</li><li>'],
#   ['Если тебе интересна веб разработка и ты хочешь развиваться в этом направлении',
#    '',
#    '',
#    '</li><li>'],
#   ['У тебя есть опыт в разработке ПО или образование - информационные и компьютерные технологии, прикладная математика, физика и другие смежные специальности',
#    '',
#    '',
#    '<br/>'],
#   ['У тебя есть опыт в разработке ПО или образование - информационные и компьютерные технологии, прикладная математика, физика и другие смежные специальности',
#    '',
#    '',
#    '<br/>'],
#   ['<u>Будет здорово, если:</u>', '', '</li></ul><ul><li>'],
#   ['<u>Будет здорово, если:</u>', '', '</li></ul><ul><li>'],
#   ['Если ты умеешь верстать и хочешь развиваться в сторону разработки',
#    '',
#    '',
#    '</li></ul><p>']],
#  [['-разработчика. Желателен опыт разработки мобильных приложений от 1 года и более.',
#    '</p><p> </p><p><b>'],
#   ['Мы ожидаем, что Вы обладаете следующими знаниями и навыками:',
#    '</b></p><p> </p><p>'],
#   ['Опыт', ''],
#   ['стек', ''],
#   ['использовать современные подходы, инструменты и технологии.',
#    '</p><p> </p><p><b>']]]

# %%
for i in filtered:
    if '29683735' in i[0]:
        print(i[1])
# Out:
# <div class="g-user-content" data-qa="vacancy-description" itemprop="description"><p><b><span>Наша цель,<span> </span></span></b><span>сделать так, чтобы<span><b> </b></span><b>предприниматель - клиент Сбербанка,<span> </span></b></span><b><span>c</span><span>мог решить любой вопрос за секунды через интернет или контактный центр</span></b><span>. Мы — это команда<span><b> </b></span><b>ц</b>ентра корпоративных решений корпоративного блока. Наша миссия превратить Сбербанк в Банк Секунд.</span></p><p></p><p><span>Для этого мы ищем<span> </span><b>Владельца ИТ-продукта,<span> </span></b>чтобы он вместе с командой из 9 человек разрабатывал ПО для сотрудников контактных центров и предпринимателей-клиентов Банка. Создавал и внедрял прорывные технологии для улучшения клиентского опыта.</span></p><p></p><p><b><span>О продукте: <p></p></span></b></p><p><span><span>Ø<span> </span></span></span><span>Ко-браузинг – новый продукт Корпоративного блока, который позволит быстрее и эффективнее обслуживать клиентов Сбербанка удаленно. <p></p></span></p><p><span><span>Ø<span> </span></span></span><span>Ко-браузинг – это возможность подключения сотрудника контактного центра к клиенту в доступном канале коммуникации для диагностики проблем, навигации по сайту, а также осуществления активных действий со стороны клиента в момент обращения.<p></p></span></p><p><b><span>Нам нужны креативные лидеры новой формации, готовые:</span></b></p><p><b></b></p><p><span><span>·<span> </span></span></span><span>Приносить<span> </span><b>реальную</b><span> </span>ценность для клиента;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Работать<span> </span><b>в гибком режиме<span> </span></b></span><b><span>Agile</span></b><b><span>;</span></b></p><p></p><p><span><span>·<span> </span></span></span><b><span>Вместе с командой</span></b><span><span> </span></span><span>достигать общие цели.</span></p><p></p><p><b><span>Ежедневные задачи для нашего владельца продукта:</span></b></p><p><b></b></p><p><span><span>·<span> </span></span></span><span>Формирование видения и дорожной карты продукта;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Вовлечение заинтересованных лиц в создание требований;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Управление бэклогом и расстановка приоритетов для команды;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Управление ожиданиями и сроками поставки функциональности потребителю;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Проведение<span> </span></span><span>Agile<span> </span></span><span>церемоний: Стендап, Планирование, Демо и др.;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Внедрение результатов работы команды и передача продукта в эксплуатацию.</span></p><p></p><p><b><span>Мы ожидаем от Вас:</span></b></p><p><b></b></p><p><span><span>·<span> </span></span></span><span>Опыт работы владельцем продукта или менеджером проекта не менее 3-х лет;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Подтвержденный опыт разработки и внедрения цифровых продукт</span><span>ов<span>;</span></span></p><p></p><p><span><span>·<span> </span></span></span><span>Опыт управления командой разработки;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Знание современных технологий и инфраструктуры;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Самобытность и самостоятельность;</span></p><p></p><p><span><span>·<span> </span></span></span><span>Высшее образование.</span></p><p></p><p><b><span>От нас:</span></b><span><p></p></span></p><p><span><span>·<span> </span></span></span><span>Работа среди профессионалов банковского дела;<p></p></span></p><p><span><span>·<span> </span></span></span><span>Профессиональное обучение и развитие;<p></p></span></p><p><span><span>·<span> </span></span></span><span>Мотивирующая система оплаты труда;<p></p></span></p><p><span><span>·<span> </span></span>< ...

# %%
len(p_list)
# Out:
# 48

# %% [markdown]
# # !!!
