# %%
import feedparser
import re
from bs4 import BeautifulSoup
import json

# %%
def cleanhtml(raw_html):
    '''
    
    функция, которая убирает из текста тэги/литералы, очищает его
    '''
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '', raw_html)
    return ' '.join(cleantext.split())

# %%
def get_news(user_id):
    with open('rss_bot_info.json', 'r') as read_obj:
        current = json.load(read_obj)
    
    chosen_news = []
    
    # запоминание пользовательских предпочтений
    try:
        categories = current['users'][user_id]['categories']
        keywords = current['users'][user_id]['keywords']
        links = [y[0] for y in [current['sources'][x] for x in categories]]
    except:
        return('ошибка данных')
    
    # анализ каждой новости из каждой ссылки
    for link in links:
        news_line = feedparser.parse(link).entries
        for news in news_line:
            content = cleanhtml(news.summary)
            if check_it(content, keywords):
                if 'document.write' in content:
                    content = content[: content.index('document.write') - 1]
                clean = {'title': news.title, 'link': news.links[0]['href'], 'content': content}
                chosen_news.append(clean)
    return chosen_news

# %%
test_id = "268178395"

# %%
get_news(test_id)
# Out:
# [{'title': 'Зеленский призвал решить конфликт в Донбассе дипломатическим путем',
#   'link': 'https://lenta.ru/news/2019/10/28/mirumir/',
#   'content': 'Разведение сил и средств в поселках Золотое и Петровское необходимо для разрешения конфликта в Донбассе, заявил президент Украины Владимир Зеленский. По его словам, Киеву необходимо попытаться восстановить мир дипломатическим путем. Зеленский отметил, что с Россией нельзя вести диалог с позиции силы.'},
#  {'title': 'Раскрыты подробности разоружения украинских националистов в Донбассе',
#   'link': 'https://lenta.ru/news/2019/10/28/bezoruzhnye/',
#   'content': 'Украинские националисты вывезли оружие из поселка Золотое в Донбассе в сопровождении полицейских, рассказал заместитель главы Национальной полиции Украины Вадим Троян. По его словам, правоохранительные органы будут проводить в зоне конфликта «антидиверсионную работу против незаконных вооруженных формирований».'},
#  {'title': 'Горбачев засомневался в желании США заключить новый договор взамен ДРСМД',
#   'link': 'https://lenta.ru/news/2019/10/28/gorby/',
#   'content': 'Заявления США о готовности заключить новый договор взамен Договора о ликвидации ракет средней и меньшей дальности (ДРСМД) не должны вводить в заблуждение. Об этом заявил бывший президент СССР Михаил Горбачев. Он также отметил то, что российский лидер Владимир Путин пообещал не размещать первыми такие ракеты в Европе.'},
#  {'title': '«Манчестер Юнайтед» прервал четырехматчевую серию без побед в АПЛ',
#   'link': 'https://lenta.ru/news/2019/10/27/mubezpobed/',
#   'content': '«Манчестер Юнайтед» на выезде обыграл «Норвич» в матче десятого тура Английской премьер-лиги (АПЛ). Встреча прошла в воскресенье, 27 октября, и завершилась со счетом 3:1 в пользу гостей. Голами отметились Маркус Рашфорд, Скотт Мактоминей и Антони Марсьяль. Вратарь «канареек» Тим Крул взял два пенальти.'},
#  {'title': '«Ливерпуль» одержал волевую победу над «Тоттенхэмом» в центральном матче тура АПЛ',
#   'link': 'https://lenta.ru/news/2019/10/27/liverproblems/',
#   'content': '«Ливерпуль» на своем поле обыграл «Тоттенхэм» в матче десятого тура Английской премьер-лиги (АПЛ). Встреча прошла в воскресенье, 27 октября, на стадионе «Энфилд» и завершилась со счетом 2:1 в пользу хозяев. В составе победителей голами отметились Джордан Хендерсон и Мохамед Салах.'},
#  {'title': 'Российский боец MMA оправдал Макгрегора за слова о дагестанцах',
#   'link': 'https://lenta.ru/news/2019/10/27/schlemenko/',
#   'content': 'Российский боец смешанного стиля (MMA) Александр Шлеменко прокомментировал конфликт дагестанцев с ирландцем Конором Макгрегором. «Там есть легкий перегиб. Макгрегор на пресс-конференции не говорил, что дагестанцы – трусы. Он сказал, что они бегают. Но это не означает, что они трусы», — заявил Шлеменко.'},
#  {'title': 'Раскрыты подробности задержания планировавшего массовое убийство подростка',
#   'link': 'https://lenta.ru/news/2019/10/27/zaderjanie/',
#   'content': 'Сотрудники правоохранительных органов задержали студента аграрного техникума Бориса Б. после попытки купить оружие и взырвчатку в интернете. Молодой человек хотел устроить массовое убийство в ближайшие дни в колледже, в котором он учился. Подросток даже выписал имена людей, с которыми у него произошел конфликт.'},
#  {'title': '«Спартак» одержал первую победу при новом тренере',
#   'link': 'https://lenta.ru/news/2019/10/27/schpartak/',
#   'content': 'Московский «Спартак» одержал победу над «Локомотивом» в матче 14-го тура Российской премьер-лиги (РПЛ). Встреча завершилась со счетом 3:0. Голами отметились нападающие Эсекиэль Понсе (57-й минута) и Йордан Ларссон (79-я, 81-я). Красно-белые провели второй матч под руководством тренера Доменико Тедеско.'},
#  {'title': 'Реакция Путина на выложенные Эрдоганом карты попала на видео',
#   'link': 'https://lenta.ru/news/2019/10/27/uberi/',
#   'content': 'Президент России Владимир Путин посоветовал турецкому коллеге Реджепу Тайипу Эрдогану закрыть от телекамер карты, которые тот принес на переговоры по Сирии, состоявшиеся в Сочи. Эрдоган в ответ на совет Путина заявил, что хочет, чтобы карты были видны. «Пусть видят, сколько мы работаем», — объяснил турецкий лидер.'},
#  {'title': 'Российские туристы поссорились с водителем автобуса и попали в тюрьму на Кипре',
#   'link': 'https://lenta.ru/news/2019/10/27/kipr/',
#   'content': 'Российских туристов приговорили к двум месяцам тюрьмы после конфликта с водителем автобуса на Кипре. По словам родственников осужденных, инцидент произошел 30 сентября на курорте Айя-Напа. Два брата ехали в автобусе с матерью, у них возник конфликт с водителем, который не брал оплату за проезд мелкими деньгами.'},
#  {'title': 'У планировавшего массовое убийство российского подростка нашли «тетрадь смерти»',
#   'link': 'https://lenta.ru/news/2019/10/27/death_note/',
#   'content': 'У студента подмосковного аграрного колледжа Бориса Б., который планировал массовое убийство, около года назад нашли так называемую тетрадь смерти. Отмечается, что Борис вел список тех, кого хотел убить, — там было минимум 8 человек, в том числе и педагог. Он вписывал имена людей, с которыми у него произошел конфликт.'},
#  {'title': 'Враждующие российские ОПГ устроили ночную перестрелку',
#   'link': 'https://lenta.ru/news/2019/10/27/perestrelka/',
#   'content': 'Две противоборствующие организованные преступные группировки (ОПГ) устроили ночную перестрелку в Кировском районе Казани, заявили в пресс-службе МВД Татарстана. Как рассказали в ведомстве, полиция задержала 14 предполагаемых участников конфликта. По факту произошедшего возбуждено уголовное дело.'},
#  {'title': 'Власти оценили план захвата Калининградской области Польшей и США',
#   'link': 'https://lenta.ru/news/2019/10/27/plan/',
#   'content': 'Вероятная потеря Калининградской области в результате потенциального военного конфликта между Россией и странами НАТО в Прибалтике является фантастическим прогнозом. Таким мнением поделился губернатор региона Антон Алиханов. Собеседник издания указал, что устал комментировать «американские глупости».'},
#  {'title': 'Опубликован план захвата Калининградской области Польшей и США',
#   'link': 'https://lenta.ru/news/2019/10/27/force/',
#   'content': 'Потенциальный военный конфликт между Россией и государствами НАТО в Прибалтике приведет к потере первой Калининградской области. Вероятный ход развития соответствующих военных действий прогнозирует старший научный сотрудник Джеймстаунского фонда (США) доктор Ричард Хукер.'},
#  {'title': 'Футболисты начали радоваться незабитому голу и пропустили',
#   'link': 'https://lenta.ru/news/2019/10/26/hajduk_vam/',
#   'content': 'Игроки «Хайдука» воспользовались замешательством футболистов «Славена Белуло» и забили гол в матче чемпионата Хорватии. На 74-й минуте футболисты «Славена Белуло» посчитали, что сумели забить гол. Однако мяч после дальнего удара хавбека Неманьи Главчича не пересек линию ворот.'},
#  {'title': '«Вест Хэм» на своем поле упустил победу над новичком АПЛ',
#   'link': 'https://lenta.ru/news/2019/10/26/westhamsheffield/',
#   'content': 'Лондонский «Вест Хэм» на своем поле сыграл вничью с «Шеффилд Юнайтед» в матче десятого тура Английской премьер-лиги (АПЛ). Матч прошел в субботу, 26 октября, в британской столице и завершился со счетом 1:0 в пользу хозяев. На гол Роберта Снодграсса точным ударом ответил Ли Муссе.'},
#  {'title': 'Путин рассказал Макрону о судьбоносных решениях по ситуации на границе Сирии',
#   'link': 'https://lenta.ru/news/2019/10/26/putinmakron/',
#   'content': 'Президент России Владимир Путин провел телефонный разговор с французским коллегой Эммануэлем Макроном. В ходе беседы глава государства рассказал о содержании российско-турецких переговоров, которые прошли в Сочи 22 октября. Французский лидер положительно оценил договоренности между Москвой и Анкарой.'},
#  {'title': 'Пастрняк набрал 23-е очко в сезоне и лидирует в гонках бомбардиров и снайперов НХЛ',
#   'link': 'https://www.sports.ru/hockey/1079573987.html',
#   'content': 'Форвард «Бостона» Давид Пастрняк сделал пять голевых передач в матче чемпионата НХЛ с «Рейнджерс» (7:4). Всего в 11 играх сезона чех набрал 23 (11+12) очка и возглавил гонку бомбардиров, опережая на 2 балла защитника «Вашингтона» Джона Карлсона и двух нападающих «Эдмонтона» – Коннора Макдэвида и Леона Драйзайтля. Также Пастрняк с 11 шайбами по-прежнему лидирует в списке снайперов. Форвард «Эдмонтона» Джеймс Нил забил 10 голов. По 9 шайб на счету капитана «Вашингтона» Александра Овечкина, Брэйдена Шенна («Сент-Луис»), Остона Мэттьюса («Торонто») и Драйзайтля. Статистика НХЛ'}]

# %%
test_ans = [{'title': 'Зеленский призвал решить конфликт в Донбассе дипломатическим путем',
  'link': 'https://lenta.ru/news/2019/10/28/mirumir/',
  'content': 'Разведение сил и средств в поселках Золотое и Петровское необходимо для разрешения конфликта в Донбассе, заявил президент Украины Владимир Зеленский. По его словам, Киеву необходимо попытаться восстановить мир дипломатическим путем. Зеленский отметил, что с Россией нельзя вести диалог с позиции силы.'}]

# %%
def reformat(text):
    return text['title'] + '\n\n' + text['content'] + '\n\n' + text['link']

# %%
print(reformat(test_ans[0]))
# Out:
# Зеленский призвал решить конфликт в Донбассе дипломатическим путем
#
# Разведение сил и средств в поселках Золотое и Петровское необходимо для разрешения конфликта в Донбассе, заявил президент Украины Владимир Зеленский. По его словам, Киеву необходимо попытаться восстановить мир дипломатическим путем. Зеленский отметил, что с Россией нельзя вести диалог с позиции силы.
#
# https://lenta.ru/news/2019/10/28/mirumir/

# %% [markdown]
# #### функция, которая проверяет наличие ключевых слов в новости

# %%
import string
import nltk
from nltk.corpus import stopwords
import pymorphy2

# %%
def check_it(text, keywords):
    morph = pymorphy2.MorphAnalyzer()
    
    keywords = set([morph.parse(word.lower())[0].normal_form for word in keywords])
    word_list = set([morph.parse(i.lower())[0].normal_form for i in nltk.word_tokenize(text) \
                     if i not in string.punctuation + '»«–' and i not in stopwords.words('russian')])
    
    return keywords & word_list != set()

# %%
test_news = '''
            Главный тренер «Манчестер Юнайтед» Оле-Гуннар Сульшер 
            прокомментировал ситуацию с травмой полузащитника Поля Погба. 
            «Не думаю, что мы увидим Поля до декабря. 
            Он будет отсутствовать еще некоторое время. Ему нужно время, 
            чтобы полностью восстановиться. Вероятно, наступит декабрь, 
            прежде чем мы сможем увидеть его на поле», – сказал Сульшер. 
            Француз остается вне игры с 30 сентября из-за травмы. 
            Ранее сообщалось, что Погба вернется в строй в ноябре.
            '''

# %%
check_it(test_news, ['авбу', 'погба'])
# Out:
# True

# %%
str(test_ans[0]['title'] + '\n\n' + test_ans[0]['content'] + '\n\n' + test_ans[0]['link'])
# Out:
# 'Зеленский призвал решить конфликт в Донбассе дипломатическим путем\n\nРазведение сил и средств в поселках Золотое и Петровское необходимо для разрешения конфликта в Донбассе, заявил президент Украины Владимир Зеленский. По его словам, Киеву необходимо попытаться восстановить мир дипломатическим путем. Зеленский отметил, что с Россией нельзя вести диалог с позиции силы.\n\nhttps://lenta.ru/news/2019/10/28/mirumir/'

# %%
print('abc' + '\n\n')
# Out:
# abc
